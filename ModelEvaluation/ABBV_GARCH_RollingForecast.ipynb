# %%
# !pip install arch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: arch in /usr/local/lib/python3.10/dist-packages (6.1.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from arch) (1.22.4)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from arch) (1.10.1)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from arch) (1.5.3)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.10/dist-packages (from arch) (0.13.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2022.7.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (23.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels>=0.12->arch) (1.16.0)

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import yfinance as yf
import arch

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/My Drive/thesis/3rd_presentation')
df = pd.read_csv('monthly_data.csv')

# %%
df
# Out:
#      Unnamed: 0        Date  unemployment_rate  inflation_rate  \
# 0             0  2000-01-01                4.0         169.300
# 1             1  2000-02-01                4.1         170.000
# 2             2  2000-03-01                4.0         171.000
# 3             3  2000-04-01                3.8         170.900
# 4             4  2000-05-01                4.0         171.200
# ..          ...         ...                ...             ...
# 278         278  2023-03-01                3.5         301.808
# 279         279  2023-04-01                3.4         302.918
# 280         280  2023-05-01                3.7             NaN
# 281         281  2023-06-01                NaN             NaN
# 282         282  2023-07-01                NaN             NaN
#
#      treasury_yield  Monthly Real GDP Index  GDP_growth  SP500_return  \
# 0               NaN             12870.47162   -1.066967           NaN
# 1          6.661000             12934.38121    0.496560     -1.522563
# 2          6.519500             13000.50928    0.511258      9.413333
# 3          6.256522             13173.13041    1.327803     -3.266805
# 4          5.990526             13149.18201   -0.181797     -1.572223
# ..              ...                     ...         ...           ...
# 278        3.746842                     NaN         NaN      3.313488
# 279        3.663043                     NaN         NaN      1.985238
# 280        3.460000                     NaN         NaN      0.461619
# 281        3.573636                     NaN         NaN           NaN
# 282        3.610000                     NaN         NaN           NaN
#
#          ABBV        AZN        BMY        JNJ        LLY        MRK  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN -12.828964 -13.228004 -16.339821 -11.121498 -21.701151
# 2         NaN  22.264136  -0.218329  -2.079067   5.804243   0.913712
# 3         NaN   5.567379  -8.205683  17.437698  23.153694  12.400712
# 4         NaN  -0.148357   5.395746   8.484832  -1.296597   7.374072
# ..        ...        ...        ...        ...        ...        ...
# 278  3.554254   8.035329   0.507544   1.862736  10.703390   0.141189
# 279 -5.176628   5.489119  -3.664707   5.612908  15.269915   9.289214
# 280 -7.868480  -0.191204  -2.695194  -5.277949   8.487855  -4.382088
# 281       NaN        NaN        NaN        NaN        NaN        NaN
# 282       NaN        NaN        NaN        NaN        NaN        NaN
#
#            NVO        NVS        PFE        ROG
# 0          NaN        NaN        NaN        NaN
# 1     2.220031   3.838386 -11.226228  54.440789
# 2     8.390897   6.420237  14.101954   6.922258
# 3    -0.097663   2.559423  15.213674   7.370518
# 4    20.863985   5.169310   5.638019  -8.163265
# ..         ...        ...        ...        ...
# 278  12.873250   9.367574   0.566924  11.025813
# 279   5.836894  16.334413  -4.681371  -1.517467
# 280  -3.967915  -6.161645  -2.237080  -2.162160
# 281        NaN        NaN        NaN        NaN
# 282        NaN        NaN        NaN        NaN
#
# [283 rows x 18 columns]

# %%
df = df[['Date', 'ABBV']]

# %%
df = df.dropna()

# %%
df
# Out:
#            Date       ABBV
# 158  2013-03-01  10.455062
# 159  2013-04-01  12.922975
# 160  2013-05-01  -6.438455
# 161  2013-06-01  -3.162299
# 162  2013-07-01  10.014486
# ..          ...        ...
# 276  2023-01-01  -8.576205
# 277  2023-02-01   5.152609
# 278  2023-03-01   3.554254
# 279  2023-04-01  -5.176628
# 280  2023-05-01  -7.868480
#
# [123 rows x 2 columns]

# %%
data = pd.read_csv('non_nan_4.csv')

# %%
merged_df = df.merge(data, on='Date', how='inner')
merged_df
# Out:
#            Date       ABBV  unemployment_rate      CPI  treasury_yield  \
# 0    2013-03-01  10.455062                7.5  232.282        1.984211
# 1    2013-04-01  12.922975                7.6  231.797        1.957500
# 2    2013-05-01  -6.438455                7.5  231.893        1.759091
# 3    2013-06-01  -3.162299                7.5  232.445        1.928182
# 4    2013-07-01  10.014486                7.3  232.900        2.300000
# ..          ...        ...                ...      ...             ...
# 118  2023-01-01  -8.576205                3.4  300.536        3.616190
# 119  2023-02-01   5.152609                3.6  301.648        3.531500
# 120  2023-03-01   3.554254                3.5  301.808        3.746842
# 121  2023-04-01  -5.176628                3.4  302.918        3.663043
# 122  2023-05-01  -7.868480                3.7  304.127        3.460000
#
#      GDP_growth  SP500_return        AZN        BMY       JNJ        LLY  \
# 0      0.397212      3.337507  14.582205  11.414669  7.978126   4.851792
# 1      0.085246      2.374537   3.881563  -3.568848  4.538222  -2.482836
# 2     -0.190605      2.361004  -1.290451  16.816781 -1.231989  -4.008663
# 3      0.620501     -1.853781  -7.707318  -2.868894  2.762464  -6.788137
# 4      0.210359      5.724173   7.230424  -3.244595  8.898141   8.122938
# ..          ...           ...        ...        ...       ...        ...
# 118    0.390254      6.776820  -3.584079   0.972908 -7.489384  -5.928822
# 119   -0.442183     -2.514271  -0.290649  -4.328217 -6.217115  -9.568502
# 120   -0.442183      3.313488   8.035329   0.507544  1.862736  10.703390
# 121   -0.442183      1.985238   5.489119  -3.664707  5.612908  15.269915
# 122   -0.442183      0.461619  -0.191204  -2.695194 -5.277949   8.487855
#
#           MRK        NVO        NVS        PFE        ROG  inflation_change  \
# 0    3.440210  -7.714279   9.067089   5.443922  -0.188640            -0.655
# 1    7.359867  11.497419   3.537347   0.727651 -10.457790            -0.485
# 2   -0.638313  -8.792401  -2.711502  -6.329562   8.513136             0.096
# 3   -0.535372  -3.805087  -1.463219   3.722003   2.269287             0.552
# 4    4.655361   9.001745   1.272809   4.355584  17.540151             0.455
# ..        ...        ...        ...        ...        ...               ...
# 118 -2.549213   2.541749  -0.110227 -13.817335  16.968326             1.546
# 119 -1.089288   1.592445  -7.172811  -7.286115   5.451681             1.112
# 120  0.141189  12.873250   9.367574   0.566924  11.025813             0.160
# 121  9.289214   5.836894  16.334413  -4.681371  -1.517467             1.110
# 122 -4.382088  -3.967915  -6.161645  -2.237080  -2.162160             0.100
#
#      unemp_change  treasury_yield_change
# 0            -0.2               0.069449
# 1             0.1              -0.026711
# 2            -0.1              -0.198409
# 3             0.0               0.169091
# 4            -0.2               0.371818
# ..            ...                    ...
# 118          -0.1              -0.274810
# 119           0.2              -0.084690
# 120          -0.1               0.215342
# 121          -0.1              -0.083799
# 122           0.3              -0.203043
#
# [123 rows x 19 columns]

# %%
def create_lags(data, tickers, covs, period):
    lagged_covs = []  # List to store the names of lagged columns

    for covariate in covs:
        for i in period:
            lagged_column_name = f'{covariate}_lag{i}'
            data[lagged_column_name] = data[covariate].shift(i)
            lagged_covs.append(lagged_column_name)

    lagged_tickers = []  # List to store the names of lagged columns

    for tick in tickers:
        for i in period:
            lagged_column_name = f'{tick}_lag{i}'
            data[lagged_column_name] = data[tick].shift(i)
            lagged_tickers.append(lagged_column_name)

    data.dropna(inplace=True)
    data = data.reset_index(drop=True)

    return data, lagged_covs, lagged_tickers

# %%
tickers = ['ABBV', 'AZN', 'BMY', 'JNJ', 'LLY', 'MRK', 'NVO', 'NVS', 'PFE','ROG']
covs = ['unemployment_rate', 'CPI', 'treasury_yield', 'GDP_growth', 'SP500_return', 'inflation_change', 'unemp_change', 'treasury_yield_change']
period = [1, 2, 3]

data, lagged_covs, lagged_tickers = create_lags(merged_df, tickers, covs, period)

# %%
merged_df
# Out:
#            Date       ABBV  unemployment_rate      CPI  treasury_yield  \
# 3    2013-06-01  -3.162299                7.5  232.445        1.928182
# 4    2013-07-01  10.014486                7.3  232.900        2.300000
# 5    2013-08-01  -5.449157                7.2  233.456        2.582273
# 6    2013-09-01   4.975348                7.2  233.544        2.737273
# 7    2013-10-01   8.316584                7.2  233.669        2.809500
# ..          ...        ...                ...      ...             ...
# 118  2023-01-01  -8.576205                3.4  300.536        3.616190
# 119  2023-02-01   5.152609                3.6  301.648        3.531500
# 120  2023-03-01   3.554254                3.5  301.808        3.746842
# 121  2023-04-01  -5.176628                3.4  302.918        3.663043
# 122  2023-05-01  -7.868480                3.7  304.127        3.460000
#
#      GDP_growth  SP500_return       AZN        BMY       JNJ  ...   NVO_lag3  \
# 3      0.620501     -1.853781 -7.707318  -2.868894  2.762464  ...  -7.714279
# 4      0.210359      5.724173  7.230424  -3.244595  8.898141  ...  11.497419
# 5      0.377706     -2.999246 -2.977106  -2.825803 -7.582886  ...  -8.792401
# 6     -0.064491      2.664237  7.407628  11.009813  1.079907  ...  -3.805087
# 7      0.403511      5.140646  1.790868  13.483172  6.828970  ...   9.001745
# ..          ...           ...       ...        ...       ...  ...        ...
# 118    0.390254      6.776820 -3.584079   0.972908 -7.489384  ...   9.244201
# 119   -0.442183     -2.514271 -0.290649  -4.328217 -6.217115  ...  14.479974
# 120   -0.442183      3.313488  8.035329   0.507544  1.862736  ...   8.619586
# 121   -0.442183      1.985238  5.489119  -3.664707  5.612908  ...   2.541749
# 122   -0.442183      0.461619 -0.191204  -2.695194 -5.277949  ...   1.592445
#
#       NVS_lag1   NVS_lag2   NVS_lag3   PFE_lag1   PFE_lag2   PFE_lag3  \
# 3    -2.711502   3.537347   9.067089  -6.329562   0.727651   5.443922
# 4    -1.463219  -2.711502   3.537347   3.722003  -6.329562   0.727651
# 5     1.272809  -1.463219  -2.711502   4.355584   3.722003  -6.329562
# 6     1.913146   1.272809  -1.463219  -2.702547   4.355584   3.722003
# 7     5.110979   1.913146   1.272809   1.843363  -2.702547   4.355584
# ..         ...        ...        ...        ...        ...        ...
# 118   1.295221  10.390734   6.735944   3.090302   7.690670   6.375682
# 119  -0.110227   1.295221  10.390734 -13.817335   3.090302   7.690670
# 120  -7.172811  -0.110227   1.295221  -7.286115 -13.817335   3.090302
# 121   9.367574  -7.172811  -0.110227   0.566924  -7.286115 -13.817335
# 122  16.334413   9.367574  -7.172811  -4.681371   0.566924  -7.286115
#
#       ROG_lag1   ROG_lag2   ROG_lag3
# 3     8.513136 -10.457790  -0.188640
# 4     2.269287   8.513136 -10.457790
# 5    17.540151   2.269287   8.513136
# 6    -0.269683  17.540151   2.269287
# 7     7.229130  -0.269683  17.540151
# ..         ...        ...        ...
# 118   9.446071 -53.665066  -2.707956
# 119  16.968326   9.446071 -53.665066
# 120   5.451681  16.968326   9.446071
# 121  11.025813   5.451681  16.968326
# 122  -1.517467  11.025813   5.451681
#
# [120 rows x 73 columns]

# %%
"""def tick_loss(alpha, returns, var):
    df = pd.DataFrame({'Return': returns, 'VaR': var})
    df['Indicator'] = np.where(df['Return'] < df['VaR'], 1, 0)

    t_loss = 0

    for i in df.index:
        t_loss += (
            alpha * (df['Return'][i] - df['VaR'][i]) * (1 - df['Indicator'][i])
            + (1 - alpha) * (df['VaR'][i] - df['Return'][i]) * df['Indicator'][i]
        )

    return t_loss, df"""

# %%
def tick_loss(alpha, returns, var):
    df = pd.DataFrame({'Return': returns, 'VaR': var})
    df['Indicator'] = np.where(df['Return'] < df['VaR'], 1, 0)

    t_loss = 0

    for i in df.index:
        t_loss += (
            alpha * (df['Return'][i] - df['VaR'][i]) * (1 - df['Indicator'][i])
            + (1 - alpha) * (df['VaR'][i] - df['Return'][i]) * df['Indicator'][i]
        )

    return t_loss

# %% [markdown]
# # 1 month ahead

# %%
import pandas as pd
import statsmodels.api as sm
from arch import arch_model
from scipy.stats import norm

def rolling_1m_forecast(data, dates, ticker, alpha):
    t_loss = 0
    dta = data.copy()

    for d in dates:
        train_df = dta[dta.Date <= d]
        test_df = dta[dta.Date > d]
        test_df = test_df.reset_index(drop=True)

        X_train = train_df.drop(columns=[ticker, 'Date'])
        y_train = train_df[ticker]

        X_test = test_df.drop(columns=[ticker, 'Date'])
        X_test = X_test.iloc[0]
        y_test = test_df[ticker]

        garch_model = arch_model(y_train, vol='Garch', p=1, q=1)
        garch_results = garch_model.fit()

        forecasts = garch_results.forecast(start=0, horizon=1)
        cond_vol_forecast = forecasts.variance.iloc[-1].apply(lambda x: np.sqrt(x))
        mean_forecast = forecasts.mean.iloc[-1]

        VaR_forecast = mean_forecast + cond_vol_forecast * norm.ppf(alpha)

        loss = tick_loss(alpha, y_test.iloc[0], VaR_forecast)

        t_loss += loss

    t_loss = t_loss / 12

    return t_loss

# %%
dates1m = ['2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01']

# %%
for t in tickers:
    if t == 'ABBV':
        loss = rolling_1m_forecast(data, dates1m, t, 0.05)
        print(f'{t}: {loss}')
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 415.16727965562995
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 372.02697265857495
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 371.6563427613615
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 371.80367697607505
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 371.6562462535467
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 371.49926145709287
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 371.49708379222403
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 371.4969264728807
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 371.496903467082
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 371.49690102612215
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 371.4969010274283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 371.49690102612215
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 418.67451080163954
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 375.1585880644287
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 374.8105958017746
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 374.7866213798662
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 374.72103880978204
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 374.61413382292835
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 374.6138123456507
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 374.6137104988059
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 374.61370013748956
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 374.61369837266
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 374.61369837325896
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 374.61369837266
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 422.9131433546542
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 378.6756979601627
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 378.37390192466216
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 378.2874799307776
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 378.258475714919
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 378.12552503662175
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 378.1252091232855
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 378.12508284433756
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 378.125061362382
# Iteration:     10,   Func. Count:     55,   Neg. LLF: 378.12506136095044
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 378.125061362382
#             Iterations: 10
#             Function evaluations: 55
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 426.95493424949484
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 383.4850662663436
# Iteration:      3,   Func. Count:     21,   Neg. LLF: 381.62405217008256
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 381.783652233557
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 381.57256151581413
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 381.5531576553225
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 381.54274044624026
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 381.54217269031454
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 381.54215153852164
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 381.5421507032837
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 381.5421507032837
#             Iterations: 10
#             Function evaluations: 57
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 430.37301780008585
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 386.98565165072205
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 384.6971651351057
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 384.7226738077194
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 384.6865281198993
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 384.6493622327128
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 384.6477905185079
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 384.62980270290535
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 384.6297918431379
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 384.6297918433429
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 384.6297918431379
#             Iterations: 10
#             Function evaluations: 58
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 434.5194883716753
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 390.2004099484524
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 388.12712322362785
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 388.1269123835097
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 388.11975242589097
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 388.0904899285459
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 388.0960447093733
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 388.06413944570085
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 388.0640870328092
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 388.0640835343753
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 388.06408353458477
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 388.0640835343753
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 439.15733750433867
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 393.82002582033374
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 391.80931396182774
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 391.8044222064833
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 391.7931140612698
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 391.74997164743627
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 391.7437170687829
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 391.74288912204486
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 391.74262968968367
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 391.7426249096537
# Iteration:     11,   Func. Count:     61,   Neg. LLF: 391.7426249117756
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 391.7426249096537
#             Iterations: 11
#             Function evaluations: 61
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 442.5241388149222
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 396.76616908697224
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 394.86060995934656
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 395.18769558088565
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 394.8504135908757
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 394.81870808026287
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 394.8142520956877
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 394.80889382403376
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 394.80865413687184
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 394.8086408233469
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 394.808632903825
# Iteration:     12,   Func. Count:     67,   Neg. LLF: 394.8086329038789
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 394.808632903825
#             Iterations: 12
#             Function evaluations: 67
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 447.4472767039716
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 400.7812345613748
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 398.672221390379
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 398.67996738143006
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 398.6665481610421
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 398.6411640509694
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 398.64432220821226
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 398.6117271981704
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 398.61166438709944
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 398.61166089087925
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 398.61166089122696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 398.61166089087925
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 450.9472781410528
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 403.73799268412455
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 401.78890673150744
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 402.130877017702
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 401.7763192887182
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 401.7442447620445
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 401.7412470578716
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 401.7404413869029
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 401.74042138861677
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 401.74041997107025
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 401.7404191945482
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 401.7404191945482
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 461.3234811636654
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 405.39400857157244
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 406.7657447619852
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 405.5795685126503
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 405.4915905205244
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 419.81478330082274
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 405.1616385819366
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 404.8496507462971
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 405.1914082181492
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 404.96148181777
# Iteration:     11,   Func. Count:     66,   Neg. LLF: 404.79732482000725
# Iteration:     12,   Func. Count:     71,   Neg. LLF: 404.7972449436512
# Iteration:     13,   Func. Count:     76,   Neg. LLF: 404.7972439877279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 404.7972439877279
#             Iterations: 13
#             Function evaluations: 76
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 465.53475176011074
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 408.75924925399136
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 409.9630436766014
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 408.92807392261375
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 408.88262419345847
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 520.0275825778482
# Iteration:      7,   Func. Count:     44,   Neg. LLF: 408.6553909492625
# Iteration:      8,   Func. Count:     50,   Neg. LLF: 408.4414990412284
# Iteration:      9,   Func. Count:     56,   Neg. LLF: 410.1947057912603
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 408.18628676754753
# Iteration:     11,   Func. Count:     67,   Neg. LLF: 408.2215337020183
# Iteration:     12,   Func. Count:     73,   Neg. LLF: 408.1758265736322
# Iteration:     13,   Func. Count:     78,   Neg. LLF: 408.17567811170653
# Iteration:     14,   Func. Count:     83,   Neg. LLF: 408.17567740379474
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 408.17567740379474
#             Iterations: 14
#             Function evaluations: 83
#             Gradient evaluations: 14
# ABBV: 0.609346994894404
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %% [markdown]
# # 3 months ahead

# %%
import pandas as pd
import statsmodels.api as sm
from arch import arch_model
from scipy.stats import norm

def rolling_3m_forecast(data, dates, ticker, alpha):
    t_loss = 0
    dta = data.copy()

    for d in dates:
        train_df = dta[dta.Date <= d]
        test_df = dta[dta.Date > d]
        test_df = test_df.reset_index(drop=True)

        X_train = train_df.drop(columns=[ticker, 'Date'])
        y_train = train_df[ticker]

        X_test = test_df.drop(columns=[ticker, 'Date'])
        X_test = X_test.iloc[0]
        y_test = test_df[ticker]

        garch_model = arch_model(y_train, vol='Garch', p=1, q=1)
        garch_results = garch_model.fit()

        forecasts = garch_results.forecast(start=0, horizon=3)  # Forecast for 3 months ahead
        cond_vol_forecast = forecasts.variance.iloc[-1].apply(lambda x: np.sqrt(x))
        mean_forecast = forecasts.mean.iloc[-1]

        VaR_forecast = mean_forecast + cond_vol_forecast * norm.ppf(alpha)

        loss = tick_loss(alpha, y_test.iloc[0], VaR_forecast)

        t_loss += loss

    t_loss = t_loss / 10  # Adjusted for 10 months (since 'dates3m' has 10 elements)

    return t_loss

# %%
dates3m = ['2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01']

# %%
for t in tickers:
    if t == 'ABBV':
        loss = rolling_3m_forecast(data, dates1m, t, 0.05)
        print(f'{t}: {loss}')
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 415.16727965562995
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 372.02697265857495
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 371.6563427613615
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 371.80367697607505
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 371.6562462535467
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 371.49926145709287
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 371.49708379222403
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 371.4969264728807
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 371.496903467082
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 371.49690102612215
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 371.4969010274283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 371.49690102612215
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 418.67451080163954
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 375.1585880644287
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 374.8105958017746
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 374.7866213798662
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 374.72103880978204
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 374.61413382292835
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 374.6138123456507
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 374.6137104988059
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 374.61370013748956
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 374.61369837266
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 374.61369837325896
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 374.61369837266
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 422.9131433546542
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 378.6756979601627
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 378.37390192466216
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 378.2874799307776
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 378.258475714919
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 378.12552503662175
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 378.1252091232855
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 378.12508284433756
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 378.125061362382
# Iteration:     10,   Func. Count:     55,   Neg. LLF: 378.12506136095044
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 378.125061362382
#             Iterations: 10
#             Function evaluations: 55
#             Gradient evaluations: 10
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 426.95493424949484
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 383.4850662663436
# Iteration:      3,   Func. Count:     21,   Neg. LLF: 381.62405217008256
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 381.783652233557
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 381.57256151581413
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 381.5531576553225
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 381.54274044624026
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 381.54217269031454
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 381.54215153852164
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 381.5421507032837
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 381.5421507032837
#             Iterations: 10
#             Function evaluations: 57
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 430.37301780008585
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 386.98565165072205
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 384.6971651351057
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 384.7226738077194
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 384.6865281198993
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 384.6493622327128
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 384.6477905185079
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 384.62980270290535
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 384.6297918431379
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 384.6297918433429
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 384.6297918431379
#             Iterations: 10
#             Function evaluations: 58
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 434.5194883716753
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 390.2004099484524
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 388.12712322362785
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 388.1269123835097
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 388.11975242589097
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 388.0904899285459
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 388.0960447093733
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 388.06413944570085
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 388.0640870328092
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 388.0640835343753
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 388.06408353458477
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 388.0640835343753
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 439.15733750433867
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 393.82002582033374
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 391.80931396182774
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 391.8044222064833
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 391.7931140612698
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 391.74997164743627
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 391.7437170687829
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 391.74288912204486
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 391.74262968968367
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 391.7426249096537
# Iteration:     11,   Func. Count:     61,   Neg. LLF: 391.7426249117756
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 391.7426249096537
#             Iterations: 11
#             Function evaluations: 61
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 442.5241388149222
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 396.76616908697224
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 394.86060995934656
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 395.18769558088565
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 394.8504135908757
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 394.81870808026287
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 394.8142520956877
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 394.80889382403376
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 394.80865413687184
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 394.8086408233469
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 394.808632903825
# Iteration:     12,   Func. Count:     67,   Neg. LLF: 394.8086329038789
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 394.808632903825
#             Iterations: 12
#             Function evaluations: 67
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 447.4472767039716
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 400.7812345613748
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 398.672221390379
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 398.67996738143006
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 398.6665481610421
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 398.6411640509694
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 398.64432220821226
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 398.6117271981704
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 398.61166438709944
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 398.61166089087925
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 398.61166089122696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 398.61166089087925
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 450.9472781410528
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 403.73799268412455
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 401.78890673150744
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 402.130877017702
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 401.7763192887182
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 401.7442447620445
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 401.7412470578716
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 401.7404413869029
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 401.74042138861677
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 401.74041997107025
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 401.7404191945482
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 401.7404191945482
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 461.3234811636654
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 405.39400857157244
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 406.7657447619852
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 405.5795685126503
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 405.4915905205244
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 419.81478330082274
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 405.1616385819366
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 404.8496507462971
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 405.1914082181492
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 404.96148181777
# Iteration:     11,   Func. Count:     66,   Neg. LLF: 404.79732482000725
# Iteration:     12,   Func. Count:     71,   Neg. LLF: 404.7972449436512
# Iteration:     13,   Func. Count:     76,   Neg. LLF: 404.7972439877279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 404.7972439877279
#             Iterations: 13
#             Function evaluations: 76
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 465.53475176011074
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 408.75924925399136
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 409.9630436766014
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 408.92807392261375
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 408.88262419345847
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 520.0275825778482
# Iteration:      7,   Func. Count:     44,   Neg. LLF: 408.6553909492625
# Iteration:      8,   Func. Count:     50,   Neg. LLF: 408.4414990412284
# Iteration:      9,   Func. Count:     56,   Neg. LLF: 410.1947057912603
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 408.18628676754753
# Iteration:     11,   Func. Count:     67,   Neg. LLF: 408.2215337020183
# Iteration:     12,   Func. Count:     73,   Neg. LLF: 408.1758265736322
# Iteration:     13,   Func. Count:     78,   Neg. LLF: 408.17567811170653
# Iteration:     14,   Func. Count:     83,   Neg. LLF: 408.17567740379474
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 408.17567740379474
#             Iterations: 14
#             Function evaluations: 83
#             Gradient evaluations: 14
# ABBV: 2.1960859869749116
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %% [markdown]
# # 6 months ahead

# %%
import pandas as pd
import statsmodels.api as sm
from arch import arch_model
from scipy.stats import norm

def rolling_6m_forecast(data, dates, ticker, alpha):
    t_loss = 0
    dta = data.copy()

    for d in dates:
        train_df = dta[dta.Date <= d]
        test_df = dta[dta.Date > d]
        test_df = test_df.reset_index(drop=True)

        X_train = train_df.drop(columns=[ticker, 'Date'])
        y_train = train_df[ticker]

        X_test = test_df.drop(columns=[ticker, 'Date'])
        X_test = X_test.iloc[0]
        y_test = test_df[ticker]

        garch_model = arch_model(y_train, vol='Garch', p=1, q=1)
        garch_results = garch_model.fit()

        forecasts = garch_results.forecast(start=0, horizon=6)  # Forecast for 6 months ahead
        cond_vol_forecast = forecasts.variance.iloc[-1].apply(lambda x: np.sqrt(x))
        mean_forecast = forecasts.mean.iloc[-1]

        VaR_forecast = mean_forecast + cond_vol_forecast * norm.ppf(alpha)

        loss = tick_loss(alpha, y_test.iloc[0], VaR_forecast)

        t_loss += loss

    t_loss = t_loss / 7  # Adjusted for 7 months (since 'dates6m' has 7 elements)

    return t_loss

# %%
dates6m = ['2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01']

# %%
for t in tickers:
    if t == 'ABBV':
        loss = rolling_6m_forecast(data, dates1m, t, 0.05)
        print(f'{t}: {loss}')
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 415.16727965562995
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 372.02697265857495
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 371.6563427613615
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 371.80367697607505
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 371.6562462535467
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 371.49926145709287
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 371.49708379222403
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 371.4969264728807
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 371.496903467082
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 371.49690102612215
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 371.4969010274283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 371.49690102612215
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 418.67451080163954
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 375.1585880644287
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 374.8105958017746
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 374.7866213798662
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 374.72103880978204
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 374.61413382292835
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 374.6138123456507
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 374.6137104988059
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 374.61370013748956
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 374.61369837266
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 374.61369837325896
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 374.61369837266
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 422.9131433546542
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 378.6756979601627
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 378.37390192466216
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 378.2874799307776
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 378.258475714919
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 378.12552503662175
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 378.1252091232855
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 378.12508284433756
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 378.125061362382
# Iteration:     10,   Func. Count:     55,   Neg. LLF: 378.12506136095044
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 378.125061362382
#             Iterations: 10
#             Function evaluations: 55
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 426.95493424949484
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 383.4850662663436
# Iteration:      3,   Func. Count:     21,   Neg. LLF: 381.62405217008256
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 381.783652233557
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 381.57256151581413
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 381.5531576553225
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 381.54274044624026
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 381.54217269031454
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 381.54215153852164
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 381.5421507032837
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 381.5421507032837
#             Iterations: 10
#             Function evaluations: 57
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 430.37301780008585
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 386.98565165072205
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 384.6971651351057
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 384.7226738077194
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 384.6865281198993
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 384.6493622327128
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 384.6477905185079
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 384.62980270290535
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 384.6297918431379
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 384.6297918433429
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 384.6297918431379
#             Iterations: 10
#             Function evaluations: 58
#             Gradient evaluations: 10
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 434.5194883716753
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 390.2004099484524
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 388.12712322362785
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 388.1269123835097
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 388.11975242589097
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 388.0904899285459
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 388.0960447093733
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 388.06413944570085
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 388.0640870328092
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 388.0640835343753
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 388.06408353458477
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 388.0640835343753
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 439.15733750433867
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 393.82002582033374
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 391.80931396182774
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 391.8044222064833
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 391.7931140612698
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 391.74997164743627
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 391.7437170687829
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 391.74288912204486
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 391.74262968968367
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 391.7426249096537
# Iteration:     11,   Func. Count:     61,   Neg. LLF: 391.7426249117756
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 391.7426249096537
#             Iterations: 11
#             Function evaluations: 61
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 442.5241388149222
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 396.76616908697224
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 394.86060995934656
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 395.18769558088565
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 394.8504135908757
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 394.81870808026287
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 394.8142520956877
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 394.80889382403376
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 394.80865413687184
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 394.8086408233469
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 394.808632903825
# Iteration:     12,   Func. Count:     67,   Neg. LLF: 394.8086329038789
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 394.808632903825
#             Iterations: 12
#             Function evaluations: 67
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 447.4472767039716
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 400.7812345613748
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 398.672221390379
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 398.67996738143006
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 398.6665481610421
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 398.6411640509694
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 398.64432220821226
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 398.6117271981704
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 398.61166438709944
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 398.61166089087925
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 398.61166089122696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 398.61166089087925
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 450.9472781410528
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 403.73799268412455
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 401.78890673150744
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 402.130877017702
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 401.7763192887182
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 401.7442447620445
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 401.7412470578716
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 401.7404413869029
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 401.74042138861677
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 401.74041997107025
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 401.7404191945482
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 401.7404191945482
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 461.3234811636654
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 405.39400857157244
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 406.7657447619852
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 405.5795685126503
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 405.4915905205244
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 419.81478330082274
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 405.1616385819366
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 404.8496507462971
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 405.1914082181492
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 404.96148181777
# Iteration:     11,   Func. Count:     66,   Neg. LLF: 404.79732482000725
# Iteration:     12,   Func. Count:     71,   Neg. LLF: 404.7972449436512
# Iteration:     13,   Func. Count:     76,   Neg. LLF: 404.7972439877279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 404.7972439877279
#             Iterations: 13
#             Function evaluations: 76
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 465.53475176011074
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 408.75924925399136
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 409.9630436766014
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 408.92807392261375
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 408.88262419345847
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 520.0275825778482
# Iteration:      7,   Func. Count:     44,   Neg. LLF: 408.6553909492625
# Iteration:      8,   Func. Count:     50,   Neg. LLF: 408.4414990412284
# Iteration:      9,   Func. Count:     56,   Neg. LLF: 410.1947057912603
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 408.18628676754753
# Iteration:     11,   Func. Count:     67,   Neg. LLF: 408.2215337020183
# Iteration:     12,   Func. Count:     73,   Neg. LLF: 408.1758265736322
# Iteration:     13,   Func. Count:     78,   Neg. LLF: 408.17567811170653
# Iteration:     14,   Func. Count:     83,   Neg. LLF: 408.17567740379474
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 408.17567740379474
#             Iterations: 14
#             Function evaluations: 83
#             Gradient evaluations: 14
# ABBV: 6.284770243680566
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %% [markdown]
# # 9 months ahead

# %%
import pandas as pd
import statsmodels.api as sm
from arch import arch_model
from scipy.stats import norm

def rolling_9m_forecast(data, dates, ticker, alpha):
    t_loss = 0
    dta = data.copy()

    for d in dates:
        train_df = dta[dta.Date <= d]
        test_df = dta[dta.Date > d]
        test_df = test_df.reset_index(drop=True)

        X_train = train_df.drop(columns=[ticker, 'Date'])
        y_train = train_df[ticker]

        X_test = test_df.drop(columns=[ticker, 'Date'])
        X_test = X_test.iloc[0]
        y_test = test_df[ticker]

        garch_model = arch_model(y_train, vol='Garch', p=1, q=1)
        garch_results = garch_model.fit()

        forecasts = garch_results.forecast(start=0, horizon=9)  # Forecast for 9 months ahead
        cond_vol_forecast = forecasts.variance.iloc[-1].apply(lambda x: np.sqrt(x))
        mean_forecast = forecasts.mean.iloc[-1]

        VaR_forecast = mean_forecast + cond_vol_forecast * norm.ppf(alpha)

        loss = tick_loss(alpha, y_test.iloc[0], VaR_forecast)

        t_loss += loss

    t_loss = t_loss / 4  # Adjusted for 4 months (since 'dates9m' has 4 elements)

    return t_loss

# %%
dates9m = ['2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01']

# %%
for t in tickers:
    if t == 'ABBV':
        loss = rolling_9m_forecast(data, dates1m, t, 0.05)
        print(f'{t}: {loss}')
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 415.16727965562995
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 372.02697265857495
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 371.6563427613615
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 371.80367697607505
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 371.6562462535467
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 371.49926145709287
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 371.49708379222403
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 371.4969264728807
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 371.496903467082
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 371.49690102612215
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 371.4969010274283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 371.49690102612215
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 418.67451080163954
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 375.1585880644287
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 374.8105958017746
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 374.7866213798662
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 374.72103880978204
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 374.61413382292835
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 374.6138123456507
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 374.6137104988059
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 374.61370013748956
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 374.61369837266
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 374.61369837325896
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 374.61369837266
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 422.9131433546542
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 378.6756979601627
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 378.37390192466216
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 378.2874799307776
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 378.258475714919
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 378.12552503662175
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 378.1252091232855
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 378.12508284433756
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 378.125061362382
# Iteration:     10,   Func. Count:     55,   Neg. LLF: 378.12506136095044
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 378.125061362382
#             Iterations: 10
#             Function evaluations: 55
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 426.95493424949484
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 383.4850662663436
# Iteration:      3,   Func. Count:     21,   Neg. LLF: 381.62405217008256
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 381.783652233557
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 381.57256151581413
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 381.5531576553225
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 381.54274044624026
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 381.54217269031454
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 381.54215153852164
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 381.5421507032837
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 381.5421507032837
#             Iterations: 10
#             Function evaluations: 57
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 430.37301780008585
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 386.98565165072205
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 384.6971651351057
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 384.7226738077194
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 384.6865281198993
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 384.6493622327128
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 384.6477905185079
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 384.62980270290535
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 384.6297918431379
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 384.6297918433429
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 384.6297918431379
#             Iterations: 10
#             Function evaluations: 58
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 434.5194883716753
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 390.2004099484524
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 388.12712322362785
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 388.1269123835097
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 388.11975242589097
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 388.0904899285459
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 388.0960447093733
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 388.06413944570085
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 388.0640870328092
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 388.0640835343753
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 388.06408353458477
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 388.0640835343753
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 439.15733750433867
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 393.82002582033374
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 391.80931396182774
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 391.8044222064833
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 391.7931140612698
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 391.74997164743627
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 391.7437170687829
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 391.74288912204486
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 391.74262968968367
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 391.7426249096537
# Iteration:     11,   Func. Count:     61,   Neg. LLF: 391.7426249117756
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 391.7426249096537
#             Iterations: 11
#             Function evaluations: 61
#             Gradient evaluations: 11
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 442.5241388149222
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 396.76616908697224
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 394.86060995934656
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 395.18769558088565
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 394.8504135908757
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 394.81870808026287
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 394.8142520956877
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 394.80889382403376
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 394.80865413687184
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 394.8086408233469
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 394.808632903825
# Iteration:     12,   Func. Count:     67,   Neg. LLF: 394.8086329038789
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 394.808632903825
#             Iterations: 12
#             Function evaluations: 67
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 447.4472767039716
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 400.7812345613748
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 398.672221390379
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 398.67996738143006
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 398.6665481610421
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 398.6411640509694
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 398.64432220821226
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 398.6117271981704
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 398.61166438709944
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 398.61166089087925
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 398.61166089122696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 398.61166089087925
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 450.9472781410528
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 403.73799268412455
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 401.78890673150744
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 402.130877017702
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 401.7763192887182
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 401.7442447620445
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 401.7412470578716
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 401.7404413869029
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 401.74042138861677
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 401.74041997107025
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 401.7404191945482
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 401.7404191945482
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 461.3234811636654
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 405.39400857157244
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 406.7657447619852
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 405.5795685126503
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 405.4915905205244
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 419.81478330082274
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 405.1616385819366
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 404.8496507462971
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 405.1914082181492
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 404.96148181777
# Iteration:     11,   Func. Count:     66,   Neg. LLF: 404.79732482000725
# Iteration:     12,   Func. Count:     71,   Neg. LLF: 404.7972449436512
# Iteration:     13,   Func. Count:     76,   Neg. LLF: 404.7972439877279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 404.7972439877279
#             Iterations: 13
#             Function evaluations: 76
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 465.53475176011074
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 408.75924925399136
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 409.9630436766014
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 408.92807392261375
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 408.88262419345847
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 520.0275825778482
# Iteration:      7,   Func. Count:     44,   Neg. LLF: 408.6553909492625
# Iteration:      8,   Func. Count:     50,   Neg. LLF: 408.4414990412284
# Iteration:      9,   Func. Count:     56,   Neg. LLF: 410.1947057912603
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 408.18628676754753
# Iteration:     11,   Func. Count:     67,   Neg. LLF: 408.2215337020183
# Iteration:     12,   Func. Count:     73,   Neg. LLF: 408.1758265736322
# Iteration:     13,   Func. Count:     78,   Neg. LLF: 408.17567811170653
# Iteration:     14,   Func. Count:     83,   Neg. LLF: 408.17567740379474
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 408.17567740379474
#             Iterations: 14
#             Function evaluations: 83
#             Gradient evaluations: 14
# ABBV: 16.523772150583902
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %% [markdown]
# # 12 months ahead

# %%
import pandas as pd
import statsmodels.api as sm
from arch import arch_model
from scipy.stats import norm

def rolling_12m_forecast(data, dates, ticker, alpha):
    t_loss = 0
    dta = data.copy()

    for d in dates:
        train_df = dta[dta.Date <= d]
        test_df = dta[dta.Date > d]
        test_df = test_df.reset_index(drop=True)

        X_train = train_df.drop(columns=[ticker, 'Date'])
        y_train = train_df[ticker]

        X_test = test_df.drop(columns=[ticker, 'Date'])
        X_test = X_test.iloc[0]
        y_test = test_df[ticker]

        garch_model = arch_model(y_train, vol='Garch', p=1, q=1)
        garch_results = garch_model.fit()

        forecasts = garch_results.forecast(start=0, horizon=12)  # Forecast for 12 months ahead
        cond_vol_forecast = forecasts.variance.iloc[-1].apply(lambda x: np.sqrt(x))
        mean_forecast = forecasts.mean.iloc[-1]

        VaR_forecast = mean_forecast + cond_vol_forecast * norm.ppf(alpha)

        loss = tick_loss(alpha, y_test.iloc[0], VaR_forecast)

        t_loss += loss

    t_loss = t_loss / len(dates)  # Adjusted for the number of months in 'dates12m'

    return t_loss

# %%
dates12m = ['2022-05-01']

# %%
for t in tickers:
    if t == 'ABBV':
        loss = rolling_12m_forecast(data, dates1m, t, 0.05)
        print(f'{t}: {loss}')
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 415.16727965562995
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 372.02697265857495
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 371.6563427613615
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 371.80367697607505
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 371.6562462535467
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 371.49926145709287
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 371.49708379222403
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 371.4969264728807
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 371.496903467082
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 371.49690102612215
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 371.4969010274283
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 371.49690102612215
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 418.67451080163954
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 375.1585880644287
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 374.8105958017746
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 374.7866213798662
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 374.72103880978204
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 374.61413382292835
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 374.6138123456507
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 374.6137104988059
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 374.61370013748956
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 374.61369837266
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 374.61369837325896
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 374.61369837266
#             Iterations: 11
#             Function evaluations: 60
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 422.9131433546542
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 378.6756979601627
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 378.37390192466216
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 378.2874799307776
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 378.258475714919
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 378.12552503662175
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 378.1252091232855
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 378.12508284433756
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 378.125061362382
# Iteration:     10,   Func. Count:     55,   Neg. LLF: 378.12506136095044
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 378.125061362382
#             Iterations: 10
#             Function evaluations: 55
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 426.95493424949484
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 383.4850662663436
# Iteration:      3,   Func. Count:     21,   Neg. LLF: 381.62405217008256
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 381.783652233557
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 381.57256151581413
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 381.5531576553225
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 381.54274044624026
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 381.54217269031454
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 381.54215153852164
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 381.5421507032837
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 381.5421507032837
#             Iterations: 10
#             Function evaluations: 57
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 430.37301780008585
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 386.98565165072205
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 384.6971651351057
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 384.7226738077194
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 384.6865281198993
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 384.6493622327128
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 384.6477905185079
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 384.62980270290535
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 384.6297918431379
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 384.6297918433429
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 384.6297918431379
#             Iterations: 10
#             Function evaluations: 58
#             Gradient evaluations: 10
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 434.5194883716753
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 390.2004099484524
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 388.12712322362785
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 388.1269123835097
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 388.11975242589097
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 388.0904899285459
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 388.0960447093733
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 388.06413944570085
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 388.0640870328092
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 388.0640835343753
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 388.06408353458477
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 388.0640835343753
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 439.15733750433867
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 393.82002582033374
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 391.80931396182774
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 391.8044222064833
# Iteration:      5,   Func. Count:     32,   Neg. LLF: 391.7931140612698
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 391.74997164743627
# Iteration:      7,   Func. Count:     42,   Neg. LLF: 391.7437170687829
# Iteration:      8,   Func. Count:     47,   Neg. LLF: 391.74288912204486
# Iteration:      9,   Func. Count:     52,   Neg. LLF: 391.74262968968367
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 391.7426249096537
# Iteration:     11,   Func. Count:     61,   Neg. LLF: 391.7426249117756
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 391.7426249096537
#             Iterations: 11
#             Function evaluations: 61
#             Gradient evaluations: 11
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 442.5241388149222
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 396.76616908697224
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 394.86060995934656
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 395.18769558088565
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 394.8504135908757
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 394.81870808026287
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 394.8142520956877
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 394.80889382403376
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 394.80865413687184
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 394.8086408233469
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 394.808632903825
# Iteration:     12,   Func. Count:     67,   Neg. LLF: 394.8086329038789
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 394.808632903825
#             Iterations: 12
#             Function evaluations: 67
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 447.4472767039716
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 400.7812345613748
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 398.672221390379
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 398.67996738143006
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 398.6665481610421
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 398.6411640509694
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 398.64432220821226
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 398.6117271981704
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 398.61166438709944
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 398.61166089087925
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 398.61166089122696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 398.61166089087925
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 450.9472781410528
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 403.73799268412455
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 401.78890673150744
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 402.130877017702
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 401.7763192887182
# Iteration:      6,   Func. Count:     38,   Neg. LLF: 401.7442447620445
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 401.7412470578716
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 401.7404413869029
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 401.74042138861677
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 401.74041997107025
# Iteration:     11,   Func. Count:     63,   Neg. LLF: 401.7404191945482
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 401.7404191945482
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 461.3234811636654
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 405.39400857157244
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 406.7657447619852
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 405.5795685126503
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 405.4915905205244
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 419.81478330082274
# Iteration:      7,   Func. Count:     43,   Neg. LLF: 405.1616385819366
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 404.8496507462971
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 405.1914082181492
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 404.96148181777
# Iteration:     11,   Func. Count:     66,   Neg. LLF: 404.79732482000725
# Iteration:     12,   Func. Count:     71,   Neg. LLF: 404.7972449436512
# Iteration:     13,   Func. Count:     76,   Neg. LLF: 404.7972439877279
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 404.7972439877279
#             Iterations: 13
#             Function evaluations: 76
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 465.53475176011074
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 408.75924925399136
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 409.9630436766014
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 408.92807392261375
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 408.88262419345847
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 520.0275825778482
# Iteration:      7,   Func. Count:     44,   Neg. LLF: 408.6553909492625
# Iteration:      8,   Func. Count:     50,   Neg. LLF: 408.4414990412284
# Iteration:      9,   Func. Count:     56,   Neg. LLF: 410.1947057912603
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 408.18628676754753
# Iteration:     11,   Func. Count:     67,   Neg. LLF: 408.2215337020183
# Iteration:     12,   Func. Count:     73,   Neg. LLF: 408.1758265736322
# Iteration:     13,   Func. Count:     78,   Neg. LLF: 408.17567811170653
# Iteration:     14,   Func. Count:     83,   Neg. LLF: 408.17567740379474
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 408.17567740379474
#             Iterations: 14
#             Function evaluations: 83
#             Gradient evaluations: 14
# ABBV: 7.355295535201958
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/arch/__future__/_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
