# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('merged_df.csv')
df
# Out:
#            Date       ABBV  unemployment_rate      CPI  treasury_yield  \
# 0    2013-03-01  10.455062                7.5  232.282        1.984211
# 1    2013-04-01  12.922975                7.6  231.797        1.957500
# 2    2013-05-01  -6.438455                7.5  231.893        1.759091
# 3    2013-06-01  -3.162299                7.5  232.445        1.928182
# 4    2013-07-01  10.014486                7.3  232.900        2.300000
# ..          ...        ...                ...      ...             ...
# 118  2023-01-01  -8.576205                3.4  300.536        3.616190
# 119  2023-02-01   5.152609                3.6  301.648        3.531500
# 120  2023-03-01   3.554254                3.5  301.808        3.746842
# 121  2023-04-01  -5.176628                3.4  302.918        3.663043
# 122  2023-05-01  -7.868480                3.7  304.127        3.460000
#
#      GDP_growth  SP500_return        AZN        BMY       JNJ        LLY  \
# ...

# %%
tickers = ['ABBV', 'AZN', 'BMY', 'JNJ', 'LLY', 'MRK', 'NVO', 'NVS', 'PFE', 'ROG']

# %%
data = df[tickers]
data
# Out:
#           ABBV        AZN        BMY       JNJ        LLY       MRK  \
# 0    10.455062  14.582205  11.414669  7.978126   4.851792  3.440210
# 1    12.922975   3.881563  -3.568848  4.538222  -2.482836  7.359867
# 2    -6.438455  -1.290451  16.816781 -1.231989  -4.008663 -0.638313
# 3    -3.162299  -7.707318  -2.868894  2.762464  -6.788137 -0.535372
# 4    10.014486   7.230424  -3.244595  8.898141   8.122938  4.655361
# ..         ...        ...        ...       ...        ...       ...
# 118  -8.576205  -3.584079   0.972908 -7.489384  -5.928822 -2.549213
# 119   5.152609  -0.290649  -4.328217 -6.217115  -9.568502 -1.089288
# 120   3.554254   8.035329   0.507544  1.862736  10.703390  0.141189
# 121  -5.176628   5.489119  -3.664707  5.612908  15.269915  9.289214
# 122  -7.868480  -0.191204  -2.695194 -5.277949   8.487855 -4.382088
#
#            NVO        NVS        PFE        ROG
# 0    -7.714279   9.067089   5.443922  -0.188640
# 1    11.497419   3.537347   0.727651 -10.457790
# ...

# %%
data = data.tail(12)
data
# Out:
#           ABBV        AZN        BMY       JNJ        LLY        MRK  \
# 111   3.928904  -0.616736   2.054343 -0.489803   3.791026  -0.934478
# 112  -6.300610   0.242173  -3.516240 -1.684398   1.683984  -1.205267
# 113  -5.429779  -5.813079  -8.633766 -7.552151  -8.632348  -4.454882
# 114  -0.185920 -11.466275   5.459121  1.932340   7.693656   0.890348
# 115   9.082759   7.239243   8.974528  6.494844  11.980826  18.457777
# 116  11.215906  15.575584   4.416367  2.316498   2.482801   8.814239
# 117   0.266786  -0.250105 -10.376181 -0.117873  -1.137072   0.753719
# 118  -8.576205  -3.584079   0.972908 -7.489384  -5.928822  -2.549213
# 119   5.152609  -0.290649  -4.328217 -6.217115  -9.568502  -1.089288
# 120   3.554254   8.035329   0.507544  1.862736  10.703390   0.141189
# 121  -5.176628   5.489119  -3.664707  5.612908  15.269915   9.289214
# 122  -7.868480  -0.191204  -2.695194 -5.277949   8.487855  -4.382088
#
#            NVO        NVS        PFE        ROG
# ...

# %%
for t in tickers:
    print(f'{t}-sd: {data[t].std()} \n')
# Out:
# ABBV-sd: 6.704474047760337
#
# AZN-sd: 7.0789798892830404
#
# BMY-sd: 5.716788526776997
#
# JNJ-sd: 4.858019609940673
#
# LLY-sd: 8.176359309922105
#
# MRK-sd: 6.796918513370569
#
# NVO-sd: 7.192472210372312
#
# NVS-sd: 8.010130041772161
#
# PFE-sd: 6.308345956880249
#
# ROG-sd: 17.672072524236967
