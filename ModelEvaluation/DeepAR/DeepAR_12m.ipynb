# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# ! pip install mxnet
# ! pip install gluonts

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from datetime import datetime
from gluonts.dataset.pandas import PandasDataset
from gluonts.dataset.split import split
from gluonts.mx import DeepAREstimator, Trainer #, TrainerCallback, EarlyStoppingCallback
from gluonts.dataset.common import ListDataset
# Out:
# /usr/local/lib/python3.10/dist-packages/gluonts/json.py:101: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
np.random.seed(42)
random.seed(42)

data = pd.read_csv('/content/gdrive/MyDrive/Thesis/DeepAR/clean_monthly_data.csv')
data
# Out:
#            Date  unemployment_rate      CPI  treasury_yield  GDP_growth  \
# 0    2000-02-01                4.1  170.000        6.661000    0.496560
# 1    2000-03-01                4.0  171.000        6.519500    0.511258
# 2    2000-04-01                3.8  170.900        6.256522    1.327803
# 3    2000-05-01                4.0  171.200        5.990526   -0.181797
# 4    2000-06-01                4.0  172.200        6.440455    0.305565
# ..          ...                ...      ...             ...         ...
# 275  2023-01-01                3.4  300.536        3.616190    0.390254
# 276  2023-02-01                3.6  301.648        3.531500   -0.442183
# 277  2023-03-01                3.5  301.808        3.746842   -0.442183
# 278  2023-04-01                3.4  302.918        3.663043   -0.442183
# 279  2023-05-01                3.7  304.127        3.460000   -0.442183
#
#      SP500_return        AZN        BMY        JNJ        LLY        MRK  \
# 0       -1.522563 -12.828964 -13.228004 -16.339821 -11.121498 -21.701151
# 1        9.413333  22.264136  -0.218329  -2.079067   5.804243   0.913712
# 2       -3.266805   5.567379  -8.205683  17.437698  23.153694  12.400712
# 3       -1.572223  -0.148357   5.395746   8.484832  -1.296597   7.374072
# 4        1.728613  10.549735   5.788826  14.239888  31.641749   3.078671
# ..            ...        ...        ...        ...        ...        ...
# 275      6.776820  -3.584079   0.972908  -7.489384  -5.928822  -2.549213
# 276     -2.514271  -0.290649  -4.328217  -6.217115  -9.568502  -1.089288
# 277      3.313488   8.035329   0.507544   1.862736  10.703390   0.141189
# 278      1.985238   5.489119  -3.664707   5.612908  15.269915   9.289214
# 279      0.461619  -0.191204  -2.695194  -5.277949   8.487855  -4.382088
#
#            NVO        NVS        PFE        ROG  inflation_change  \
# 0     2.220031   3.838386 -11.226228  54.440789             1.000
# 1     8.390897   6.420237  14.101954   6.922258             1.000
# 2    -0.097663   2.559423  15.213674   7.370518            -0.100
# 3    20.863985   5.169310   5.638019  -8.163265             0.300
# 4     2.813690   8.474599   8.076012  13.131313             1.000
# ..         ...        ...        ...        ...               ...
# 275   2.541749  -0.110227 -13.817335  16.968326             1.546
# 276   1.592445  -7.172811  -7.286115   5.451681             1.112
# 277  12.873250   9.367574   0.566924  11.025813             0.160
# 278   5.836894  16.334413  -4.681371  -1.517467             1.110
# 279  -3.967915  -6.161645  -2.237080  -2.162160             0.100
#
#      unemp_change  treasury_yield_change
# 0            -0.1              -0.141500
# 1            -0.1              -0.141500
# 2            -0.2              -0.262978
# 3             0.2              -0.265995
# 4             0.0               0.449928
# ..            ...                    ...
# 275          -0.1              -0.274810
# 276           0.2              -0.084690
# 277          -0.1               0.215342
# 278          -0.1              -0.083799
# 279           0.3              -0.203043
#
# [280 rows x 18 columns]

# %%
def format(df):
  df = df.set_index('Date')
  return df

# %% [markdown]
# MACRO

# %%
macro = data.copy()

for m in ['GDP_growth',	'SP500_return',	'inflation_change',	'unemp_change',	'treasury_yield_change']:
  macro[f'{m}_lag'] = macro[m].shift(1)
  macro[f'{m}_lag2'] = macro[m].shift(2)
  macro[f'{m}_lag3'] = macro[m].shift(3)


macro['Quater_dummy'] = 0
macro['Quater_rippel'] = 0
macro['Date'] = pd.to_datetime(macro['Date'])
for index, row in macro.iterrows():
    date = pd.to_datetime(row['Date'])  # Convert the date string to datetime type
    if date.month in [3, 6, 9, 12]:
        macro.loc[index, 'Quater_dummy'] = 1
    if date.month in [1, 4, 7, 10]:
        macro.loc[index, 'Quater_rippel'] = 1

macro = format(macro)

# %%
macro
# Out:
#             unemployment_rate      CPI  treasury_yield  GDP_growth  \
# Date
# 2000-02-01                4.1  170.000        6.661000    0.496560
# 2000-03-01                4.0  171.000        6.519500    0.511258
# 2000-04-01                3.8  170.900        6.256522    1.327803
# 2000-05-01                4.0  171.200        5.990526   -0.181797
# 2000-06-01                4.0  172.200        6.440455    0.305565
# ...                       ...      ...             ...         ...
# 2023-01-01                3.4  300.536        3.616190    0.390254
# 2023-02-01                3.6  301.648        3.531500   -0.442183
# 2023-03-01                3.5  301.808        3.746842   -0.442183
# 2023-04-01                3.4  302.918        3.663043   -0.442183
# 2023-05-01                3.7  304.127        3.460000   -0.442183
#
#             SP500_return        AZN        BMY        JNJ        LLY  \
# Date
# 2000-02-01     -1.522563 -12.828964 -13.228004 -16.339821 -11.121498
# 2000-03-01      9.413333  22.264136  -0.218329  -2.079067   5.804243
# 2000-04-01     -3.266805   5.567379  -8.205683  17.437698  23.153694
# 2000-05-01     -1.572223  -0.148357   5.395746   8.484832  -1.296597
# 2000-06-01      1.728613  10.549735   5.788826  14.239888  31.641749
# ...                  ...        ...        ...        ...        ...
# 2023-01-01      6.776820  -3.584079   0.972908  -7.489384  -5.928822
# 2023-02-01     -2.514271  -0.290649  -4.328217  -6.217115  -9.568502
# 2023-03-01      3.313488   8.035329   0.507544   1.862736  10.703390
# 2023-04-01      1.985238   5.489119  -3.664707   5.612908  15.269915
# 2023-05-01      0.461619  -0.191204  -2.695194  -5.277949   8.487855
#
#                   MRK  ...  inflation_change_lag2  inflation_change_lag3  \
# Date                   ...
# 2000-02-01 -21.701151  ...                    NaN                    NaN
# 2000-03-01   0.913712  ...                    NaN                    NaN
# 2000-04-01  12.400712  ...                  1.000                    NaN
# 2000-05-01   7.374072  ...                  1.000                  1.000
# 2000-06-01   3.078671  ...                 -0.100                  1.000
# ...               ...  ...                    ...                    ...
# 2023-01-01  -2.549213  ...                  0.611                  1.448
# 2023-02-01  -1.089288  ...                  0.392                  0.611
# 2023-03-01   0.141189  ...                  1.546                  0.392
# 2023-04-01   9.289214  ...                  1.112                  1.546
# 2023-05-01  -4.382088  ...                  0.160                  1.112
#
#             unemp_change_lag  unemp_change_lag2  unemp_change_lag3  \
# Date
# 2000-02-01               NaN                NaN                NaN
# 2000-03-01              -0.1                NaN                NaN
# 2000-04-01              -0.1               -0.1                NaN
# 2000-05-01              -0.2               -0.1               -0.1
# 2000-06-01               0.2               -0.2               -0.1
# ...                      ...                ...                ...
# 2023-01-01              -0.1               -0.1                0.2
# 2023-02-01              -0.1               -0.1               -0.1
# 2023-03-01               0.2               -0.1               -0.1
# 2023-04-01              -0.1                0.2               -0.1
# 2023-05-01              -0.1               -0.1                0.2
#
#             treasury_yield_change_lag  treasury_yield_change_lag2  \
# Date
# 2000-02-01                        NaN                         NaN
# 2000-03-01                  -0.141500                         NaN
# 2000-04-01                  -0.141500                   -0.141500
# 2000-05-01                  -0.262978                   -0.141500
# 2000-06-01                  -0.265995                   -0.262978
# ...                               ...                         ...
# 2023-01-01                  -0.092500                    0.464452
# 2023-02-01                  -0.274810                   -0.092500
# 2023-03-01                  -0.084690                   -0.274810
# 2023-04-01                   0.215342                   -0.084690
# 2023-05-01                  -0.083799                    0.215342
#
#             treasury_yield_change_lag3  Quater_dummy  Quater_rippel
# Date
# 2000-02-01                         NaN             0              0
# 2000-03-01                         NaN             1              0
# 2000-04-01                         NaN             0              1
# 2000-05-01                   -0.141500             0              0
# 2000-06-01                   -0.141500             1              0
# ...                                ...           ...            ...
# 2023-01-01                    0.621222             0              1
# 2023-02-01                    0.464452             0              0
# 2023-03-01                   -0.092500             1              0
# 2023-04-01                   -0.274810             0              1
# 2023-05-01                   -0.084690             0              0
#
# [280 rows x 34 columns]

# %%
def data_prep(df, ticker):
    train_data = ListDataset(
        [
            {
                "start": df.index[0],
                "target": df[ticker].values,
                "dynamic_feat": [
                              df['GDP_growth_lag'].values,
                              df['GDP_growth_lag2'].values,
                              df['GDP_growth_lag3'].values,
                              df['SP500_return_lag'].values,
                              df['SP500_return_lag2'].values,
                              df['SP500_return_lag3'].values,
                              df['inflation_change_lag'].values,
                              df['inflation_change_lag2'].values,
                              df['inflation_change_lag3'].values,
                              df['unemp_change_lag'].values,
                              df['unemp_change_lag2'].values,
                              df['unemp_change_lag3'].values,
                              df['treasury_yield_change_lag'].values,
                              df['treasury_yield_change_lag2'].values,
                              df['treasury_yield_change_lag3'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    test_data = ListDataset(
        [
            {
                "start": df.index[-12],
                "target": df[ticker][-12:].values,
                "dynamic_feat": [
                              df['GDP_growth_lag'].values,
                              df['GDP_growth_lag2'].values,
                              df['GDP_growth_lag3'].values,
                              df['SP500_return_lag'].values,
                              df['SP500_return_lag2'].values,
                              df['SP500_return_lag3'].values,
                              df['inflation_change_lag'].values,
                              df['inflation_change_lag2'].values,
                              df['inflation_change_lag3'].values,
                              df['unemp_change_lag'].values,
                              df['unemp_change_lag2'].values,
                              df['unemp_change_lag3'].values,
                              df['treasury_yield_change_lag'].values,
                              df['treasury_yield_change_lag2'].values,
                              df['treasury_yield_change_lag3'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    return train_data, test_data

# %%
hyperparameters = {
    "prediction_length": 12,
    "context_length": 15,
    "num_cells": 10,
    "num_layers": 2,
    "dropout_rate": 0.1,
    "batch_size": 1,
    "likelihood": "gaussian",
    "hybridize": True
}

# %%
estimator = DeepAREstimator(
    prediction_length = hyperparameters["prediction_length"],
    context_length = hyperparameters["context_length"],
    num_cells = hyperparameters["num_cells"],
    num_layers = hyperparameters["num_layers"],
    dropout_rate = hyperparameters["dropout_rate"],
    batch_size = hyperparameters["batch_size"],
    freq = "M",
    trainer = Trainer(epochs = 30)
    )

# %%
def fit_n_predict(model, training, test):
  predictor = model.train(training)
  predictor = next(predictor.predict(test))
  samples = predictor.samples
  time = predictor.index
  return samples, time

# %%
def tick_loss(alpha, returns, var):
    df = pd.DataFrame({'Return': returns, 'VaR': var})
    df['Indicator'] = np.where(df['Return'] < df['VaR'], 1, 0)
    #print(df)

    t_loss = 0

    for i in df.index:
        t_loss += (alpha * (df['Return'][i] - df['VaR'][i]) * (1 - df['Indicator'][i]) +
                 (1 - alpha) * (df['VaR'][i] - df['Return'][i]) * df['Indicator'][i])

    return t_loss

# %%
dates12m = ['2022-05-01']

# %%
def get_performance(ticker, dates):

  dta = macro.copy()
  t_loss = 0

  for d in dates:
    split_date = d
    train_df = dta[dta.index <= split_date]
    test_df = dta[dta.index > split_date]

    train, test = data_prep(train_df, ticker)
    predictions, check = fit_n_predict(estimator, train, test)
    p95 = np.percentile(predictions, 95, axis=0)
    p50 = np.percentile(predictions, 50, axis=0)
    p5 = np.percentile(predictions, 5, axis=0)

    var  = pd.Series(p5)
    agg = test_df[ticker]
    r = agg.values
    r = pd.Series(r)
    t_loss += tick_loss(0.05, r, var)

  return t_loss

# %%
tickers = ['NVS', 'AZN', 'BMY', 'JNJ', 'LLY', 'MRK', 'NVO', 'PFE', 'ROG']

# %%
for t in tickers:
  loss = get_performance(t, dates12m)
  print(f'{t}: {loss}')
# Out:
# 100%|██████████| 50/50 [00:01<00:00, 33.64it/s, epoch=1/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:01<00:00, 45.54it/s, epoch=2/30, avg_epoch_loss=3.08]
# 100%|██████████| 50/50 [00:01<00:00, 46.40it/s, epoch=3/30, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:01<00:00, 46.12it/s, epoch=4/30, avg_epoch_loss=3.01]
# 100%|██████████| 50/50 [00:01<00:00, 46.18it/s, epoch=5/30, avg_epoch_loss=2.96]
# 100%|██████████| 50/50 [00:01<00:00, 45.48it/s, epoch=6/30, avg_epoch_loss=2.95]
# 100%|██████████| 50/50 [00:01<00:00, 46.11it/s, epoch=7/30, avg_epoch_loss=2.91]
# 100%|██████████| 50/50 [00:01<00:00, 46.27it/s, epoch=8/30, avg_epoch_loss=2.88]
# 100%|██████████| 50/50 [00:01<00:00, 45.49it/s, epoch=9/30, avg_epoch_loss=2.91]
# 100%|██████████| 50/50 [00:01<00:00, 32.57it/s, epoch=10/30, avg_epoch_loss=2.77]
# 100%|██████████| 50/50 [00:01<00:00, 30.33it/s, epoch=11/30, avg_epoch_loss=2.73]
# 100%|██████████| 50/50 [00:01<00:00, 29.92it/s, epoch=12/30, avg_epoch_loss=2.7]
# 100%|██████████| 50/50 [00:01<00:00, 37.64it/s, epoch=13/30, avg_epoch_loss=2.75]
# 100%|██████████| 50/50 [00:01<00:00, 45.94it/s, epoch=14/30, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:01<00:00, 46.53it/s, epoch=15/30, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:01<00:00, 46.47it/s, epoch=16/30, avg_epoch_loss=3.96]
# 100%|██████████| 50/50 [00:01<00:00, 46.05it/s, epoch=17/30, avg_epoch_loss=2.48]
# 100%|██████████| 50/50 [00:01<00:00, 45.66it/s, epoch=18/30, avg_epoch_loss=2.54]
# 100%|██████████| 50/50 [00:01<00:00, 44.98it/s, epoch=19/30, avg_epoch_loss=2.42]
# 100%|██████████| 50/50 [00:01<00:00, 45.49it/s, epoch=20/30, avg_epoch_loss=2.5]
# 100%|██████████| 50/50 [00:01<00:00, 31.76it/s, epoch=21/30, avg_epoch_loss=2.44]
# 100%|██████████| 50/50 [00:01<00:00, 30.08it/s, epoch=22/30, avg_epoch_loss=2.24]
# 100%|██████████| 50/50 [00:01<00:00, 30.69it/s, epoch=23/30, avg_epoch_loss=2.34]
# 100%|██████████| 50/50 [00:01<00:00, 28.65it/s, epoch=24/30, avg_epoch_loss=2.3]
# 100%|██████████| 50/50 [00:01<00:00, 41.30it/s, epoch=25/30, avg_epoch_loss=3.58]
# 100%|██████████| 50/50 [00:01<00:00, 46.14it/s, epoch=26/30, avg_epoch_loss=2.3]
# 100%|██████████| 50/50 [00:01<00:00, 44.52it/s, epoch=27/30, avg_epoch_loss=2.28]
# 100%|██████████| 50/50 [00:01<00:00, 45.48it/s, epoch=28/30, avg_epoch_loss=2.26]
# 100%|██████████| 50/50 [00:01<00:00, 44.31it/s, epoch=29/30, avg_epoch_loss=2.22]
# 100%|██████████| 50/50 [00:01<00:00, 45.24it/s, epoch=30/30, avg_epoch_loss=2.16]
# NVS: 10.389463795369599
# 100%|██████████| 50/50 [00:01<00:00, 40.20it/s, epoch=1/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:01<00:00, 44.78it/s, epoch=2/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 38.58it/s, epoch=3/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 29.81it/s, epoch=4/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 29.47it/s, epoch=5/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 30.55it/s, epoch=6/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 43.68it/s, epoch=7/30, avg_epoch_loss=4.44]
# 100%|██████████| 50/50 [00:01<00:00, 44.38it/s, epoch=8/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:01<00:00, 44.10it/s, epoch=9/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:01<00:00, 45.30it/s, epoch=10/30, avg_epoch_loss=3.01]
# 100%|██████████| 50/50 [00:01<00:00, 45.71it/s, epoch=11/30, avg_epoch_loss=2.99]
# 100%|██████████| 50/50 [00:01<00:00, 45.80it/s, epoch=12/30, avg_epoch_loss=5.58]
# 100%|██████████| 50/50 [00:01<00:00, 45.25it/s, epoch=13/30, avg_epoch_loss=2.95]
# 100%|██████████| 50/50 [00:01<00:00, 44.59it/s, epoch=14/30, avg_epoch_loss=2.89]
# 100%|██████████| 50/50 [00:01<00:00, 37.23it/s, epoch=15/30, avg_epoch_loss=2.87]
# 100%|██████████| 50/50 [00:01<00:00, 29.87it/s, epoch=16/30, avg_epoch_loss=2.82]
# 100%|██████████| 50/50 [00:01<00:00, 29.01it/s, epoch=17/30, avg_epoch_loss=2.86]
# 100%|██████████| 50/50 [00:01<00:00, 31.76it/s, epoch=18/30, avg_epoch_loss=4.16]
# 100%|██████████| 50/50 [00:01<00:00, 44.58it/s, epoch=19/30, avg_epoch_loss=2.82]
# 100%|██████████| 50/50 [00:01<00:00, 44.90it/s, epoch=20/30, avg_epoch_loss=2.73]
# 100%|██████████| 50/50 [00:01<00:00, 45.11it/s, epoch=21/30, avg_epoch_loss=2.77]
# 100%|██████████| 50/50 [00:01<00:00, 43.56it/s, epoch=22/30, avg_epoch_loss=2.78]
# 100%|██████████| 50/50 [00:01<00:00, 44.20it/s, epoch=23/30, avg_epoch_loss=2.68]
# 100%|██████████| 50/50 [00:01<00:00, 43.97it/s, epoch=24/30, avg_epoch_loss=2.7]
# 100%|██████████| 50/50 [00:01<00:00, 43.79it/s, epoch=25/30, avg_epoch_loss=2.7]
# 100%|██████████| 50/50 [00:01<00:00, 44.08it/s, epoch=26/30, avg_epoch_loss=2.74]
# 100%|██████████| 50/50 [00:01<00:00, 34.81it/s, epoch=27/30, avg_epoch_loss=2.67]
# 100%|██████████| 50/50 [00:01<00:00, 28.44it/s, epoch=28/30, avg_epoch_loss=2.75]
# 100%|██████████| 50/50 [00:01<00:00, 28.99it/s, epoch=29/30, avg_epoch_loss=2.75]
# 100%|██████████| 50/50 [00:01<00:00, 34.46it/s, epoch=30/30, avg_epoch_loss=2.67]
# AZN: 9.468353591786823
# 100%|██████████| 50/50 [00:01<00:00, 41.05it/s, epoch=1/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 29.25it/s, epoch=2/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 35.43it/s, epoch=3/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 44.45it/s, epoch=4/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 44.14it/s, epoch=5/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 43.82it/s, epoch=6/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 42.97it/s, epoch=7/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 31.26it/s, epoch=8/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 29.27it/s, epoch=9/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 27.54it/s, epoch=10/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:01<00:00, 39.42it/s, epoch=11/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 43.55it/s, epoch=12/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 43.28it/s, epoch=13/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 43.53it/s, epoch=14/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 42.65it/s, epoch=15/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 43.14it/s, epoch=16/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 43.57it/s, epoch=17/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 42.45it/s, epoch=18/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 37.59it/s, epoch=19/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 28.64it/s, epoch=20/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 29.22it/s, epoch=21/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 31.13it/s, epoch=22/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 43.91it/s, epoch=23/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 44.16it/s, epoch=24/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 44.67it/s, epoch=25/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 44.64it/s, epoch=26/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 43.46it/s, epoch=27/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 43.70it/s, epoch=28/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 43.17it/s, epoch=29/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 41.85it/s, epoch=30/30, avg_epoch_loss=3.33]
# BMY: 8.521001395218333
# 100%|██████████| 50/50 [00:01<00:00, 28.46it/s, epoch=1/30, avg_epoch_loss=2.95]
# 100%|██████████| 50/50 [00:01<00:00, 29.84it/s, epoch=2/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:01<00:00, 28.43it/s, epoch=3/30, avg_epoch_loss=3.01]
# 100%|██████████| 50/50 [00:01<00:00, 40.47it/s, epoch=4/30, avg_epoch_loss=2.99]
# 100%|██████████| 50/50 [00:01<00:00, 44.50it/s, epoch=5/30, avg_epoch_loss=2.89]
# 100%|██████████| 50/50 [00:01<00:00, 44.98it/s, epoch=6/30, avg_epoch_loss=2.92]
# 100%|██████████| 50/50 [00:01<00:00, 42.97it/s, epoch=7/30, avg_epoch_loss=2.91]
# 100%|██████████| 50/50 [00:01<00:00, 42.73it/s, epoch=8/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 43.56it/s, epoch=9/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:01<00:00, 42.77it/s, epoch=10/30, avg_epoch_loss=2.91]
# 100%|██████████| 50/50 [00:01<00:00, 42.11it/s, epoch=11/30, avg_epoch_loss=3.01]
# 100%|██████████| 50/50 [00:01<00:00, 38.06it/s, epoch=12/30, avg_epoch_loss=2.9]
# 100%|██████████| 50/50 [00:01<00:00, 28.22it/s, epoch=13/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:01<00:00, 28.28it/s, epoch=14/30, avg_epoch_loss=2.88]
# 100%|██████████| 50/50 [00:01<00:00, 30.65it/s, epoch=15/30, avg_epoch_loss=3]
# 100%|██████████| 50/50 [00:01<00:00, 43.84it/s, epoch=16/30, avg_epoch_loss=4.31]
# 100%|██████████| 50/50 [00:01<00:00, 42.73it/s, epoch=17/30, avg_epoch_loss=3.02]
# 100%|██████████| 50/50 [00:01<00:00, 44.03it/s, epoch=18/30, avg_epoch_loss=2.9]
# 100%|██████████| 50/50 [00:01<00:00, 44.11it/s, epoch=19/30, avg_epoch_loss=2.92]
# 100%|██████████| 50/50 [00:01<00:00, 42.75it/s, epoch=20/30, avg_epoch_loss=2.89]
# 100%|██████████| 50/50 [00:01<00:00, 42.56it/s, epoch=21/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:01<00:00, 43.87it/s, epoch=22/30, avg_epoch_loss=3.02]
# 100%|██████████| 50/50 [00:01<00:00, 43.55it/s, epoch=23/30, avg_epoch_loss=2.94]
# 100%|██████████| 50/50 [00:01<00:00, 30.59it/s, epoch=24/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 28.37it/s, epoch=25/30, avg_epoch_loss=2.98]
# 100%|██████████| 50/50 [00:01<00:00, 27.02it/s, epoch=26/30, avg_epoch_loss=2.94]
# 100%|██████████| 50/50 [00:01<00:00, 39.55it/s, epoch=27/30, avg_epoch_loss=2.96]
# 100%|██████████| 50/50 [00:01<00:00, 43.40it/s, epoch=28/30, avg_epoch_loss=4.4]
# 100%|██████████| 50/50 [00:01<00:00, 42.85it/s, epoch=29/30, avg_epoch_loss=2.94]
# 100%|██████████| 50/50 [00:01<00:00, 42.90it/s, epoch=30/30, avg_epoch_loss=2.98]
# JNJ: 3.88587049766113
# 100%|██████████| 50/50 [00:01<00:00, 39.43it/s, epoch=1/30, avg_epoch_loss=4.7]
# 100%|██████████| 50/50 [00:01<00:00, 42.48it/s, epoch=2/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 42.03it/s, epoch=3/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 42.11it/s, epoch=4/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 32.76it/s, epoch=5/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 29.73it/s, epoch=6/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 27.27it/s, epoch=7/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 35.52it/s, epoch=8/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 41.34it/s, epoch=9/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 42.47it/s, epoch=10/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 41.31it/s, epoch=11/30, avg_epoch_loss=5.93]
# 100%|██████████| 50/50 [00:01<00:00, 42.09it/s, epoch=12/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 42.58it/s, epoch=13/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 43.03it/s, epoch=14/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 42.94it/s, epoch=15/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 36.13it/s, epoch=16/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 28.90it/s, epoch=17/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 28.66it/s, epoch=18/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 30.86it/s, epoch=19/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 42.95it/s, epoch=20/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 42.02it/s, epoch=21/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 42.67it/s, epoch=22/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 42.46it/s, epoch=23/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 42.61it/s, epoch=24/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:01<00:00, 42.38it/s, epoch=25/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 44.17it/s, epoch=26/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 43.04it/s, epoch=27/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 28.77it/s, epoch=28/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 28.40it/s, epoch=29/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 27.03it/s, epoch=30/30, avg_epoch_loss=4.63]
# LLY: 13.52021943155245
# 100%|██████████| 50/50 [00:01<00:00, 38.99it/s, epoch=1/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:01<00:00, 42.78it/s, epoch=2/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 42.64it/s, epoch=3/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 43.39it/s, epoch=4/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 42.95it/s, epoch=5/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 43.39it/s, epoch=6/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 43.87it/s, epoch=7/30, avg_epoch_loss=4.72]
# 100%|██████████| 50/50 [00:01<00:00, 43.81it/s, epoch=8/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 31.54it/s, epoch=9/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 28.50it/s, epoch=10/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 27.19it/s, epoch=11/30, avg_epoch_loss=4.67]
# 100%|██████████| 50/50 [00:01<00:00, 37.70it/s, epoch=12/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:01<00:00, 42.10it/s, epoch=13/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 42.15it/s, epoch=14/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 41.66it/s, epoch=15/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 42.51it/s, epoch=16/30, avg_epoch_loss=4.76]
# 100%|██████████| 50/50 [00:01<00:00, 42.33it/s, epoch=17/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 42.01it/s, epoch=18/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 41.02it/s, epoch=19/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 33.48it/s, epoch=20/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 28.14it/s, epoch=21/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 27.14it/s, epoch=22/30, avg_epoch_loss=4.7]
# 100%|██████████| 50/50 [00:01<00:00, 34.48it/s, epoch=23/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 42.02it/s, epoch=24/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 41.60it/s, epoch=25/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 42.32it/s, epoch=26/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 41.37it/s, epoch=27/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 41.79it/s, epoch=28/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 41.90it/s, epoch=29/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 41.84it/s, epoch=30/30, avg_epoch_loss=3.28]
# MRK: 7.920822471110342
# 100%|██████████| 50/50 [00:01<00:00, 30.31it/s, epoch=1/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 27.98it/s, epoch=2/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 27.97it/s, epoch=3/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 37.40it/s, epoch=4/30, avg_epoch_loss=4.49]
# 100%|██████████| 50/50 [00:01<00:00, 43.32it/s, epoch=5/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 42.39it/s, epoch=6/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 42.80it/s, epoch=7/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 42.42it/s, epoch=8/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:01<00:00, 42.58it/s, epoch=9/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 41.81it/s, epoch=10/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 41.60it/s, epoch=11/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 36.59it/s, epoch=12/30, avg_epoch_loss=4.53]
# 100%|██████████| 50/50 [00:01<00:00, 28.22it/s, epoch=13/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 27.91it/s, epoch=14/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 31.15it/s, epoch=15/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 42.38it/s, epoch=16/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 42.30it/s, epoch=17/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 41.69it/s, epoch=18/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 41.24it/s, epoch=19/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 41.28it/s, epoch=20/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 41.66it/s, epoch=21/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 42.22it/s, epoch=22/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 39.74it/s, epoch=23/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 28.04it/s, epoch=24/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 27.83it/s, epoch=25/30, avg_epoch_loss=4.52]
# 100%|██████████| 50/50 [00:01<00:00, 28.77it/s, epoch=26/30, avg_epoch_loss=4.49]
# 100%|██████████| 50/50 [00:01<00:00, 41.23it/s, epoch=27/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 42.92it/s, epoch=28/30, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:01<00:00, 42.25it/s, epoch=29/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:01<00:00, 42.42it/s, epoch=30/30, avg_epoch_loss=3.38]
# NVO: 9.60315521812571
# 100%|██████████| 50/50 [00:01<00:00, 39.51it/s, epoch=1/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 43.38it/s, epoch=2/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:01<00:00, 43.38it/s, epoch=3/30, avg_epoch_loss=4.5]
# 100%|██████████| 50/50 [00:01<00:00, 40.81it/s, epoch=4/30, avg_epoch_loss=3.14]
# 100%|██████████| 50/50 [00:01<00:00, 27.72it/s, epoch=5/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 28.60it/s, epoch=6/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 28.42it/s, epoch=7/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:01<00:00, 42.67it/s, epoch=8/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 42.21it/s, epoch=9/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 41.11it/s, epoch=10/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 42.58it/s, epoch=11/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 41.93it/s, epoch=12/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:01<00:00, 41.40it/s, epoch=13/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 40.95it/s, epoch=14/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 41.77it/s, epoch=15/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:01<00:00, 28.19it/s, epoch=16/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 28.72it/s, epoch=17/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 27.13it/s, epoch=18/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:01<00:00, 42.19it/s, epoch=19/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 42.05it/s, epoch=20/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 42.31it/s, epoch=21/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 41.91it/s, epoch=22/30, avg_epoch_loss=3.14]
# 100%|██████████| 50/50 [00:01<00:00, 42.10it/s, epoch=23/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:01<00:00, 41.26it/s, epoch=24/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:01<00:00, 41.69it/s, epoch=25/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 42.69it/s, epoch=26/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:01<00:00, 30.70it/s, epoch=27/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 28.41it/s, epoch=28/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:01<00:00, 26.66it/s, epoch=29/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:01<00:00, 39.11it/s, epoch=30/30, avg_epoch_loss=4.53]
# PFE: 11.480772782701449
# 100%|██████████| 50/50 [00:01<00:00, 39.16it/s, epoch=1/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 42.48it/s, epoch=2/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 41.10it/s, epoch=3/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 41.29it/s, epoch=4/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 41.55it/s, epoch=5/30, avg_epoch_loss=3.97]
# 100%|██████████| 50/50 [00:01<00:00, 41.82it/s, epoch=6/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 41.83it/s, epoch=7/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 29.30it/s, epoch=8/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:01<00:00, 27.83it/s, epoch=9/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 25.76it/s, epoch=10/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 40.32it/s, epoch=11/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 41.51it/s, epoch=12/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 42.36it/s, epoch=13/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:01<00:00, 41.47it/s, epoch=14/30, avg_epoch_loss=5.17]
# 100%|██████████| 50/50 [00:01<00:00, 41.43it/s, epoch=15/30, avg_epoch_loss=5.12]
# 100%|██████████| 50/50 [00:01<00:00, 41.12it/s, epoch=16/30, avg_epoch_loss=5.18]
# 100%|██████████| 50/50 [00:01<00:00, 42.25it/s, epoch=17/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:01<00:00, 41.89it/s, epoch=18/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:01<00:00, 30.32it/s, epoch=19/30, avg_epoch_loss=3.98]
# 100%|██████████| 50/50 [00:01<00:00, 27.67it/s, epoch=20/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:01<00:00, 26.75it/s, epoch=21/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:01<00:00, 39.49it/s, epoch=22/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:01<00:00, 42.12it/s, epoch=23/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:01<00:00, 42.01it/s, epoch=24/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:01<00:00, 42.05it/s, epoch=25/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:01<00:00, 41.46it/s, epoch=26/30, avg_epoch_loss=5.17]
# 100%|██████████| 50/50 [00:01<00:00, 41.45it/s, epoch=27/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 42.15it/s, epoch=28/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 40.52it/s, epoch=29/30, avg_epoch_loss=5.17]
# 100%|██████████| 50/50 [00:01<00:00, 30.65it/s, epoch=30/30, avg_epoch_loss=3.9]
# ROG: 45.54227993228767

# %% [markdown]
# STOCKS

# %%
stocks = data.copy()

for t in tickers:
  stocks[f'{t}_lag'] = stocks[t].shift(1)
  stocks[f'{t}_lag2'] = stocks[t].shift(2)
  #stocks[f'{t}_lag3'] = stocks[t].shift(3)


stocks['Quater_dummy'] = 0
stocks['Quater_rippel'] = 0
stocks['Date'] = pd.to_datetime(stocks['Date'])
for index, row in stocks.iterrows():
    date = pd.to_datetime(row['Date'])  # Convert the date string to datetime type
    if date.month in [3, 6, 9, 12]:
        stocks.loc[index, 'Quater_dummy'] = 1
    if date.month in [1, 4, 7, 10]:
        stocks.loc[index, 'Quater_rippel'] = 1

stocks = format(stocks)

# %%
def data_prep(df, ticker):
    train_data = ListDataset(
        [
            {
                "start": df.index[0],
                "target": df[ticker].values,
                "dynamic_feat": [
                              df['NVS_lag'].values,
                              df['NVS_lag2'].values,
                              df['AZN_lag'].values,
                              df['AZN_lag2'].values,
                              df['BMY_lag'].values,
                              df['BMY_lag2'].values,
                              df['JNJ_lag'].values,
                              df['JNJ_lag2'].values,
                              df['LLY_lag'].values,
                              df['LLY_lag2'].values,
                              df['MRK_lag'].values,
                              df['MRK_lag2'].values,
                              df['NVO_lag'].values,
                              df['NVO_lag2'].values,
                              df['PFE_lag'].values,
                              df['PFE_lag2'].values,
                              df['ROG_lag'].values,
                              df['ROG_lag2'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    test_data = ListDataset(
        [
            {
                "start": df.index[-12],
                "target": df[ticker][-12:].values,
                "dynamic_feat": [
                              df['NVS_lag'].values,
                              df['NVS_lag2'].values,
                              df['AZN_lag'].values,
                              df['AZN_lag2'].values,
                              df['BMY_lag'].values,
                              df['BMY_lag2'].values,
                              df['JNJ_lag'].values,
                              df['JNJ_lag2'].values,
                              df['LLY_lag'].values,
                              df['LLY_lag2'].values,
                              df['MRK_lag'].values,
                              df['MRK_lag2'].values,
                              df['NVO_lag'].values,
                              df['NVO_lag2'].values,
                              df['PFE_lag'].values,
                              df['PFE_lag2'].values,
                              df['ROG_lag'].values,
                              df['ROG_lag2'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    return train_data, test_data

# %%
def get_performance(ticker, dates):

  dta = stocks.copy()
  t_loss = 0

  for d in dates:
    split_date = d
    train_df = dta[dta.index <= split_date]
    test_df = dta[dta.index > split_date]

    train, test = data_prep(train_df, ticker)
    predictions, check = fit_n_predict(estimator, train, test)
    p95 = np.percentile(predictions, 95, axis=0)
    p50 = np.percentile(predictions, 50, axis=0)
    p5 = np.percentile(predictions, 5, axis=0)

    var  = pd.Series(p5)
    agg = test_df[ticker]
    r = agg.values
    r = pd.Series(r)
    t_loss += tick_loss(0.05, r, var)

  return t_loss

# %%
for t in tickers:
  loss = get_performance(t, dates12m)
  print(f'{t}: {loss}')
# Out:
# 100%|██████████| 50/50 [00:01<00:00, 36.97it/s, epoch=1/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:01<00:00, 34.87it/s, epoch=2/30, avg_epoch_loss=3.1]
# 100%|██████████| 50/50 [00:01<00:00, 27.47it/s, epoch=3/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:01<00:00, 26.94it/s, epoch=4/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:01<00:00, 31.37it/s, epoch=5/30, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:01<00:00, 40.82it/s, epoch=6/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:01<00:00, 39.43it/s, epoch=7/30, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:01<00:00, 41.18it/s, epoch=8/30, avg_epoch_loss=4.45]
# 100%|██████████| 50/50 [00:01<00:00, 40.82it/s, epoch=9/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:01<00:00, 39.80it/s, epoch=10/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:01<00:00, 40.60it/s, epoch=11/30, avg_epoch_loss=3.1]
# 100%|██████████| 50/50 [00:01<00:00, 40.27it/s, epoch=12/30, avg_epoch_loss=3.1]
# 100%|██████████| 50/50 [00:01<00:00, 33.11it/s, epoch=13/30, avg_epoch_loss=3.08]
# 100%|██████████| 50/50 [00:01<00:00, 27.52it/s, epoch=14/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:01<00:00, 26.86it/s, epoch=15/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:01<00:00, 33.76it/s, epoch=16/30, avg_epoch_loss=4.4]
# 100%|██████████| 50/50 [00:01<00:00, 41.43it/s, epoch=17/30, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:01<00:00, 40.49it/s, epoch=18/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:01<00:00, 41.10it/s, epoch=19/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:01<00:00, 41.30it/s, epoch=20/30, avg_epoch_loss=3.09]
# 100%|██████████| 50/50 [00:01<00:00, 40.60it/s, epoch=21/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:01<00:00, 40.88it/s, epoch=22/30, avg_epoch_loss=4.44]
# 100%|██████████| 50/50 [00:01<00:00, 40.20it/s, epoch=23/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:01<00:00, 32.03it/s, epoch=24/30, avg_epoch_loss=3.09]
# 100%|██████████| 50/50 [00:01<00:00, 27.47it/s, epoch=25/30, avg_epoch_loss=3.1]
# 100%|██████████| 50/50 [00:01<00:00, 26.76it/s, epoch=26/30, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:01<00:00, 35.21it/s, epoch=27/30, avg_epoch_loss=3.01]
# 100%|██████████| 50/50 [00:01<00:00, 40.78it/s, epoch=28/30, avg_epoch_loss=5.74]
# 100%|██████████| 50/50 [00:01<00:00, 40.73it/s, epoch=29/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:01<00:00, 41.41it/s, epoch=30/30, avg_epoch_loss=3.09]
# NVS: 10.700534439054236
# 100%|██████████| 50/50 [00:01<00:00, 37.81it/s, epoch=1/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 40.76it/s, epoch=2/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:01<00:00, 40.33it/s, epoch=3/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 40.28it/s, epoch=4/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:01<00:00, 27.78it/s, epoch=5/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:01<00:00, 27.79it/s, epoch=6/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 26.89it/s, epoch=7/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.10it/s, epoch=8/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 39.02it/s, epoch=9/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 40.90it/s, epoch=10/30, avg_epoch_loss=4.65]
# 100%|██████████| 50/50 [00:01<00:00, 40.61it/s, epoch=11/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.62it/s, epoch=12/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 41.00it/s, epoch=13/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 39.88it/s, epoch=14/30, avg_epoch_loss=4.63]
# 100%|██████████| 50/50 [00:01<00:00, 36.32it/s, epoch=15/30, avg_epoch_loss=5.84]
# 100%|██████████| 50/50 [00:01<00:00, 27.17it/s, epoch=16/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 26.98it/s, epoch=17/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 29.99it/s, epoch=18/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 40.32it/s, epoch=19/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 39.77it/s, epoch=20/30, avg_epoch_loss=5.94]
# 100%|██████████| 50/50 [00:01<00:00, 39.84it/s, epoch=21/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 39.78it/s, epoch=22/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.49it/s, epoch=23/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 38.24it/s, epoch=24/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.85it/s, epoch=25/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 31.91it/s, epoch=26/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 27.12it/s, epoch=27/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 26.61it/s, epoch=28/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 35.48it/s, epoch=29/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.75it/s, epoch=30/30, avg_epoch_loss=3.33]
# AZN: 7.353326537834606
# 100%|██████████| 50/50 [00:01<00:00, 36.71it/s, epoch=1/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 40.33it/s, epoch=2/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 39.65it/s, epoch=3/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 40.69it/s, epoch=4/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:01<00:00, 40.55it/s, epoch=5/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 40.10it/s, epoch=6/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 27.48it/s, epoch=7/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 27.54it/s, epoch=8/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 27.62it/s, epoch=9/30, avg_epoch_loss=4.66]
# 100%|██████████| 50/50 [00:01<00:00, 40.60it/s, epoch=10/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 41.34it/s, epoch=11/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:01<00:00, 40.88it/s, epoch=12/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 41.07it/s, epoch=13/30, avg_epoch_loss=4.63]
# 100%|██████████| 50/50 [00:01<00:00, 41.06it/s, epoch=14/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 39.93it/s, epoch=15/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 41.00it/s, epoch=16/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 35.45it/s, epoch=17/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 27.22it/s, epoch=18/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 27.40it/s, epoch=19/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 30.13it/s, epoch=20/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 38.84it/s, epoch=21/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 39.73it/s, epoch=22/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.67it/s, epoch=23/30, avg_epoch_loss=4.65]
# 100%|██████████| 50/50 [00:01<00:00, 40.29it/s, epoch=24/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.86it/s, epoch=25/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 40.37it/s, epoch=26/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.64it/s, epoch=27/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 29.03it/s, epoch=28/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 27.43it/s, epoch=29/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 26.17it/s, epoch=30/30, avg_epoch_loss=3.4]
# BMY: 6.248924117319541
# 100%|██████████| 50/50 [00:01<00:00, 36.91it/s, epoch=1/30, avg_epoch_loss=2.99]
# 100%|██████████| 50/50 [00:01<00:00, 40.69it/s, epoch=2/30, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:01<00:00, 41.42it/s, epoch=3/30, avg_epoch_loss=3.04]
# 100%|██████████| 50/50 [00:01<00:00, 39.81it/s, epoch=4/30, avg_epoch_loss=2.98]
# 100%|██████████| 50/50 [00:01<00:00, 40.79it/s, epoch=5/30, avg_epoch_loss=2.99]
# 100%|██████████| 50/50 [00:01<00:00, 36.57it/s, epoch=6/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 33.90it/s, epoch=7/30, avg_epoch_loss=4.32]
# 100%|██████████| 50/50 [00:01<00:00, 26.24it/s, epoch=8/30, avg_epoch_loss=3.03]
# 100%|██████████| 50/50 [00:02<00:00, 22.89it/s, epoch=9/30, avg_epoch_loss=5.64]
# 100%|██████████| 50/50 [00:02<00:00, 18.39it/s, epoch=10/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 26.70it/s, epoch=11/30, avg_epoch_loss=2.89]
# 100%|██████████| 50/50 [00:01<00:00, 40.33it/s, epoch=12/30, avg_epoch_loss=2.96]
# 100%|██████████| 50/50 [00:01<00:00, 40.97it/s, epoch=13/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:01<00:00, 40.56it/s, epoch=14/30, avg_epoch_loss=2.99]
# 100%|██████████| 50/50 [00:01<00:00, 39.12it/s, epoch=15/30, avg_epoch_loss=2.94]
# 100%|██████████| 50/50 [00:01<00:00, 40.31it/s, epoch=16/30, avg_epoch_loss=2.96]
# 100%|██████████| 50/50 [00:01<00:00, 38.87it/s, epoch=17/30, avg_epoch_loss=3.02]
# 100%|██████████| 50/50 [00:01<00:00, 40.37it/s, epoch=18/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 31.82it/s, epoch=19/30, avg_epoch_loss=2.94]
# 100%|██████████| 50/50 [00:01<00:00, 27.45it/s, epoch=20/30, avg_epoch_loss=2.91]
# 100%|██████████| 50/50 [00:01<00:00, 26.49it/s, epoch=21/30, avg_epoch_loss=3]
# 100%|██████████| 50/50 [00:01<00:00, 34.54it/s, epoch=22/30, avg_epoch_loss=2.96]
# 100%|██████████| 50/50 [00:01<00:00, 40.58it/s, epoch=23/30, avg_epoch_loss=2.95]
# 100%|██████████| 50/50 [00:01<00:00, 40.29it/s, epoch=24/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 39.43it/s, epoch=25/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 40.75it/s, epoch=26/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 40.17it/s, epoch=27/30, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:01<00:00, 40.57it/s, epoch=28/30, avg_epoch_loss=3.04]
# 100%|██████████| 50/50 [00:01<00:00, 39.67it/s, epoch=29/30, avg_epoch_loss=2.95]
# 100%|██████████| 50/50 [00:01<00:00, 29.44it/s, epoch=30/30, avg_epoch_loss=2.94]
# JNJ: 3.8500111822657748
# 100%|██████████| 50/50 [00:01<00:00, 25.45it/s, epoch=1/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 27.85it/s, epoch=2/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 40.34it/s, epoch=3/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 40.04it/s, epoch=4/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 40.55it/s, epoch=5/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 40.34it/s, epoch=6/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 40.62it/s, epoch=7/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 41.04it/s, epoch=8/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 40.36it/s, epoch=9/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 35.04it/s, epoch=10/30, avg_epoch_loss=4.66]
# 100%|██████████| 50/50 [00:01<00:00, 27.02it/s, epoch=11/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:01<00:00, 27.05it/s, epoch=12/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 30.42it/s, epoch=13/30, avg_epoch_loss=6.05]
# 100%|██████████| 50/50 [00:01<00:00, 39.46it/s, epoch=14/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 38.98it/s, epoch=15/30, avg_epoch_loss=4.65]
# 100%|██████████| 50/50 [00:01<00:00, 39.87it/s, epoch=16/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 39.64it/s, epoch=17/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 39.84it/s, epoch=18/30, avg_epoch_loss=4.7]
# 100%|██████████| 50/50 [00:01<00:00, 40.01it/s, epoch=19/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 40.42it/s, epoch=20/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 31.60it/s, epoch=21/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 27.07it/s, epoch=22/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 26.28it/s, epoch=23/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 36.88it/s, epoch=24/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 40.93it/s, epoch=25/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 39.94it/s, epoch=26/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 39.42it/s, epoch=27/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 40.75it/s, epoch=28/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:01<00:00, 40.36it/s, epoch=29/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 40.12it/s, epoch=30/30, avg_epoch_loss=3.23]
# LLY: 13.905071108970205
# 100%|██████████| 50/50 [00:01<00:00, 36.34it/s, epoch=1/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 28.11it/s, epoch=2/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 27.74it/s, epoch=3/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 28.84it/s, epoch=4/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 40.00it/s, epoch=5/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 40.49it/s, epoch=6/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 40.64it/s, epoch=7/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 40.50it/s, epoch=8/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 40.64it/s, epoch=9/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 40.30it/s, epoch=10/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 40.36it/s, epoch=11/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 34.40it/s, epoch=12/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 27.47it/s, epoch=13/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 26.44it/s, epoch=14/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:01<00:00, 32.06it/s, epoch=15/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 39.86it/s, epoch=16/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:01<00:00, 38.46it/s, epoch=17/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:01<00:00, 39.69it/s, epoch=18/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 39.55it/s, epoch=19/30, avg_epoch_loss=4.65]
# 100%|██████████| 50/50 [00:01<00:00, 40.34it/s, epoch=20/30, avg_epoch_loss=4.67]
# 100%|██████████| 50/50 [00:01<00:00, 40.11it/s, epoch=21/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 40.31it/s, epoch=22/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 30.13it/s, epoch=23/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 27.46it/s, epoch=24/30, avg_epoch_loss=5.94]
# 100%|██████████| 50/50 [00:01<00:00, 25.63it/s, epoch=25/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 38.51it/s, epoch=26/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 39.73it/s, epoch=27/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 40.21it/s, epoch=28/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 40.25it/s, epoch=29/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 38.91it/s, epoch=30/30, avg_epoch_loss=3.33]
# MRK: 9.72722022268009
# 100%|██████████| 50/50 [00:01<00:00, 37.65it/s, epoch=1/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 39.63it/s, epoch=2/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 34.44it/s, epoch=3/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 26.87it/s, epoch=4/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 27.24it/s, epoch=5/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 30.75it/s, epoch=6/30, avg_epoch_loss=4.76]
# 100%|██████████| 50/50 [00:01<00:00, 39.45it/s, epoch=7/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 40.23it/s, epoch=8/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.42it/s, epoch=9/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 39.49it/s, epoch=10/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.01it/s, epoch=11/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.60it/s, epoch=12/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 40.90it/s, epoch=13/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 32.00it/s, epoch=14/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 29.02it/s, epoch=15/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 27.82it/s, epoch=16/30, avg_epoch_loss=4.76]
# 100%|██████████| 50/50 [00:01<00:00, 35.76it/s, epoch=17/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 43.68it/s, epoch=18/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:01<00:00, 41.47it/s, epoch=19/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 40.67it/s, epoch=20/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 40.28it/s, epoch=21/30, avg_epoch_loss=3.47]
# 100%|██████████| 50/50 [00:01<00:00, 40.26it/s, epoch=22/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.93it/s, epoch=23/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.87it/s, epoch=24/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 30.93it/s, epoch=25/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 27.03it/s, epoch=26/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 26.05it/s, epoch=27/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 36.86it/s, epoch=28/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 40.09it/s, epoch=29/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 40.63it/s, epoch=30/30, avg_epoch_loss=3.32]
# NVO: 8.454933417798408
# 100%|██████████| 50/50 [00:01<00:00, 37.85it/s, epoch=1/30, avg_epoch_loss=4.61]
# 100%|██████████| 50/50 [00:01<00:00, 40.78it/s, epoch=2/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 39.68it/s, epoch=3/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 40.21it/s, epoch=4/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 36.64it/s, epoch=5/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 26.99it/s, epoch=6/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:01<00:00, 27.75it/s, epoch=7/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 29.34it/s, epoch=8/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 40.50it/s, epoch=9/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 39.78it/s, epoch=10/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 39.21it/s, epoch=11/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 39.89it/s, epoch=12/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 39.50it/s, epoch=13/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:01<00:00, 39.70it/s, epoch=14/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 39.68it/s, epoch=15/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 31.58it/s, epoch=16/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 27.05it/s, epoch=17/30, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:01<00:00, 26.14it/s, epoch=18/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:01<00:00, 35.64it/s, epoch=19/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:01<00:00, 39.40it/s, epoch=20/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 38.94it/s, epoch=21/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 40.02it/s, epoch=22/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 40.04it/s, epoch=23/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 39.44it/s, epoch=24/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 40.07it/s, epoch=25/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 39.60it/s, epoch=26/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 27.57it/s, epoch=27/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 26.03it/s, epoch=28/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 27.83it/s, epoch=29/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 39.95it/s, epoch=30/30, avg_epoch_loss=3.19]
# PFE: 8.093538454908327
# 100%|██████████| 50/50 [00:01<00:00, 37.63it/s, epoch=1/30, avg_epoch_loss=5.18]
# 100%|██████████| 50/50 [00:01<00:00, 42.53it/s, epoch=2/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 41.32it/s, epoch=3/30, avg_epoch_loss=5.12]
# 100%|██████████| 50/50 [00:01<00:00, 39.54it/s, epoch=4/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:01<00:00, 39.31it/s, epoch=5/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 40.18it/s, epoch=6/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 30.90it/s, epoch=7/30, avg_epoch_loss=5.15]
# 100%|██████████| 50/50 [00:01<00:00, 27.09it/s, epoch=8/30, avg_epoch_loss=5.11]
# 100%|██████████| 50/50 [00:01<00:00, 26.19it/s, epoch=9/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:01<00:00, 36.84it/s, epoch=10/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 39.16it/s, epoch=11/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:01<00:00, 38.54it/s, epoch=12/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 39.63it/s, epoch=13/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 40.08it/s, epoch=14/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 39.74it/s, epoch=15/30, avg_epoch_loss=5.13]
# 100%|██████████| 50/50 [00:01<00:00, 39.25it/s, epoch=16/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 37.24it/s, epoch=17/30, avg_epoch_loss=5.17]
# 100%|██████████| 50/50 [00:01<00:00, 26.83it/s, epoch=18/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:01<00:00, 26.87it/s, epoch=19/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 28.40it/s, epoch=20/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:01<00:00, 39.48it/s, epoch=21/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:01<00:00, 39.25it/s, epoch=22/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 39.28it/s, epoch=23/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:01<00:00, 39.04it/s, epoch=24/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 39.60it/s, epoch=25/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:01<00:00, 38.78it/s, epoch=26/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 39.06it/s, epoch=27/30, avg_epoch_loss=5.17]
# 100%|██████████| 50/50 [00:01<00:00, 30.09it/s, epoch=28/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:01<00:00, 26.62it/s, epoch=29/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 25.13it/s, epoch=30/30, avg_epoch_loss=3.89]
# ROG: 35.998422041920165

# %%
all = data.copy()

for m in ['GDP_growth',	'SP500_return',	'inflation_change',	'unemp_change',	'treasury_yield_change']:
  all[f'{m}_lag'] = all[m].shift(1)
  all[f'{m}_lag2'] = all[m].shift(2)
  all[f'{m}_lag3'] = all[m].shift(3)


all['Quater_dummy'] = 0
all['Quater_rippel'] = 0
all['Date'] = pd.to_datetime(all['Date'])
for index, row in all.iterrows():
    date = pd.to_datetime(row['Date'])  # Convert the date string to datetime type
    if date.month in [3, 6, 9, 12]:
        all.loc[index, 'Quater_dummy'] = 1
    if date.month in [1, 4, 7, 10]:
        all.loc[index, 'Quater_rippel'] = 1


for t in tickers:
  all[f'{t}_lag'] = all[t].shift(1)
  all[f'{t}_lag2'] = all[t].shift(2)

# %%
def data_prep(df, ticker):
    train_data = ListDataset(
        [
            {
                "start": df.index[0],
                "target": df[ticker].values,
                "dynamic_feat": [
                              df['GDP_growth_lag'].values,
                              df['GDP_growth_lag2'].values,
                              df['GDP_growth_lag3'].values,
                              df['SP500_return_lag'].values,
                              df['SP500_return_lag2'].values,
                              df['SP500_return_lag3'].values,
                              df['inflation_change_lag'].values,
                              df['inflation_change_lag2'].values,
                              df['inflation_change_lag3'].values,
                              df['unemp_change_lag'].values,
                              df['unemp_change_lag2'].values,
                              df['unemp_change_lag3'].values,
                              df['treasury_yield_change_lag'].values,
                              df['treasury_yield_change_lag2'].values,
                              df['treasury_yield_change_lag3'].values,
                              df['NVS_lag'].values,
                              df['NVS_lag2'].values,
                              df['AZN_lag'].values,
                              df['AZN_lag2'].values,
                              df['BMY_lag'].values,
                              df['BMY_lag2'].values,
                              df['JNJ_lag'].values,
                              df['JNJ_lag2'].values,
                              df['LLY_lag'].values,
                              df['LLY_lag2'].values,
                              df['MRK_lag'].values,
                              df['MRK_lag2'].values,
                              df['NVO_lag'].values,
                              df['NVO_lag2'].values,
                              df['PFE_lag'].values,
                              df['PFE_lag2'].values,
                              df['ROG_lag'].values,
                              df['ROG_lag2'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    test_data = ListDataset(
        [
            {
                "start": df.index[-12],
                "target": df[ticker][-12:].values,
                "dynamic_feat": [
                              df['GDP_growth_lag'].values,
                              df['GDP_growth_lag2'].values,
                              df['GDP_growth_lag3'].values,
                              df['SP500_return_lag'].values,
                              df['SP500_return_lag2'].values,
                              df['SP500_return_lag3'].values,
                              df['inflation_change_lag'].values,
                              df['inflation_change_lag2'].values,
                              df['inflation_change_lag3'].values,
                              df['unemp_change_lag'].values,
                              df['unemp_change_lag2'].values,
                              df['unemp_change_lag3'].values,
                              df['treasury_yield_change_lag'].values,
                              df['treasury_yield_change_lag2'].values,
                              df['treasury_yield_change_lag3'].values,
                              df['NVS_lag'].values,
                              df['NVS_lag2'].values,
                              df['AZN_lag'].values,
                              df['AZN_lag2'].values,
                              df['BMY_lag'].values,
                              df['BMY_lag2'].values,
                              df['JNJ_lag'].values,
                              df['JNJ_lag2'].values,
                              df['LLY_lag'].values,
                              df['LLY_lag2'].values,
                              df['MRK_lag'].values,
                              df['MRK_lag2'].values,
                              df['NVO_lag'].values,
                              df['NVO_lag2'].values,
                              df['PFE_lag'].values,
                              df['PFE_lag2'].values,
                              df['ROG_lag'].values,
                              df['ROG_lag2'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    return train_data, test_data

# %%
def get_performance(ticker, dates):

  dta = all.copy()
  t_loss = 0

  for d in dates:
    split_date = d
    train_df = dta[dta.index <= split_date]
    test_df = dta[dta.index > split_date]

    train, test = data_prep(train_df, ticker)
    predictions, check = fit_n_predict(estimator, train, test)
    p95 = np.percentile(predictions, 95, axis=0)
    p50 = np.percentile(predictions, 50, axis=0)
    p5 = np.percentile(predictions, 5, axis=0)

    var  = pd.Series(p5)
    agg = test_df[ticker]
    r = agg.values
    r = pd.Series(r)
    t_loss += tick_loss(0.05, r, var)

  return t_loss

# %%
#all = format(all)

# %%
for t in tickers:
  loss = get_performance(t, dates12m)
  print(f'{t}: {loss}')
# Out:
# 100%|██████████| 50/50 [00:01<00:00, 35.18it/s, epoch=1/30, avg_epoch_loss=4.4]
# 100%|██████████| 50/50 [00:01<00:00, 39.82it/s, epoch=2/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:01<00:00, 40.16it/s, epoch=3/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:01<00:00, 34.37it/s, epoch=4/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:01<00:00, 27.36it/s, epoch=5/30, avg_epoch_loss=3.1]
# 100%|██████████| 50/50 [00:01<00:00, 27.09it/s, epoch=6/30, avg_epoch_loss=3.08]
# 100%|██████████| 50/50 [00:01<00:00, 33.11it/s, epoch=7/30, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:01<00:00, 41.79it/s, epoch=8/30, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:01<00:00, 28.43it/s, epoch=9/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:01<00:00, 33.84it/s, epoch=10/30, avg_epoch_loss=3.09]
# 100%|██████████| 50/50 [00:01<00:00, 41.40it/s, epoch=11/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:01<00:00, 41.35it/s, epoch=12/30, avg_epoch_loss=3.09]
# 100%|██████████| 50/50 [00:01<00:00, 42.21it/s, epoch=13/30, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:01<00:00, 42.21it/s, epoch=14/30, avg_epoch_loss=3.08]
# 100%|██████████| 50/50 [00:01<00:00, 29.00it/s, epoch=15/30, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:01<00:00, 28.70it/s, epoch=16/30, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:01<00:00, 26.36it/s, epoch=17/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:01<00:00, 40.56it/s, epoch=18/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:01<00:00, 39.85it/s, epoch=19/30, avg_epoch_loss=3.1]
# 100%|██████████| 50/50 [00:01<00:00, 40.24it/s, epoch=20/30, avg_epoch_loss=3.02]
# 100%|██████████| 50/50 [00:01<00:00, 40.26it/s, epoch=21/30, avg_epoch_loss=3.03]
# 100%|██████████| 50/50 [00:01<00:00, 40.18it/s, epoch=22/30, avg_epoch_loss=3.04]
# 100%|██████████| 50/50 [00:01<00:00, 40.62it/s, epoch=23/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:01<00:00, 39.94it/s, epoch=24/30, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:01<00:00, 39.04it/s, epoch=25/30, avg_epoch_loss=3.04]
# 100%|██████████| 50/50 [00:01<00:00, 27.37it/s, epoch=26/30, avg_epoch_loss=4.34]
# 100%|██████████| 50/50 [00:01<00:00, 27.36it/s, epoch=27/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:01<00:00, 28.13it/s, epoch=28/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:01<00:00, 40.70it/s, epoch=29/30, avg_epoch_loss=3.09]
# 100%|██████████| 50/50 [00:01<00:00, 41.05it/s, epoch=30/30, avg_epoch_loss=3.02]
# NVS: 7.120741299941517
# 100%|██████████| 50/50 [00:01<00:00, 37.81it/s, epoch=1/30, avg_epoch_loss=6.2]
# 100%|██████████| 50/50 [00:01<00:00, 40.84it/s, epoch=2/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.47it/s, epoch=3/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 33.26it/s, epoch=4/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 33.22it/s, epoch=5/30, avg_epoch_loss=4.69]
# 100%|██████████| 50/50 [00:01<00:00, 28.96it/s, epoch=6/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 28.78it/s, epoch=7/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 27.00it/s, epoch=8/30, avg_epoch_loss=4.78]
# 100%|██████████| 50/50 [00:01<00:00, 40.87it/s, epoch=9/30, avg_epoch_loss=4.68]
# 100%|██████████| 50/50 [00:01<00:00, 40.89it/s, epoch=10/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:01<00:00, 40.56it/s, epoch=11/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 40.36it/s, epoch=12/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 39.87it/s, epoch=13/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 40.66it/s, epoch=14/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:01<00:00, 40.30it/s, epoch=15/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 40.69it/s, epoch=16/30, avg_epoch_loss=4.71]
# 100%|██████████| 50/50 [00:01<00:00, 27.65it/s, epoch=17/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 27.05it/s, epoch=18/30, avg_epoch_loss=4.71]
# 100%|██████████| 50/50 [00:01<00:00, 27.26it/s, epoch=19/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.02it/s, epoch=20/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 40.22it/s, epoch=21/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 40.34it/s, epoch=22/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:01<00:00, 38.48it/s, epoch=23/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.73it/s, epoch=24/30, avg_epoch_loss=4.74]
# 100%|██████████| 50/50 [00:01<00:00, 40.52it/s, epoch=25/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.80it/s, epoch=26/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 34.59it/s, epoch=27/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 27.54it/s, epoch=28/30, avg_epoch_loss=4.73]
# 100%|██████████| 50/50 [00:01<00:00, 26.86it/s, epoch=29/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 31.69it/s, epoch=30/30, avg_epoch_loss=3.33]
# AZN: 7.1894706156124695
# 100%|██████████| 50/50 [00:01<00:00, 37.91it/s, epoch=1/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 40.32it/s, epoch=2/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 40.26it/s, epoch=3/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 41.10it/s, epoch=4/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 41.57it/s, epoch=5/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:01<00:00, 41.88it/s, epoch=6/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 41.02it/s, epoch=7/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 31.03it/s, epoch=8/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 28.16it/s, epoch=9/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 27.16it/s, epoch=10/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 36.76it/s, epoch=11/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:01<00:00, 40.92it/s, epoch=12/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 41.02it/s, epoch=13/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.87it/s, epoch=14/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 40.46it/s, epoch=15/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 39.81it/s, epoch=16/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 39.78it/s, epoch=17/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 40.21it/s, epoch=18/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:01<00:00, 30.86it/s, epoch=19/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 27.15it/s, epoch=20/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 26.40it/s, epoch=21/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 38.52it/s, epoch=22/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 40.14it/s, epoch=23/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 40.29it/s, epoch=24/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 39.71it/s, epoch=25/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.66it/s, epoch=26/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:01<00:00, 40.22it/s, epoch=27/30, avg_epoch_loss=4.52]
# 100%|██████████| 50/50 [00:01<00:00, 39.68it/s, epoch=28/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.23it/s, epoch=29/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 27.24it/s, epoch=30/30, avg_epoch_loss=3.36]
# BMY: 8.358154767032685
# 100%|██████████| 50/50 [00:01<00:00, 25.09it/s, epoch=1/30, avg_epoch_loss=2.99]
# 100%|██████████| 50/50 [00:01<00:00, 29.92it/s, epoch=2/30, avg_epoch_loss=2.92]
# 100%|██████████| 50/50 [00:01<00:00, 41.52it/s, epoch=3/30, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:01<00:00, 41.42it/s, epoch=4/30, avg_epoch_loss=2.96]
# 100%|██████████| 50/50 [00:01<00:00, 40.71it/s, epoch=5/30, avg_epoch_loss=2.96]
# 100%|██████████| 50/50 [00:01<00:00, 41.82it/s, epoch=6/30, avg_epoch_loss=2.94]
# 100%|██████████| 50/50 [00:01<00:00, 41.45it/s, epoch=7/30, avg_epoch_loss=2.95]
# 100%|██████████| 50/50 [00:01<00:00, 39.93it/s, epoch=8/30, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:01<00:00, 39.54it/s, epoch=9/30, avg_epoch_loss=2.96]
# 100%|██████████| 50/50 [00:01<00:00, 35.60it/s, epoch=10/30, avg_epoch_loss=2.95]
# 100%|██████████| 50/50 [00:01<00:00, 27.18it/s, epoch=11/30, avg_epoch_loss=2.87]
# 100%|██████████| 50/50 [00:01<00:00, 26.43it/s, epoch=12/30, avg_epoch_loss=2.89]
# 100%|██████████| 50/50 [00:01<00:00, 32.21it/s, epoch=13/30, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:01<00:00, 39.11it/s, epoch=14/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:01<00:00, 40.10it/s, epoch=15/30, avg_epoch_loss=2.94]
# 100%|██████████| 50/50 [00:01<00:00, 39.00it/s, epoch=16/30, avg_epoch_loss=2.91]
# 100%|██████████| 50/50 [00:01<00:00, 39.44it/s, epoch=17/30, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:01<00:00, 39.83it/s, epoch=18/30, avg_epoch_loss=2.91]
# 100%|██████████| 50/50 [00:01<00:00, 38.81it/s, epoch=19/30, avg_epoch_loss=2.98]
# 100%|██████████| 50/50 [00:01<00:00, 39.46it/s, epoch=20/30, avg_epoch_loss=4.31]
# 100%|██████████| 50/50 [00:01<00:00, 29.65it/s, epoch=21/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:01<00:00, 26.84it/s, epoch=22/30, avg_epoch_loss=4.25]
# 100%|██████████| 50/50 [00:01<00:00, 25.90it/s, epoch=23/30, avg_epoch_loss=2.94]
# 100%|██████████| 50/50 [00:01<00:00, 39.58it/s, epoch=24/30, avg_epoch_loss=2.95]
# 100%|██████████| 50/50 [00:01<00:00, 39.39it/s, epoch=25/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:01<00:00, 38.92it/s, epoch=26/30, avg_epoch_loss=2.92]
# 100%|██████████| 50/50 [00:01<00:00, 38.24it/s, epoch=27/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 39.04it/s, epoch=28/30, avg_epoch_loss=2.9]
# 100%|██████████| 50/50 [00:01<00:00, 39.49it/s, epoch=29/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:01<00:00, 39.24it/s, epoch=30/30, avg_epoch_loss=2.86]
# JNJ: 6.472368270155928
# 100%|██████████| 50/50 [00:01<00:00, 30.29it/s, epoch=1/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:01<00:00, 27.38it/s, epoch=2/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 26.75it/s, epoch=3/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 34.34it/s, epoch=4/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 41.92it/s, epoch=5/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 40.75it/s, epoch=6/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 41.15it/s, epoch=7/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 40.65it/s, epoch=8/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 40.61it/s, epoch=9/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 40.56it/s, epoch=10/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 40.50it/s, epoch=11/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 31.51it/s, epoch=12/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 27.14it/s, epoch=13/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 26.56it/s, epoch=14/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 35.05it/s, epoch=15/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 40.29it/s, epoch=16/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.10it/s, epoch=17/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 38.57it/s, epoch=18/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 39.62it/s, epoch=19/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 39.88it/s, epoch=20/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 39.62it/s, epoch=21/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 39.19it/s, epoch=22/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 27.62it/s, epoch=23/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 27.23it/s, epoch=24/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 27.26it/s, epoch=25/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.00it/s, epoch=26/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 39.16it/s, epoch=27/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 39.53it/s, epoch=28/30, avg_epoch_loss=4.51]
# 100%|██████████| 50/50 [00:01<00:00, 39.39it/s, epoch=29/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 39.92it/s, epoch=30/30, avg_epoch_loss=3.22]
# LLY: 10.605029583606285
# 100%|██████████| 50/50 [00:01<00:00, 36.96it/s, epoch=1/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 41.67it/s, epoch=2/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 32.77it/s, epoch=3/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 27.25it/s, epoch=4/30, avg_epoch_loss=6.01]
# 100%|██████████| 50/50 [00:01<00:00, 26.00it/s, epoch=5/30, avg_epoch_loss=4.66]
# 100%|██████████| 50/50 [00:01<00:00, 35.12it/s, epoch=6/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 39.60it/s, epoch=7/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 38.46it/s, epoch=8/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 39.46it/s, epoch=9/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 39.61it/s, epoch=10/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.64it/s, epoch=11/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 39.88it/s, epoch=12/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 39.86it/s, epoch=13/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 28.32it/s, epoch=14/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 27.33it/s, epoch=15/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 26.79it/s, epoch=16/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 38.76it/s, epoch=17/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 39.41it/s, epoch=18/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 38.60it/s, epoch=19/30, avg_epoch_loss=4.8]
# 100%|██████████| 50/50 [00:01<00:00, 39.92it/s, epoch=20/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 39.62it/s, epoch=21/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 39.52it/s, epoch=22/30, avg_epoch_loss=4.67]
# 100%|██████████| 50/50 [00:01<00:00, 39.90it/s, epoch=23/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 32.77it/s, epoch=24/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 27.04it/s, epoch=25/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 26.09it/s, epoch=26/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:01<00:00, 32.57it/s, epoch=27/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.77it/s, epoch=28/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.67it/s, epoch=29/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 39.51it/s, epoch=30/30, avg_epoch_loss=4.62]
# MRK: 9.185014884202
# 100%|██████████| 50/50 [00:01<00:00, 37.62it/s, epoch=1/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 40.19it/s, epoch=2/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.50it/s, epoch=3/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 38.98it/s, epoch=4/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 26.93it/s, epoch=5/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 26.88it/s, epoch=6/30, avg_epoch_loss=4.74]
# 100%|██████████| 50/50 [00:01<00:00, 27.81it/s, epoch=7/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 38.09it/s, epoch=8/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 38.75it/s, epoch=9/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 39.96it/s, epoch=10/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 38.87it/s, epoch=11/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 39.47it/s, epoch=12/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 38.22it/s, epoch=13/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 39.64it/s, epoch=14/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 30.27it/s, epoch=15/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 27.26it/s, epoch=16/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 25.66it/s, epoch=17/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:01<00:00, 36.42it/s, epoch=18/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 39.76it/s, epoch=19/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.09it/s, epoch=20/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 38.60it/s, epoch=21/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 39.16it/s, epoch=22/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 39.25it/s, epoch=23/30, avg_epoch_loss=4.69]
# 100%|██████████| 50/50 [00:01<00:00, 38.85it/s, epoch=24/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 37.49it/s, epoch=25/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:01<00:00, 27.30it/s, epoch=26/30, avg_epoch_loss=4.69]
# 100%|██████████| 50/50 [00:01<00:00, 26.93it/s, epoch=27/30, avg_epoch_loss=4.72]
# 100%|██████████| 50/50 [00:01<00:00, 28.53it/s, epoch=28/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 39.95it/s, epoch=29/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 39.35it/s, epoch=30/30, avg_epoch_loss=3.34]
# NVO: 9.568964836360342
# 100%|██████████| 50/50 [00:01<00:00, 37.21it/s, epoch=1/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 40.59it/s, epoch=2/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 39.54it/s, epoch=3/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 39.64it/s, epoch=4/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 38.99it/s, epoch=5/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 28.42it/s, epoch=6/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 26.96it/s, epoch=7/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 25.77it/s, epoch=8/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 39.44it/s, epoch=9/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 38.64it/s, epoch=10/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:01<00:00, 39.46it/s, epoch=11/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 39.21it/s, epoch=12/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 39.77it/s, epoch=13/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 39.03it/s, epoch=14/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 39.33it/s, epoch=15/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 33.96it/s, epoch=16/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 26.70it/s, epoch=17/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 25.91it/s, epoch=18/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:01<00:00, 32.34it/s, epoch=19/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 39.03it/s, epoch=20/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 38.86it/s, epoch=21/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 39.59it/s, epoch=22/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 38.63it/s, epoch=23/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 38.76it/s, epoch=24/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:01<00:00, 39.57it/s, epoch=25/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 38.79it/s, epoch=26/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 27.32it/s, epoch=27/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 27.26it/s, epoch=28/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 27.23it/s, epoch=29/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 38.59it/s, epoch=30/30, avg_epoch_loss=3.23]
# PFE: 8.65549598588367
# 100%|██████████| 50/50 [00:01<00:00, 37.66it/s, epoch=1/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:01<00:00, 40.02it/s, epoch=2/30, avg_epoch_loss=5.22]
# 100%|██████████| 50/50 [00:01<00:00, 39.48it/s, epoch=3/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:01<00:00, 39.45it/s, epoch=4/30, avg_epoch_loss=5.18]
# 100%|██████████| 50/50 [00:01<00:00, 39.15it/s, epoch=5/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 38.32it/s, epoch=6/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:01<00:00, 30.90it/s, epoch=7/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 26.88it/s, epoch=8/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 25.91it/s, epoch=9/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 37.43it/s, epoch=10/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 40.16it/s, epoch=11/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:01<00:00, 38.95it/s, epoch=12/30, avg_epoch_loss=5.2]
# 100%|██████████| 50/50 [00:01<00:00, 39.89it/s, epoch=13/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:01<00:00, 39.90it/s, epoch=14/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 39.89it/s, epoch=15/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 38.76it/s, epoch=16/30, avg_epoch_loss=5.24]
# 100%|██████████| 50/50 [00:01<00:00, 37.68it/s, epoch=17/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 26.71it/s, epoch=18/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:01<00:00, 26.95it/s, epoch=19/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 28.55it/s, epoch=20/30, avg_epoch_loss=3.99]
# 100%|██████████| 50/50 [00:01<00:00, 37.63it/s, epoch=21/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:01<00:00, 39.85it/s, epoch=22/30, avg_epoch_loss=5.17]
# 100%|██████████| 50/50 [00:01<00:00, 38.90it/s, epoch=23/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 38.58it/s, epoch=24/30, avg_epoch_loss=3.96]
# 100%|██████████| 50/50 [00:01<00:00, 39.39it/s, epoch=25/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 40.04it/s, epoch=26/30, avg_epoch_loss=5.21]
# 100%|██████████| 50/50 [00:01<00:00, 39.67it/s, epoch=27/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 30.48it/s, epoch=28/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 26.41it/s, epoch=29/30, avg_epoch_loss=5.2]
# 100%|██████████| 50/50 [00:01<00:00, 25.19it/s, epoch=30/30, avg_epoch_loss=3.94]
# ROG: 47.716691281584254
