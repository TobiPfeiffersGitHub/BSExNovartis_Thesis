# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# ! pip install mxnet
# ! pip install gluonts

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from datetime import datetime
from gluonts.dataset.pandas import PandasDataset
from gluonts.dataset.split import split
from gluonts.mx import DeepAREstimator, Trainer #, TrainerCallback, EarlyStoppingCallback
from gluonts.dataset.common import ListDataset
# Out:
# /usr/local/lib/python3.10/dist-packages/gluonts/json.py:101: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
# np.random.seed(42)
# random.seed(42)

data = pd.read_csv('/content/gdrive/MyDrive/Thesis/DeepAR/clean_monthly_data.csv')
data
# Out:
#            Date  unemployment_rate      CPI  treasury_yield  GDP_growth  \
# 0    2000-02-01                4.1  170.000        6.661000    0.496560
# 1    2000-03-01                4.0  171.000        6.519500    0.511258
# 2    2000-04-01                3.8  170.900        6.256522    1.327803
# 3    2000-05-01                4.0  171.200        5.990526   -0.181797
# 4    2000-06-01                4.0  172.200        6.440455    0.305565
# ..          ...                ...      ...             ...         ...
# 275  2023-01-01                3.4  300.536        3.616190    0.390254
# 276  2023-02-01                3.6  301.648        3.531500   -0.442183
# 277  2023-03-01                3.5  301.808        3.746842   -0.442183
# 278  2023-04-01                3.4  302.918        3.663043   -0.442183
# 279  2023-05-01                3.7  304.127        3.460000   -0.442183
#
#      SP500_return        AZN        BMY        JNJ        LLY        MRK  \
# 0       -1.522563 -12.828964 -13.228004 -16.339821 -11.121498 -21.701151
# 1        9.413333  22.264136  -0.218329  -2.079067   5.804243   0.913712
# 2       -3.266805   5.567379  -8.205683  17.437698  23.153694  12.400712
# 3       -1.572223  -0.148357   5.395746   8.484832  -1.296597   7.374072
# 4        1.728613  10.549735   5.788826  14.239888  31.641749   3.078671
# ..            ...        ...        ...        ...        ...        ...
# 275      6.776820  -3.584079   0.972908  -7.489384  -5.928822  -2.549213
# 276     -2.514271  -0.290649  -4.328217  -6.217115  -9.568502  -1.089288
# 277      3.313488   8.035329   0.507544   1.862736  10.703390   0.141189
# 278      1.985238   5.489119  -3.664707   5.612908  15.269915   9.289214
# 279      0.461619  -0.191204  -2.695194  -5.277949   8.487855  -4.382088
#
#            NVO        NVS        PFE        ROG  inflation_change  \
# 0     2.220031   3.838386 -11.226228  54.440789             1.000
# 1     8.390897   6.420237  14.101954   6.922258             1.000
# 2    -0.097663   2.559423  15.213674   7.370518            -0.100
# 3    20.863985   5.169310   5.638019  -8.163265             0.300
# 4     2.813690   8.474599   8.076012  13.131313             1.000
# ..         ...        ...        ...        ...               ...
# 275   2.541749  -0.110227 -13.817335  16.968326             1.546
# 276   1.592445  -7.172811  -7.286115   5.451681             1.112
# 277  12.873250   9.367574   0.566924  11.025813             0.160
# 278   5.836894  16.334413  -4.681371  -1.517467             1.110
# 279  -3.967915  -6.161645  -2.237080  -2.162160             0.100
#
#      unemp_change  treasury_yield_change
# 0            -0.1              -0.141500
# 1            -0.1              -0.141500
# 2            -0.2              -0.262978
# 3             0.2              -0.265995
# 4             0.0               0.449928
# ..            ...                    ...
# 275          -0.1              -0.274810
# 276           0.2              -0.084690
# 277          -0.1               0.215342
# 278          -0.1              -0.083799
# 279           0.3              -0.203043
#
# [280 rows x 18 columns]

# %%
def format(df):
  df = df.set_index('Date')
  return df
####################################################
hyperparameters = {
    "prediction_length": 3,
    "context_length": 6,
    "num_cells": 10,
    "num_layers": 2,
    "dropout_rate": 0.1,
    "batch_size": 1,
    "likelihood": "gaussian",
    "hybridize": True
}
####################################################
estimator = DeepAREstimator(
    prediction_length = hyperparameters["prediction_length"],
    context_length = hyperparameters["context_length"],
    num_cells = hyperparameters["num_cells"],
    num_layers = hyperparameters["num_layers"],
    dropout_rate = hyperparameters["dropout_rate"],
    batch_size = hyperparameters["batch_size"],
    freq = "M",
    trainer = Trainer(epochs = 30)
    )
####################################################
def fit_n_predict(model, training, test):
  predictor = model.train(training)
  predictor = next(predictor.predict(test))
  samples = predictor.samples
  time = predictor.index
  return samples, time
####################################################
def tick_loss(alpha, returns, var):
    df = pd.DataFrame({'Return': returns, 'VaR': var})
    df['Indicator'] = np.where(df['Return'] < df['VaR'], 1, 0)
    #print(df)

    t_loss = 0

    for i in df.index:
        t_loss += (alpha * (df['Return'][i] - df['VaR'][i]) * (1 - df['Indicator'][i]) +
                 (1 - alpha) * (df['VaR'][i] - df['Return'][i]) * df['Indicator'][i])

    return t_loss
####################################################

# %%
dates3m = ['2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01']
tickers = ['NVS', 'AZN', 'BMY', 'JNJ', 'LLY', 'MRK', 'NVO', 'PFE', 'ROG']

# %% [markdown]
# MACRO

# %%
macro = data.copy()

for m in ['GDP_growth',	'SP500_return',	'inflation_change',	'unemp_change',	'treasury_yield_change']:
  macro[f'{m}_lag'] = macro[m].shift(1)
  macro[f'{m}_lag2'] = macro[m].shift(2)
  macro[f'{m}_lag3'] = macro[m].shift(3)


macro['Quater_dummy'] = 0
macro['Quater_rippel'] = 0
macro['Date'] = pd.to_datetime(macro['Date'])
for index, row in data.iterrows():
    date = pd.to_datetime(row['Date'])  # Convert the date string to datetime type
    if date.month in [3, 6, 9, 12]:
        data.loc[index, 'Quater_dummy'] = 1
    if date.month in [1, 4, 7, 10]:
        data.loc[index, 'Quater_rippel'] = 1

macro = format(macro)

# %%
def data_prep(df, ticker):
    train_data = ListDataset(
        [
            {
                "start": df.index[0],
                "target": df[ticker].values,
                "dynamic_feat": [
                              df['GDP_growth_lag'].values,
                              df['GDP_growth_lag2'].values,
                              df['GDP_growth_lag3'].values,
                              df['SP500_return_lag'].values,
                              df['SP500_return_lag2'].values,
                              df['SP500_return_lag3'].values,
                              df['inflation_change_lag'].values,
                              df['inflation_change_lag2'].values,
                              df['inflation_change_lag3'].values,
                              df['unemp_change_lag'].values,
                              df['unemp_change_lag2'].values,
                              df['unemp_change_lag3'].values,
                              df['treasury_yield_change_lag'].values,
                              df['treasury_yield_change_lag2'].values,
                              df['treasury_yield_change_lag3'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    test_data = ListDataset(
        [
            {
                "start": df.index[-3],
                "target": df[ticker][-3:].values,
                "dynamic_feat": [
                              df['GDP_growth_lag'].values,
                              df['GDP_growth_lag2'].values,
                              df['GDP_growth_lag3'].values,
                              df['SP500_return_lag'].values,
                              df['SP500_return_lag2'].values,
                              df['SP500_return_lag3'].values,
                              df['inflation_change_lag'].values,
                              df['inflation_change_lag2'].values,
                              df['inflation_change_lag3'].values,
                              df['unemp_change_lag'].values,
                              df['unemp_change_lag2'].values,
                              df['unemp_change_lag3'].values,
                              df['treasury_yield_change_lag'].values,
                              df['treasury_yield_change_lag2'].values,
                              df['treasury_yield_change_lag3'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    return train_data, test_data

# %%
def get_performance(ticker, dates):

  dta = macro.copy()
  t_loss = 0

  for d in dates:
    split_date = d
    train_df = dta[dta.index <= split_date]
    test_df = dta[dta.index > split_date]

    train, test = data_prep(train_df, ticker)
    predictions, check = fit_n_predict(estimator, train, test)
    p95 = np.percentile(predictions, 95, axis=0)
    p50 = np.percentile(predictions, 50, axis=0)
    p5 = np.percentile(predictions, 5, axis=0)

    var  = pd.Series(p5)
    agg = test_df[ticker]
    r = agg.values
    r = r[0:3]
    r = pd.Series(r)
    t_loss += tick_loss(0.05, r, var)

  t_loss = t_loss/10

  return t_loss

# %%
#for t in ['NVS', 'AZN', 'BMY']:
#for t in ['JNJ', 'LLY', 'MRK']:
#for t in ['NVO', 'PFE', 'ROG']:
  loss = get_performance(t, dates3m)
  print(f'{t}: {loss}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-03227909ed78> in <cell line: 1>()
#       2 #for t in ['JNJ', 'LLY', 'MRK']:
#       3 #for t in ['NVO', 'PFE', 'ROG']:
# ----> 4   loss = get_performance(t, dates3m)
#       5   print(f'{t}: {loss}')
#
# NameError: name 'get_performance' is not defined

# %% [markdown]
# STOCKS

# %%
stocks = data.copy()

for t in tickers:
  stocks[f'{t}_lag'] = stocks[t].shift(1)
  stocks[f'{t}_lag2'] = stocks[t].shift(2)
  #stocks[f'{t}_lag3'] = stocks[t].shift(3)


stocks['Quater_dummy'] = 0
stocks['Quater_rippel'] = 0
stocks['Date'] = pd.to_datetime(stocks['Date'])
for index, row in stocks.iterrows():
    date = pd.to_datetime(row['Date'])  # Convert the date string to datetime type
    if date.month in [3, 6, 9, 12]:
        stocks.loc[index, 'Quater_dummy'] = 1
    if date.month in [1, 4, 7, 10]:
        stocks.loc[index, 'Quater_rippel'] = 1

stocks = format(stocks)

# %%
def data_prep(df, ticker):
    train_data = ListDataset(
        [
            {
                "start": df.index[0],
                "target": df[ticker].values,
                "dynamic_feat": [
                              df['NVS_lag'].values,
                              df['NVS_lag2'].values,
                              df['AZN_lag'].values,
                              df['AZN_lag2'].values,
                              df['BMY_lag'].values,
                              df['BMY_lag2'].values,
                              df['JNJ_lag'].values,
                              df['JNJ_lag2'].values,
                              df['LLY_lag'].values,
                              df['LLY_lag2'].values,
                              df['MRK_lag'].values,
                              df['MRK_lag2'].values,
                              df['NVO_lag'].values,
                              df['NVO_lag2'].values,
                              df['PFE_lag'].values,
                              df['PFE_lag2'].values,
                              df['ROG_lag'].values,
                              df['ROG_lag2'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    test_data = ListDataset(
        [
            {
                "start": df.index[-3],
                "target": df[ticker][-3:].values,
                "dynamic_feat": [
                              df['NVS_lag'].values,
                              df['NVS_lag2'].values,
                              df['AZN_lag'].values,
                              df['AZN_lag2'].values,
                              df['BMY_lag'].values,
                              df['BMY_lag2'].values,
                              df['JNJ_lag'].values,
                              df['JNJ_lag2'].values,
                              df['LLY_lag'].values,
                              df['LLY_lag2'].values,
                              df['MRK_lag'].values,
                              df['MRK_lag2'].values,
                              df['NVO_lag'].values,
                              df['NVO_lag2'].values,
                              df['PFE_lag'].values,
                              df['PFE_lag2'].values,
                              df['ROG_lag'].values,
                              df['ROG_lag2'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    return train_data, test_data

# %%
def get_performance(ticker, dates):

  dta = stocks.copy()
  t_loss = 0

  for d in dates:
    split_date = d
    train_df = dta[dta.index <= split_date]
    test_df = dta[dta.index > split_date]

    train, test = data_prep(train_df, ticker)
    predictions, check = fit_n_predict(estimator, train, test)
    p95 = np.percentile(predictions, 95, axis=0)
    p50 = np.percentile(predictions, 50, axis=0)
    p5 = np.percentile(predictions, 5, axis=0)

    var  = pd.Series(p5)
    agg = test_df[ticker]
    r = agg.values
    r = r[0:3]
    r = pd.Series(r)
    t_loss += tick_loss(0.05, r, var)

  t_loss = t_loss/10

  return t_loss

# %%
#for t in ['NVS', 'AZN', 'BMY']:
#for t in ['JNJ', 'LLY', 'MRK']:
for t in ['NVO', 'PFE', 'ROG']:
  loss = get_performance(t, dates3m)
  print(f'{t}: {loss}')
# Out:
# 100%|██████████| 50/50 [00:01<00:00, 43.81it/s, epoch=1/30, avg_epoch_loss=3.46]
# 100%|██████████| 50/50 [00:00<00:00, 53.91it/s, epoch=2/30, avg_epoch_loss=3.47]
# 100%|██████████| 50/50 [00:00<00:00, 83.50it/s, epoch=3/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 84.76it/s, epoch=4/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 82.31it/s, epoch=5/30, avg_epoch_loss=4.66]
# 100%|██████████| 50/50 [00:00<00:00, 80.82it/s, epoch=6/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 84.61it/s, epoch=7/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 80.16it/s, epoch=8/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 85.39it/s, epoch=9/30, avg_epoch_loss=4.59]
# 100%|██████████| 50/50 [00:00<00:00, 80.77it/s, epoch=10/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 84.05it/s, epoch=11/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 87.59it/s, epoch=12/30, avg_epoch_loss=3.14]
# 100%|██████████| 50/50 [00:00<00:00, 82.33it/s, epoch=13/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 82.42it/s, epoch=14/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 77.56it/s, epoch=15/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 74.99it/s, epoch=16/30, avg_epoch_loss=3]
# 100%|██████████| 50/50 [00:00<00:00, 84.30it/s, epoch=17/30, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:00<00:00, 82.89it/s, epoch=18/30, avg_epoch_loss=3.09]
# 100%|██████████| 50/50 [00:00<00:00, 57.48it/s, epoch=19/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:00<00:00, 55.64it/s, epoch=20/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:00<00:00, 56.65it/s, epoch=21/30, avg_epoch_loss=3.01]
# 100%|██████████| 50/50 [00:00<00:00, 57.94it/s, epoch=22/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:00<00:00, 53.86it/s, epoch=23/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:00<00:00, 54.44it/s, epoch=24/30, avg_epoch_loss=4.08]
# 100%|██████████| 50/50 [00:00<00:00, 79.47it/s, epoch=25/30, avg_epoch_loss=2.82]
# 100%|██████████| 50/50 [00:00<00:00, 81.60it/s, epoch=26/30, avg_epoch_loss=2.79]
# 100%|██████████| 50/50 [00:00<00:00, 82.79it/s, epoch=27/30, avg_epoch_loss=2.82]
# 100%|██████████| 50/50 [00:00<00:00, 80.89it/s, epoch=28/30, avg_epoch_loss=2.76]
# 100%|██████████| 50/50 [00:00<00:00, 83.20it/s, epoch=29/30, avg_epoch_loss=2.7]
# 100%|██████████| 50/50 [00:00<00:00, 83.21it/s, epoch=30/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 76.77it/s, epoch=1/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 82.86it/s, epoch=2/30, avg_epoch_loss=4.74]
# 100%|██████████| 50/50 [00:00<00:00, 82.69it/s, epoch=3/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 81.35it/s, epoch=4/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 82.51it/s, epoch=5/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 84.27it/s, epoch=6/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 79.48it/s, epoch=7/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 82.21it/s, epoch=8/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 79.85it/s, epoch=9/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 71.11it/s, epoch=10/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 53.65it/s, epoch=11/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 54.53it/s, epoch=12/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 54.90it/s, epoch=13/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 52.74it/s, epoch=14/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 50.67it/s, epoch=15/30, avg_epoch_loss=4.33]
# 100%|██████████| 50/50 [00:00<00:00, 68.91it/s, epoch=16/30, avg_epoch_loss=3.09]
# 100%|██████████| 50/50 [00:00<00:00, 78.50it/s, epoch=17/30, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:00<00:00, 79.12it/s, epoch=18/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:00<00:00, 81.56it/s, epoch=19/30, avg_epoch_loss=4.35]
# 100%|██████████| 50/50 [00:00<00:00, 79.51it/s, epoch=20/30, avg_epoch_loss=3]
# 100%|██████████| 50/50 [00:00<00:00, 82.21it/s, epoch=21/30, avg_epoch_loss=3]
# 100%|██████████| 50/50 [00:00<00:00, 82.29it/s, epoch=22/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:00<00:00, 81.03it/s, epoch=23/30, avg_epoch_loss=3.04]
# 100%|██████████| 50/50 [00:00<00:00, 80.16it/s, epoch=24/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:00<00:00, 78.11it/s, epoch=25/30, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 81.60it/s, epoch=26/30, avg_epoch_loss=3]
# 100%|██████████| 50/50 [00:00<00:00, 82.12it/s, epoch=27/30, avg_epoch_loss=3.04]
# 100%|██████████| 50/50 [00:00<00:00, 77.98it/s, epoch=28/30, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:00<00:00, 80.73it/s, epoch=29/30, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:00<00:00, 82.36it/s, epoch=30/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 72.49it/s, epoch=1/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 55.89it/s, epoch=2/30, avg_epoch_loss=4.39]
# 100%|██████████| 50/50 [00:00<00:00, 50.88it/s, epoch=3/30, avg_epoch_loss=4.42]
# 100%|██████████| 50/50 [00:00<00:00, 55.98it/s, epoch=4/30, avg_epoch_loss=4.39]
# 100%|██████████| 50/50 [00:00<00:00, 56.17it/s, epoch=5/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 50.73it/s, epoch=6/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 59.54it/s, epoch=7/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 55.59it/s, epoch=8/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 55.07it/s, epoch=9/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 55.01it/s, epoch=10/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 81.23it/s, epoch=11/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 76.96it/s, epoch=12/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 79.26it/s, epoch=13/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 79.28it/s, epoch=14/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 81.09it/s, epoch=15/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 80.22it/s, epoch=16/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 77.00it/s, epoch=17/30, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:00<00:00, 77.94it/s, epoch=18/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 79.29it/s, epoch=19/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 78.42it/s, epoch=20/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 70.59it/s, epoch=21/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 52.83it/s, epoch=22/30, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:00<00:00, 53.73it/s, epoch=23/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 52.72it/s, epoch=24/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 53.67it/s, epoch=25/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 49.09it/s, epoch=26/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 68.22it/s, epoch=27/30, avg_epoch_loss=5.28]
# 100%|██████████| 50/50 [00:00<00:00, 79.59it/s, epoch=28/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 80.51it/s, epoch=29/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 77.01it/s, epoch=30/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 73.75it/s, epoch=1/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 82.88it/s, epoch=2/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:00<00:00, 80.47it/s, epoch=3/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 76.64it/s, epoch=4/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 77.49it/s, epoch=5/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 75.46it/s, epoch=6/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 78.87it/s, epoch=7/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 80.58it/s, epoch=8/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 77.96it/s, epoch=9/30, avg_epoch_loss=4.59]
# 100%|██████████| 50/50 [00:00<00:00, 76.72it/s, epoch=10/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 80.30it/s, epoch=11/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 62.30it/s, epoch=12/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 54.16it/s, epoch=13/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 52.05it/s, epoch=14/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 54.47it/s, epoch=15/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 51.65it/s, epoch=16/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 51.26it/s, epoch=17/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 76.46it/s, epoch=18/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 77.20it/s, epoch=19/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 79.04it/s, epoch=20/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 76.95it/s, epoch=21/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 73.47it/s, epoch=22/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 77.67it/s, epoch=23/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 77.39it/s, epoch=24/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 75.22it/s, epoch=25/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 79.81it/s, epoch=26/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 75.47it/s, epoch=27/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 76.94it/s, epoch=28/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 79.33it/s, epoch=29/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 76.76it/s, epoch=30/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 73.56it/s, epoch=1/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 67.48it/s, epoch=2/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 53.15it/s, epoch=3/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 52.82it/s, epoch=4/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 51.41it/s, epoch=5/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 52.65it/s, epoch=6/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 48.51it/s, epoch=7/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 71.08it/s, epoch=8/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 74.91it/s, epoch=9/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 74.49it/s, epoch=10/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 72.35it/s, epoch=11/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 76.52it/s, epoch=12/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 73.85it/s, epoch=13/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 76.37it/s, epoch=14/30, avg_epoch_loss=3.46]
# 100%|██████████| 50/50 [00:00<00:00, 76.32it/s, epoch=15/30, avg_epoch_loss=3.49]
# 100%|██████████| 50/50 [00:00<00:00, 72.14it/s, epoch=16/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 76.79it/s, epoch=17/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 78.80it/s, epoch=18/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 77.41it/s, epoch=19/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 74.88it/s, epoch=20/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 78.88it/s, epoch=21/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 77.82it/s, epoch=22/30, avg_epoch_loss=4.51]
# 100%|██████████| 50/50 [00:00<00:00, 54.00it/s, epoch=23/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 54.76it/s, epoch=24/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 54.62it/s, epoch=25/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 53.47it/s, epoch=26/30, avg_epoch_loss=3.47]
# 100%|██████████| 50/50 [00:00<00:00, 50.05it/s, epoch=27/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 57.83it/s, epoch=28/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 75.90it/s, epoch=29/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 76.95it/s, epoch=30/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 72.37it/s, epoch=1/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 77.29it/s, epoch=2/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 75.17it/s, epoch=3/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 75.75it/s, epoch=4/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 76.05it/s, epoch=5/30, avg_epoch_loss=6.02]
# 100%|██████████| 50/50 [00:00<00:00, 79.15it/s, epoch=6/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 78.07it/s, epoch=7/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 76.07it/s, epoch=8/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 75.77it/s, epoch=9/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 77.49it/s, epoch=10/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 74.98it/s, epoch=11/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 77.08it/s, epoch=12/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 62.88it/s, epoch=13/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 53.23it/s, epoch=14/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 51.27it/s, epoch=15/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 52.04it/s, epoch=16/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:01<00:00, 49.64it/s, epoch=17/30, avg_epoch_loss=3.45]
# 100%|██████████| 50/50 [00:00<00:00, 52.93it/s, epoch=18/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 76.61it/s, epoch=19/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 77.66it/s, epoch=20/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 75.07it/s, epoch=21/30, avg_epoch_loss=3.51]
# 100%|██████████| 50/50 [00:00<00:00, 76.21it/s, epoch=22/30, avg_epoch_loss=4.61]
# 100%|██████████| 50/50 [00:00<00:00, 77.43it/s, epoch=23/30, avg_epoch_loss=4.63]
# 100%|██████████| 50/50 [00:00<00:00, 76.39it/s, epoch=24/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 77.17it/s, epoch=25/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 77.55it/s, epoch=26/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 76.25it/s, epoch=27/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 79.67it/s, epoch=28/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 76.62it/s, epoch=29/30, avg_epoch_loss=4.72]
# 100%|██████████| 50/50 [00:00<00:00, 76.26it/s, epoch=30/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 72.04it/s, epoch=1/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 77.59it/s, epoch=2/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 66.64it/s, epoch=3/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 53.49it/s, epoch=4/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 54.08it/s, epoch=5/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 54.03it/s, epoch=6/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 51.69it/s, epoch=7/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:01<00:00, 45.84it/s, epoch=8/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:01<00:00, 47.99it/s, epoch=9/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:01<00:00, 48.73it/s, epoch=10/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 52.16it/s, epoch=11/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 51.67it/s, epoch=12/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 47.42it/s, epoch=13/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 70.02it/s, epoch=14/30, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:00<00:00, 77.50it/s, epoch=15/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 79.22it/s, epoch=16/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 76.47it/s, epoch=17/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 79.26it/s, epoch=18/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 76.99it/s, epoch=19/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 74.51it/s, epoch=20/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 78.94it/s, epoch=21/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 77.89it/s, epoch=22/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 75.73it/s, epoch=23/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 53.07it/s, epoch=24/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 53.26it/s, epoch=25/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 52.03it/s, epoch=26/30, avg_epoch_loss=4.53]
# 100%|██████████| 50/50 [00:00<00:00, 51.59it/s, epoch=27/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 48.97it/s, epoch=28/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 62.94it/s, epoch=29/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 76.39it/s, epoch=30/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 72.45it/s, epoch=1/30, avg_epoch_loss=3.45]
# 100%|██████████| 50/50 [00:00<00:00, 77.68it/s, epoch=2/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 76.25it/s, epoch=3/30, avg_epoch_loss=4.66]
# 100%|██████████| 50/50 [00:00<00:00, 75.71it/s, epoch=4/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 74.98it/s, epoch=5/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 73.89it/s, epoch=6/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 75.18it/s, epoch=7/30, avg_epoch_loss=4.7]
# 100%|██████████| 50/50 [00:00<00:00, 77.42it/s, epoch=8/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 75.54it/s, epoch=9/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 74.86it/s, epoch=10/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 73.86it/s, epoch=11/30, avg_epoch_loss=4.65]
# 100%|██████████| 50/50 [00:00<00:00, 75.30it/s, epoch=12/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 74.16it/s, epoch=13/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 52.79it/s, epoch=14/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 52.95it/s, epoch=15/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 54.20it/s, epoch=16/30, avg_epoch_loss=4.66]
# 100%|██████████| 50/50 [00:00<00:00, 53.97it/s, epoch=17/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:01<00:00, 47.67it/s, epoch=18/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 63.71it/s, epoch=19/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 77.43it/s, epoch=20/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 78.37it/s, epoch=21/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 76.80it/s, epoch=22/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 78.44it/s, epoch=23/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 77.11it/s, epoch=24/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 76.00it/s, epoch=25/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 75.89it/s, epoch=26/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 76.62it/s, epoch=27/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 73.63it/s, epoch=28/30, avg_epoch_loss=4.65]
# 100%|██████████| 50/50 [00:00<00:00, 77.45it/s, epoch=29/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 76.52it/s, epoch=30/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 71.71it/s, epoch=1/30, avg_epoch_loss=3.45]
# 100%|██████████| 50/50 [00:00<00:00, 78.24it/s, epoch=2/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 76.06it/s, epoch=3/30, avg_epoch_loss=3.48]
# 100%|██████████| 50/50 [00:00<00:00, 54.71it/s, epoch=4/30, avg_epoch_loss=3.48]
# 100%|██████████| 50/50 [00:00<00:00, 52.30it/s, epoch=5/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 54.87it/s, epoch=6/30, avg_epoch_loss=5.7]
# 100%|██████████| 50/50 [00:00<00:00, 54.16it/s, epoch=7/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 51.09it/s, epoch=8/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 54.95it/s, epoch=9/30, avg_epoch_loss=3.45]
# 100%|██████████| 50/50 [00:00<00:00, 77.66it/s, epoch=10/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 77.47it/s, epoch=11/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 76.72it/s, epoch=12/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 76.54it/s, epoch=13/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 77.80it/s, epoch=14/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 75.22it/s, epoch=15/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 78.75it/s, epoch=16/30, avg_epoch_loss=3.45]
# 100%|██████████| 50/50 [00:00<00:00, 76.86it/s, epoch=17/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 75.64it/s, epoch=18/30, avg_epoch_loss=3.45]
# 100%|██████████| 50/50 [00:00<00:00, 77.70it/s, epoch=19/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 76.74it/s, epoch=20/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 75.04it/s, epoch=21/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 75.78it/s, epoch=22/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 77.21it/s, epoch=23/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 69.33it/s, epoch=24/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 53.61it/s, epoch=25/30, avg_epoch_loss=3.46]
# 100%|██████████| 50/50 [00:00<00:00, 51.55it/s, epoch=26/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 51.93it/s, epoch=27/30, avg_epoch_loss=3.47]
# 100%|██████████| 50/50 [00:00<00:00, 52.58it/s, epoch=28/30, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:01<00:00, 48.92it/s, epoch=29/30, avg_epoch_loss=3.46]
# 100%|██████████| 50/50 [00:00<00:00, 68.62it/s, epoch=30/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 73.47it/s, epoch=1/30, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:00<00:00, 80.12it/s, epoch=2/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 76.13it/s, epoch=3/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 75.61it/s, epoch=4/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 76.70it/s, epoch=5/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 78.85it/s, epoch=6/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 75.24it/s, epoch=7/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 75.54it/s, epoch=8/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 74.72it/s, epoch=9/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 76.77it/s, epoch=10/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 77.69it/s, epoch=11/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 73.41it/s, epoch=12/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 77.39it/s, epoch=13/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 75.11it/s, epoch=14/30, avg_epoch_loss=4.43]
# 100%|██████████| 50/50 [00:00<00:00, 53.24it/s, epoch=15/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 52.86it/s, epoch=16/30, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:00<00:00, 53.84it/s, epoch=17/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 52.44it/s, epoch=18/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:01<00:00, 49.16it/s, epoch=19/30, avg_epoch_loss=4.41]
# 100%|██████████| 50/50 [00:00<00:00, 63.71it/s, epoch=20/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 78.99it/s, epoch=21/30, avg_epoch_loss=4.53]
# 100%|██████████| 50/50 [00:00<00:00, 74.08it/s, epoch=22/30, avg_epoch_loss=4.41]
# 100%|██████████| 50/50 [00:00<00:00, 76.33it/s, epoch=23/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 77.52it/s, epoch=24/30, avg_epoch_loss=3.47]
# 100%|██████████| 50/50 [00:00<00:00, 78.02it/s, epoch=25/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 77.60it/s, epoch=26/30, avg_epoch_loss=4.34]
# 100%|██████████| 50/50 [00:00<00:00, 76.71it/s, epoch=27/30, avg_epoch_loss=4.52]
# 100%|██████████| 50/50 [00:00<00:00, 75.46it/s, epoch=28/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 75.64it/s, epoch=29/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 78.29it/s, epoch=30/30, avg_epoch_loss=3.41]
# NVO: 3.535487070869494
# 100%|██████████| 50/50 [00:00<00:00, 69.61it/s, epoch=1/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 76.46it/s, epoch=2/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 76.13it/s, epoch=3/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 79.78it/s, epoch=4/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 55.40it/s, epoch=5/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 49.90it/s, epoch=6/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 54.02it/s, epoch=7/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.89it/s, epoch=8/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 50.85it/s, epoch=9/30, avg_epoch_loss=4.65]
# 100%|██████████| 50/50 [00:00<00:00, 57.89it/s, epoch=10/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 76.41it/s, epoch=11/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 76.79it/s, epoch=12/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 76.47it/s, epoch=13/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 75.54it/s, epoch=14/30, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:00<00:00, 70.76it/s, epoch=15/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.07it/s, epoch=16/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 77.34it/s, epoch=17/30, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:00<00:00, 74.71it/s, epoch=18/30, avg_epoch_loss=4.59]
# 100%|██████████| 50/50 [00:00<00:00, 74.35it/s, epoch=19/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 72.10it/s, epoch=20/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 76.52it/s, epoch=21/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:00<00:00, 76.36it/s, epoch=22/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 74.62it/s, epoch=23/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 75.29it/s, epoch=24/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 60.61it/s, epoch=25/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.66it/s, epoch=26/30, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:00<00:00, 53.37it/s, epoch=27/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 53.70it/s, epoch=28/30, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:00<00:00, 50.24it/s, epoch=29/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 52.71it/s, epoch=30/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 70.29it/s, epoch=1/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 77.60it/s, epoch=2/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 77.06it/s, epoch=3/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 74.65it/s, epoch=4/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.05it/s, epoch=5/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 75.68it/s, epoch=6/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 77.36it/s, epoch=7/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 76.27it/s, epoch=8/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.41it/s, epoch=9/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:00<00:00, 76.15it/s, epoch=10/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 75.18it/s, epoch=11/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 76.54it/s, epoch=12/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 74.91it/s, epoch=13/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 77.59it/s, epoch=14/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 59.02it/s, epoch=15/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 52.74it/s, epoch=16/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 53.22it/s, epoch=17/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 53.62it/s, epoch=18/30, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:01<00:00, 49.31it/s, epoch=19/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 51.39it/s, epoch=20/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 73.43it/s, epoch=21/30, avg_epoch_loss=3.14]
# 100%|██████████| 50/50 [00:00<00:00, 77.05it/s, epoch=22/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 72.27it/s, epoch=23/30, avg_epoch_loss=3.14]
# 100%|██████████| 50/50 [00:00<00:00, 75.56it/s, epoch=24/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 77.97it/s, epoch=25/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 76.05it/s, epoch=26/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 72.45it/s, epoch=27/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 76.15it/s, epoch=28/30, avg_epoch_loss=4.5]
# 100%|██████████| 50/50 [00:00<00:00, 75.54it/s, epoch=29/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 75.21it/s, epoch=30/30, avg_epoch_loss=4.52]
# 100%|██████████| 50/50 [00:00<00:00, 72.26it/s, epoch=1/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 79.56it/s, epoch=2/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 77.88it/s, epoch=3/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 78.79it/s, epoch=4/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 64.76it/s, epoch=5/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 53.90it/s, epoch=6/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 53.88it/s, epoch=7/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 55.20it/s, epoch=8/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 53.53it/s, epoch=9/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:01<00:00, 47.21it/s, epoch=10/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 74.09it/s, epoch=11/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.53it/s, epoch=12/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 75.95it/s, epoch=13/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 75.96it/s, epoch=14/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 76.00it/s, epoch=15/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:00<00:00, 77.56it/s, epoch=16/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 77.23it/s, epoch=17/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 75.34it/s, epoch=18/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 77.89it/s, epoch=19/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 77.15it/s, epoch=20/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 75.49it/s, epoch=21/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 76.69it/s, epoch=22/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 75.84it/s, epoch=23/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:00<00:00, 75.35it/s, epoch=24/30, avg_epoch_loss=4.63]
# 100%|██████████| 50/50 [00:00<00:00, 77.95it/s, epoch=25/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 53.40it/s, epoch=26/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 51.77it/s, epoch=27/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 53.03it/s, epoch=28/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 52.23it/s, epoch=29/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:01<00:00, 49.86it/s, epoch=30/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 60.92it/s, epoch=1/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 76.24it/s, epoch=2/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 76.96it/s, epoch=3/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 78.85it/s, epoch=4/30, avg_epoch_loss=5.87]
# 100%|██████████| 50/50 [00:00<00:00, 75.55it/s, epoch=5/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 74.08it/s, epoch=6/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 72.88it/s, epoch=7/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 75.79it/s, epoch=8/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 74.16it/s, epoch=9/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 75.02it/s, epoch=10/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 75.42it/s, epoch=11/30, avg_epoch_loss=4.67]
# 100%|██████████| 50/50 [00:00<00:00, 76.61it/s, epoch=12/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:00<00:00, 67.78it/s, epoch=13/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 74.30it/s, epoch=14/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 73.63it/s, epoch=15/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:00<00:00, 54.03it/s, epoch=16/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 53.08it/s, epoch=17/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.18it/s, epoch=18/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 53.70it/s, epoch=19/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:01<00:00, 47.90it/s, epoch=20/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 60.95it/s, epoch=21/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 75.40it/s, epoch=22/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 77.15it/s, epoch=23/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 75.64it/s, epoch=24/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 74.29it/s, epoch=25/30, avg_epoch_loss=5.86]
# 100%|██████████| 50/50 [00:00<00:00, 75.93it/s, epoch=26/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 75.44it/s, epoch=27/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 76.78it/s, epoch=28/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 75.88it/s, epoch=29/30, avg_epoch_loss=3.1]
# 100%|██████████| 50/50 [00:00<00:00, 75.92it/s, epoch=30/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 66.57it/s, epoch=1/30, avg_epoch_loss=4.61]
# 100%|██████████| 50/50 [00:00<00:00, 78.51it/s, epoch=2/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 76.47it/s, epoch=3/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 77.27it/s, epoch=4/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:00<00:00, 74.66it/s, epoch=5/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 52.75it/s, epoch=6/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 51.13it/s, epoch=7/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 51.08it/s, epoch=8/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 50.80it/s, epoch=9/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:01<00:00, 46.80it/s, epoch=10/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 64.62it/s, epoch=11/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 73.44it/s, epoch=12/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 74.35it/s, epoch=13/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 74.08it/s, epoch=14/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 76.80it/s, epoch=15/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 72.13it/s, epoch=16/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:00<00:00, 71.39it/s, epoch=17/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 74.98it/s, epoch=18/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 74.90it/s, epoch=19/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 75.14it/s, epoch=20/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 75.51it/s, epoch=21/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 75.00it/s, epoch=22/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 76.21it/s, epoch=23/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 75.75it/s, epoch=24/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:00<00:00, 71.59it/s, epoch=25/30, avg_epoch_loss=4.63]
# 100%|██████████| 50/50 [00:00<00:00, 52.16it/s, epoch=26/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 52.03it/s, epoch=27/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 52.09it/s, epoch=28/30, avg_epoch_loss=3.14]
# 100%|██████████| 50/50 [00:00<00:00, 53.23it/s, epoch=29/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 47.59it/s, epoch=30/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 70.50it/s, epoch=1/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:00<00:00, 73.85it/s, epoch=2/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.10it/s, epoch=3/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 74.99it/s, epoch=4/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 77.85it/s, epoch=5/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.99it/s, epoch=6/30, avg_epoch_loss=4.49]
# 100%|██████████| 50/50 [00:00<00:00, 76.24it/s, epoch=7/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 74.93it/s, epoch=8/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:00<00:00, 74.20it/s, epoch=9/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 76.68it/s, epoch=10/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 74.99it/s, epoch=11/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 69.56it/s, epoch=12/30, avg_epoch_loss=4.68]
# 100%|██████████| 50/50 [00:00<00:00, 75.12it/s, epoch=13/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.81it/s, epoch=14/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 64.98it/s, epoch=15/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 51.97it/s, epoch=16/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:01<00:00, 48.94it/s, epoch=17/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 51.79it/s, epoch=18/30, avg_epoch_loss=4.51]
# 100%|██████████| 50/50 [00:00<00:00, 52.05it/s, epoch=19/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 47.09it/s, epoch=20/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 46.98it/s, epoch=21/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:01<00:00, 42.45it/s, epoch=22/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 44.42it/s, epoch=23/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 44.75it/s, epoch=24/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 60.05it/s, epoch=25/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 74.90it/s, epoch=26/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 75.72it/s, epoch=27/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 74.67it/s, epoch=28/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 73.51it/s, epoch=29/30, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:00<00:00, 76.73it/s, epoch=30/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 66.68it/s, epoch=1/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 75.83it/s, epoch=2/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 76.57it/s, epoch=3/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 73.64it/s, epoch=4/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 74.00it/s, epoch=5/30, avg_epoch_loss=4.69]
# 100%|██████████| 50/50 [00:00<00:00, 75.72it/s, epoch=6/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 74.45it/s, epoch=7/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 50.36it/s, epoch=8/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:01<00:00, 49.43it/s, epoch=9/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 52.68it/s, epoch=10/30, avg_epoch_loss=4.69]
# 100%|██████████| 50/50 [00:00<00:00, 52.78it/s, epoch=11/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 45.37it/s, epoch=12/30, avg_epoch_loss=4.74]
# 100%|██████████| 50/50 [00:00<00:00, 69.77it/s, epoch=13/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 75.54it/s, epoch=14/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 74.37it/s, epoch=15/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 74.85it/s, epoch=16/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 77.22it/s, epoch=17/30, avg_epoch_loss=4.66]
# 100%|██████████| 50/50 [00:00<00:00, 73.10it/s, epoch=18/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 74.74it/s, epoch=19/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 74.95it/s, epoch=20/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 72.85it/s, epoch=21/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 73.42it/s, epoch=22/30, avg_epoch_loss=4.66]
# 100%|██████████| 50/50 [00:00<00:00, 74.37it/s, epoch=23/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 73.19it/s, epoch=24/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 73.70it/s, epoch=25/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 74.62it/s, epoch=26/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 64.65it/s, epoch=27/30, avg_epoch_loss=4.69]
# 100%|██████████| 50/50 [00:00<00:00, 50.81it/s, epoch=28/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 51.13it/s, epoch=29/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 52.19it/s, epoch=30/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:01<00:00, 46.84it/s, epoch=1/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 49.46it/s, epoch=2/30, avg_epoch_loss=4.67]
# 100%|██████████| 50/50 [00:00<00:00, 70.20it/s, epoch=3/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 74.97it/s, epoch=4/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:00<00:00, 66.12it/s, epoch=5/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 72.87it/s, epoch=6/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 77.01it/s, epoch=7/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 76.99it/s, epoch=8/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 72.73it/s, epoch=9/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 74.66it/s, epoch=10/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 77.34it/s, epoch=11/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 74.86it/s, epoch=12/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 74.64it/s, epoch=13/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 74.63it/s, epoch=14/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 73.38it/s, epoch=15/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 71.80it/s, epoch=16/30, avg_epoch_loss=5.96]
# 100%|██████████| 50/50 [00:00<00:00, 55.45it/s, epoch=17/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 51.77it/s, epoch=18/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 52.81it/s, epoch=19/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 50.90it/s, epoch=20/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 48.67it/s, epoch=21/30, avg_epoch_loss=3.1]
# 100%|██████████| 50/50 [00:00<00:00, 56.91it/s, epoch=22/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:00<00:00, 75.09it/s, epoch=23/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 76.04it/s, epoch=24/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 77.77it/s, epoch=25/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 75.29it/s, epoch=26/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 76.31it/s, epoch=27/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 74.87it/s, epoch=28/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 73.67it/s, epoch=29/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.80it/s, epoch=30/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 71.13it/s, epoch=1/30, avg_epoch_loss=4.63]
# 100%|██████████| 50/50 [00:00<00:00, 76.99it/s, epoch=2/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 74.82it/s, epoch=3/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 75.59it/s, epoch=4/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 73.64it/s, epoch=5/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 70.92it/s, epoch=6/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 52.30it/s, epoch=7/30, avg_epoch_loss=5.92]
# 100%|██████████| 50/50 [00:00<00:00, 52.43it/s, epoch=8/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 52.15it/s, epoch=9/30, avg_epoch_loss=4.67]
# 100%|██████████| 50/50 [00:00<00:00, 50.58it/s, epoch=10/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:01<00:00, 45.11it/s, epoch=11/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 68.58it/s, epoch=12/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 72.76it/s, epoch=13/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 71.11it/s, epoch=14/30, avg_epoch_loss=6.04]
# 100%|██████████| 50/50 [00:00<00:00, 75.00it/s, epoch=15/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 74.14it/s, epoch=16/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.97it/s, epoch=17/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:00<00:00, 75.05it/s, epoch=18/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 75.12it/s, epoch=19/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 74.47it/s, epoch=20/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 75.65it/s, epoch=21/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 74.63it/s, epoch=22/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 74.06it/s, epoch=23/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 75.18it/s, epoch=24/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 67.37it/s, epoch=25/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 64.68it/s, epoch=26/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 50.55it/s, epoch=27/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 50.43it/s, epoch=28/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 50.92it/s, epoch=29/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 48.71it/s, epoch=30/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:00<00:00, 50.52it/s, epoch=1/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 76.17it/s, epoch=2/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 73.25it/s, epoch=3/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 75.02it/s, epoch=4/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 74.60it/s, epoch=5/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 73.58it/s, epoch=6/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 73.61it/s, epoch=7/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.54it/s, epoch=8/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 71.60it/s, epoch=9/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 71.83it/s, epoch=10/30, avg_epoch_loss=4.59]
# 100%|██████████| 50/50 [00:00<00:00, 73.45it/s, epoch=11/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 73.68it/s, epoch=12/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 73.30it/s, epoch=13/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 75.54it/s, epoch=14/30, avg_epoch_loss=5.91]
# 100%|██████████| 50/50 [00:00<00:00, 73.41it/s, epoch=15/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 51.49it/s, epoch=16/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 48.90it/s, epoch=17/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:00<00:00, 52.21it/s, epoch=18/30, avg_epoch_loss=4.58]
# ...
# 100%|██████████| 50/50 [00:00<00:00, 50.95it/s, epoch=16/30, avg_epoch_loss=3.8]
# 100%|██████████| 50/50 [00:00<00:00, 52.71it/s, epoch=17/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:01<00:00, 48.51it/s, epoch=18/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:01<00:00, 49.49it/s, epoch=19/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 76.00it/s, epoch=20/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 75.59it/s, epoch=21/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 77.81it/s, epoch=22/30, avg_epoch_loss=5.14]
# 100%|██████████| 50/50 [00:00<00:00, 74.65it/s, epoch=23/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 75.15it/s, epoch=24/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 72.87it/s, epoch=25/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 77.72it/s, epoch=26/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 74.61it/s, epoch=27/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 75.29it/s, epoch=28/30, avg_epoch_loss=6.45]
# 100%|██████████| 50/50 [00:00<00:00, 74.78it/s, epoch=29/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 72.95it/s, epoch=30/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 72.19it/s, epoch=1/30, avg_epoch_loss=5.28]
# 100%|██████████| 50/50 [00:00<00:00, 77.80it/s, epoch=2/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 78.28it/s, epoch=3/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 64.80it/s, epoch=4/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 53.01it/s, epoch=5/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 52.64it/s, epoch=6/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 52.94it/s, epoch=7/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 46.82it/s, epoch=8/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 51.72it/s, epoch=9/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 76.71it/s, epoch=10/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 74.46it/s, epoch=11/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 74.20it/s, epoch=12/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 76.72it/s, epoch=13/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 75.68it/s, epoch=14/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 74.93it/s, epoch=15/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 58.76it/s, epoch=16/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 51.44it/s, epoch=17/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:00<00:00, 52.33it/s, epoch=18/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 52.68it/s, epoch=19/30, avg_epoch_loss=3.96]
# 100%|██████████| 50/50 [00:01<00:00, 48.37it/s, epoch=20/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 54.80it/s, epoch=21/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 53.10it/s, epoch=22/30, avg_epoch_loss=5.18]
# 100%|██████████| 50/50 [00:00<00:00, 51.08it/s, epoch=23/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 51.94it/s, epoch=24/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 52.69it/s, epoch=25/30, avg_epoch_loss=3.96]
# 100%|██████████| 50/50 [00:01<00:00, 48.21it/s, epoch=26/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 61.73it/s, epoch=27/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 73.38it/s, epoch=28/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 75.12it/s, epoch=29/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 73.29it/s, epoch=30/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 70.15it/s, epoch=1/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 74.07it/s, epoch=2/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 74.96it/s, epoch=3/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 75.76it/s, epoch=4/30, avg_epoch_loss=5.32]
# 100%|██████████| 50/50 [00:00<00:00, 75.02it/s, epoch=5/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 72.77it/s, epoch=6/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 74.37it/s, epoch=7/30, avg_epoch_loss=3.96]
# 100%|██████████| 50/50 [00:00<00:00, 75.62it/s, epoch=8/30, avg_epoch_loss=3.79]
# 100%|██████████| 50/50 [00:00<00:00, 74.91it/s, epoch=9/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 73.87it/s, epoch=10/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 73.06it/s, epoch=11/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 51.81it/s, epoch=12/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 52.56it/s, epoch=13/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 53.08it/s, epoch=14/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 52.89it/s, epoch=15/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 47.41it/s, epoch=16/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 66.41it/s, epoch=17/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 75.79it/s, epoch=18/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:00<00:00, 71.40it/s, epoch=19/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 71.79it/s, epoch=20/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 75.87it/s, epoch=21/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 77.13it/s, epoch=22/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 76.20it/s, epoch=23/30, avg_epoch_loss=3.8]
# 100%|██████████| 50/50 [00:00<00:00, 75.50it/s, epoch=24/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 76.85it/s, epoch=25/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 74.27it/s, epoch=26/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 75.03it/s, epoch=27/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 77.18it/s, epoch=28/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 77.51it/s, epoch=29/30, avg_epoch_loss=5.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.66it/s, epoch=30/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 66.84it/s, epoch=1/30, avg_epoch_loss=4.01]
# 100%|██████████| 50/50 [00:00<00:00, 52.31it/s, epoch=2/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 52.24it/s, epoch=3/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:00<00:00, 50.88it/s, epoch=4/30, avg_epoch_loss=3.97]
# 100%|██████████| 50/50 [00:00<00:00, 50.50it/s, epoch=5/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:01<00:00, 47.17it/s, epoch=6/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 72.15it/s, epoch=7/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 76.74it/s, epoch=8/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 76.60it/s, epoch=9/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 75.35it/s, epoch=10/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 75.50it/s, epoch=11/30, avg_epoch_loss=5.14]
# 100%|██████████| 50/50 [00:00<00:00, 77.42it/s, epoch=12/30, avg_epoch_loss=5.19]
# 100%|██████████| 50/50 [00:00<00:00, 76.68it/s, epoch=13/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 77.61it/s, epoch=14/30, avg_epoch_loss=5.22]
# 100%|██████████| 50/50 [00:00<00:00, 75.51it/s, epoch=15/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 75.00it/s, epoch=16/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 72.31it/s, epoch=17/30, avg_epoch_loss=5.21]
# 100%|██████████| 50/50 [00:00<00:00, 74.18it/s, epoch=18/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 74.53it/s, epoch=19/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 73.85it/s, epoch=20/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 69.25it/s, epoch=21/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 51.79it/s, epoch=22/30, avg_epoch_loss=3.96]
# 100%|██████████| 50/50 [00:00<00:00, 52.63it/s, epoch=23/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:00<00:00, 52.66it/s, epoch=24/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 52.23it/s, epoch=25/30, avg_epoch_loss=3.78]
# 100%|██████████| 50/50 [00:01<00:00, 46.90it/s, epoch=26/30, avg_epoch_loss=3.98]
# 100%|██████████| 50/50 [00:00<00:00, 65.92it/s, epoch=27/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 75.38it/s, epoch=28/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 75.45it/s, epoch=29/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:00<00:00, 76.38it/s, epoch=30/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 71.98it/s, epoch=1/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 74.22it/s, epoch=2/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 76.03it/s, epoch=3/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 75.85it/s, epoch=4/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 72.74it/s, epoch=5/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 74.38it/s, epoch=6/30, avg_epoch_loss=5.29]
# 100%|██████████| 50/50 [00:00<00:00, 74.50it/s, epoch=7/30, avg_epoch_loss=5.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.27it/s, epoch=8/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 75.29it/s, epoch=9/30, avg_epoch_loss=3.8]
# 100%|██████████| 50/50 [00:00<00:00, 75.70it/s, epoch=10/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 70.60it/s, epoch=11/30, avg_epoch_loss=5.24]
# 100%|██████████| 50/50 [00:00<00:00, 51.64it/s, epoch=12/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 50.06it/s, epoch=13/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 52.41it/s, epoch=14/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 52.41it/s, epoch=15/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:01<00:00, 48.01it/s, epoch=16/30, avg_epoch_loss=3.76]
# 100%|██████████| 50/50 [00:00<00:00, 64.66it/s, epoch=17/30, avg_epoch_loss=5.3]
# 100%|██████████| 50/50 [00:00<00:00, 77.98it/s, epoch=18/30, avg_epoch_loss=5.17]
# 100%|██████████| 50/50 [00:00<00:00, 74.97it/s, epoch=19/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 75.78it/s, epoch=20/30, avg_epoch_loss=5.27]
# 100%|██████████| 50/50 [00:00<00:00, 77.50it/s, epoch=21/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 76.29it/s, epoch=22/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 77.96it/s, epoch=23/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 76.84it/s, epoch=24/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 75.03it/s, epoch=25/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 74.07it/s, epoch=26/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 74.54it/s, epoch=27/30, avg_epoch_loss=3.97]
# 100%|██████████| 50/50 [00:00<00:00, 74.41it/s, epoch=28/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 77.18it/s, epoch=29/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 75.04it/s, epoch=30/30, avg_epoch_loss=3.8]
# 100%|██████████| 50/50 [00:00<00:00, 65.85it/s, epoch=1/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 52.24it/s, epoch=2/30, avg_epoch_loss=3.77]
# 100%|██████████| 50/50 [00:00<00:00, 52.25it/s, epoch=3/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 50.56it/s, epoch=4/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 51.50it/s, epoch=5/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:01<00:00, 47.17it/s, epoch=6/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 64.87it/s, epoch=7/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 75.85it/s, epoch=8/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 74.50it/s, epoch=9/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 75.06it/s, epoch=10/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 75.61it/s, epoch=11/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 76.50it/s, epoch=12/30, avg_epoch_loss=3.76]
# 100%|██████████| 50/50 [00:00<00:00, 75.66it/s, epoch=13/30, avg_epoch_loss=5.07]
# 100%|██████████| 50/50 [00:00<00:00, 75.23it/s, epoch=14/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 72.93it/s, epoch=15/30, avg_epoch_loss=5.16]
# 100%|██████████| 50/50 [00:00<00:00, 74.30it/s, epoch=16/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 76.72it/s, epoch=17/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 73.22it/s, epoch=18/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 73.36it/s, epoch=19/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 73.22it/s, epoch=20/30, avg_epoch_loss=5.17]
# 100%|██████████| 50/50 [00:00<00:00, 64.54it/s, epoch=21/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 53.04it/s, epoch=22/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 51.58it/s, epoch=23/30, avg_epoch_loss=5.11]
# 100%|██████████| 50/50 [00:00<00:00, 52.07it/s, epoch=24/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 51.51it/s, epoch=25/30, avg_epoch_loss=6.49]
# 100%|██████████| 50/50 [00:01<00:00, 46.09it/s, epoch=26/30, avg_epoch_loss=5.2]
# 100%|██████████| 50/50 [00:00<00:00, 70.03it/s, epoch=27/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 72.35it/s, epoch=28/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 72.29it/s, epoch=29/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 72.48it/s, epoch=30/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 70.89it/s, epoch=1/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 72.85it/s, epoch=2/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 72.88it/s, epoch=3/30, avg_epoch_loss=5.22]
# 100%|██████████| 50/50 [00:00<00:00, 74.99it/s, epoch=4/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 75.28it/s, epoch=5/30, avg_epoch_loss=5.26]
# 100%|██████████| 50/50 [00:00<00:00, 75.02it/s, epoch=6/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 74.31it/s, epoch=7/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 74.11it/s, epoch=8/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:00<00:00, 74.23it/s, epoch=9/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 73.40it/s, epoch=10/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 55.97it/s, epoch=11/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 50.84it/s, epoch=12/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:01<00:00, 49.27it/s, epoch=13/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:01<00:00, 46.49it/s, epoch=14/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:01<00:00, 47.08it/s, epoch=15/30, avg_epoch_loss=5.15]
# 100%|██████████| 50/50 [00:00<00:00, 61.91it/s, epoch=16/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 72.11it/s, epoch=17/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 73.93it/s, epoch=18/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 72.99it/s, epoch=19/30, avg_epoch_loss=3.96]
# 100%|██████████| 50/50 [00:00<00:00, 74.90it/s, epoch=20/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 73.65it/s, epoch=21/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 72.34it/s, epoch=22/30, avg_epoch_loss=3.8]
# 100%|██████████| 50/50 [00:00<00:00, 72.50it/s, epoch=23/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 73.03it/s, epoch=24/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 71.19it/s, epoch=25/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 72.84it/s, epoch=26/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 74.26it/s, epoch=27/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 73.98it/s, epoch=28/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 72.98it/s, epoch=29/30, avg_epoch_loss=5.3]
# 100%|██████████| 50/50 [00:00<00:00, 63.43it/s, epoch=30/30, avg_epoch_loss=6.63]
# ROG: 17.08958064436013

# %% [markdown]
# MACROS + STOCKS

# %%
all = data.copy()

for m in ['GDP_growth',	'SP500_return',	'inflation_change',	'unemp_change',	'treasury_yield_change']:
  all[f'{m}_lag'] = all[m].shift(1)
  all[f'{m}_lag2'] = all[m].shift(2)
  all[f'{m}_lag3'] = all[m].shift(3)


all['Quater_dummy'] = 0
all['Quater_rippel'] = 0
all['Date'] = pd.to_datetime(all['Date'])
for index, row in all.iterrows():
    date = pd.to_datetime(row['Date'])  # Convert the date string to datetime type
    if date.month in [3, 6, 9, 12]:
        all.loc[index, 'Quater_dummy'] = 1
    if date.month in [1, 4, 7, 10]:
        all.loc[index, 'Quater_rippel'] = 1


for t in tickers:
  all[f'{t}_lag'] = all[t].shift(1)
  all[f'{t}_lag2'] = all[t].shift(2)

# %%
all = format(all)

# %%
def data_prep(df, ticker):
    train_data = ListDataset(
        [
            {
                "start": df.index[0],
                "target": df[ticker].values,
                "dynamic_feat": [
                              df['GDP_growth_lag'].values,
                              df['GDP_growth_lag2'].values,
                              df['GDP_growth_lag3'].values,
                              df['SP500_return_lag'].values,
                              df['SP500_return_lag2'].values,
                              df['SP500_return_lag3'].values,
                              df['inflation_change_lag'].values,
                              df['inflation_change_lag2'].values,
                              df['inflation_change_lag3'].values,
                              df['unemp_change_lag'].values,
                              df['unemp_change_lag2'].values,
                              df['unemp_change_lag3'].values,
                              df['treasury_yield_change_lag'].values,
                              df['treasury_yield_change_lag2'].values,
                              df['treasury_yield_change_lag3'].values,
                              df['NVS_lag'].values,
                              df['NVS_lag2'].values,
                              df['AZN_lag'].values,
                              df['AZN_lag2'].values,
                              df['BMY_lag'].values,
                              df['BMY_lag2'].values,
                              df['JNJ_lag'].values,
                              df['JNJ_lag2'].values,
                              df['LLY_lag'].values,
                              df['LLY_lag2'].values,
                              df['MRK_lag'].values,
                              df['MRK_lag2'].values,
                              df['NVO_lag'].values,
                              df['NVO_lag2'].values,
                              df['PFE_lag'].values,
                              df['PFE_lag2'].values,
                              df['ROG_lag'].values,
                              df['ROG_lag2'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    test_data = ListDataset(
        [
            {
                "start": df.index[-3],
                "target": df[ticker][-3:].values,
                "dynamic_feat": [
                              df['GDP_growth_lag'].values,
                              df['GDP_growth_lag2'].values,
                              df['GDP_growth_lag3'].values,
                              df['SP500_return_lag'].values,
                              df['SP500_return_lag2'].values,
                              df['SP500_return_lag3'].values,
                              df['inflation_change_lag'].values,
                              df['inflation_change_lag2'].values,
                              df['inflation_change_lag3'].values,
                              df['unemp_change_lag'].values,
                              df['unemp_change_lag2'].values,
                              df['unemp_change_lag3'].values,
                              df['treasury_yield_change_lag'].values,
                              df['treasury_yield_change_lag2'].values,
                              df['treasury_yield_change_lag3'].values,
                              df['NVS_lag'].values,
                              df['NVS_lag2'].values,
                              df['AZN_lag'].values,
                              df['AZN_lag2'].values,
                              df['BMY_lag'].values,
                              df['BMY_lag2'].values,
                              df['JNJ_lag'].values,
                              df['JNJ_lag2'].values,
                              df['LLY_lag'].values,
                              df['LLY_lag2'].values,
                              df['MRK_lag'].values,
                              df['MRK_lag2'].values,
                              df['NVO_lag'].values,
                              df['NVO_lag2'].values,
                              df['PFE_lag'].values,
                              df['PFE_lag2'].values,
                              df['ROG_lag'].values,
                              df['ROG_lag2'].values,
                              df['Quater_dummy'].values,
                              df['Quater_rippel'].values
                ]
            }
        ],
        freq="M"
    )

    return train_data, test_data

# %%
def get_performance(ticker, dates):

  dta = all.copy()
  t_loss = 0

  for d in dates:
    split_date = d
    train_df = dta[dta.index <= split_date]
    test_df = dta[dta.index > split_date]

    train, test = data_prep(train_df, ticker)
    predictions, check = fit_n_predict(estimator, train, test)
    p95 = np.percentile(predictions, 95, axis=0)
    p50 = np.percentile(predictions, 50, axis=0)
    p5 = np.percentile(predictions, 5, axis=0)

    var  = pd.Series(p5)
    agg = test_df[ticker]
    r = agg.values
    r = r[0:3]
    r = pd.Series(r)
    t_loss += tick_loss(0.05, r, var)

  t_loss = t_loss/10

  return t_loss

# %%
#for t in ['NVS', 'AZN', 'BMY']:
#for t in ['JNJ', 'LLY', 'MRK']:
for t in ['NVO', 'PFE', 'ROG']:
  loss = get_performance(t, dates3m)
  print(f'{t}: {loss}')
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 75.47it/s, epoch=1/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 80.32it/s, epoch=2/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 73.56it/s, epoch=3/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 55.68it/s, epoch=4/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 56.83it/s, epoch=5/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 58.30it/s, epoch=6/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 57.84it/s, epoch=7/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 54.86it/s, epoch=8/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 53.27it/s, epoch=9/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 79.70it/s, epoch=10/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 82.40it/s, epoch=11/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 79.20it/s, epoch=12/30, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:00<00:00, 81.06it/s, epoch=13/30, avg_epoch_loss=3.06]
# 100%|██████████| 50/50 [00:00<00:00, 83.45it/s, epoch=14/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 81.29it/s, epoch=15/30, avg_epoch_loss=3.01]
# 100%|██████████| 50/50 [00:00<00:00, 80.51it/s, epoch=16/30, avg_epoch_loss=4.33]
# 100%|██████████| 50/50 [00:00<00:00, 75.08it/s, epoch=17/30, avg_epoch_loss=3.1]
# 100%|██████████| 50/50 [00:00<00:00, 82.08it/s, epoch=18/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:00<00:00, 81.85it/s, epoch=19/30, avg_epoch_loss=3.03]
# 100%|██████████| 50/50 [00:00<00:00, 81.14it/s, epoch=20/30, avg_epoch_loss=3.09]
# 100%|██████████| 50/50 [00:00<00:00, 80.83it/s, epoch=21/30, avg_epoch_loss=2.98]
# 100%|██████████| 50/50 [00:00<00:00, 82.45it/s, epoch=22/30, avg_epoch_loss=2.98]
# 100%|██████████| 50/50 [00:00<00:00, 82.28it/s, epoch=23/30, avg_epoch_loss=2.92]
# 100%|██████████| 50/50 [00:00<00:00, 83.49it/s, epoch=24/30, avg_epoch_loss=4.02]
# 100%|██████████| 50/50 [00:00<00:00, 73.14it/s, epoch=25/30, avg_epoch_loss=2.82]
# 100%|██████████| 50/50 [00:00<00:00, 56.40it/s, epoch=26/30, avg_epoch_loss=2.84]
# 100%|██████████| 50/50 [00:00<00:00, 54.66it/s, epoch=27/30, avg_epoch_loss=3.78]
# 100%|██████████| 50/50 [00:00<00:00, 56.42it/s, epoch=28/30, avg_epoch_loss=3.68]
# 100%|██████████| 50/50 [00:00<00:00, 55.54it/s, epoch=29/30, avg_epoch_loss=2.77]
# 100%|██████████| 50/50 [00:00<00:00, 53.06it/s, epoch=30/30, avg_epoch_loss=2.74]
# 100%|██████████| 50/50 [00:00<00:00, 62.72it/s, epoch=1/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 80.65it/s, epoch=2/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 83.23it/s, epoch=3/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 80.52it/s, epoch=4/30, avg_epoch_loss=4.69]
# 100%|██████████| 50/50 [00:00<00:00, 78.88it/s, epoch=5/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 81.13it/s, epoch=6/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 81.87it/s, epoch=7/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 82.03it/s, epoch=8/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 78.47it/s, epoch=9/30, avg_epoch_loss=4.45]
# 100%|██████████| 50/50 [00:00<00:00, 77.94it/s, epoch=10/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 82.89it/s, epoch=11/30, avg_epoch_loss=3.14]
# 100%|██████████| 50/50 [00:00<00:00, 80.15it/s, epoch=12/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 80.44it/s, epoch=13/30, avg_epoch_loss=3.13]
# 100%|██████████| 50/50 [00:00<00:00, 79.28it/s, epoch=14/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 79.51it/s, epoch=15/30, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 79.57it/s, epoch=16/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:00<00:00, 57.02it/s, epoch=17/30, avg_epoch_loss=3.14]
# 100%|██████████| 50/50 [00:00<00:00, 55.00it/s, epoch=18/30, avg_epoch_loss=3.01]
# 100%|██████████| 50/50 [00:00<00:00, 54.91it/s, epoch=19/30, avg_epoch_loss=3.03]
# 100%|██████████| 50/50 [00:00<00:00, 54.95it/s, epoch=20/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:00<00:00, 50.50it/s, epoch=21/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:00<00:00, 56.36it/s, epoch=22/30, avg_epoch_loss=3.08]
# 100%|██████████| 50/50 [00:00<00:00, 79.75it/s, epoch=23/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:00<00:00, 53.80it/s, epoch=24/30, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:00<00:00, 54.16it/s, epoch=25/30, avg_epoch_loss=2.95]
# 100%|██████████| 50/50 [00:00<00:00, 57.45it/s, epoch=26/30, avg_epoch_loss=3.02]
# 100%|██████████| 50/50 [00:00<00:00, 67.83it/s, epoch=27/30, avg_epoch_loss=2.93]
# 100%|██████████| 50/50 [00:00<00:00, 75.26it/s, epoch=28/30, avg_epoch_loss=2.97]
# 100%|██████████| 50/50 [00:00<00:00, 78.76it/s, epoch=29/30, avg_epoch_loss=3.07]
# 100%|██████████| 50/50 [00:00<00:00, 75.52it/s, epoch=30/30, avg_epoch_loss=3.04]
# 100%|██████████| 50/50 [00:00<00:00, 71.70it/s, epoch=1/30, avg_epoch_loss=3.45]
# 100%|██████████| 50/50 [00:00<00:00, 77.63it/s, epoch=2/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 80.97it/s, epoch=3/30, avg_epoch_loss=4.36]
# 100%|██████████| 50/50 [00:00<00:00, 75.64it/s, epoch=4/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 80.02it/s, epoch=5/30, avg_epoch_loss=4.41]
# 100%|██████████| 50/50 [00:00<00:00, 60.43it/s, epoch=6/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 55.79it/s, epoch=7/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 55.89it/s, epoch=8/30, avg_epoch_loss=4.38]
# 100%|██████████| 50/50 [00:00<00:00, 54.93it/s, epoch=9/30, avg_epoch_loss=4.29]
# 100%|██████████| 50/50 [00:00<00:00, 50.91it/s, epoch=10/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:01<00:00, 49.99it/s, epoch=11/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 77.24it/s, epoch=12/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 73.97it/s, epoch=13/30, avg_epoch_loss=4.28]
# 100%|██████████| 50/50 [00:00<00:00, 79.41it/s, epoch=14/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 78.55it/s, epoch=15/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 77.32it/s, epoch=16/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 77.01it/s, epoch=17/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 77.05it/s, epoch=18/30, avg_epoch_loss=4.33]
# 100%|██████████| 50/50 [00:00<00:00, 78.28it/s, epoch=19/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 79.62it/s, epoch=20/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 76.37it/s, epoch=21/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 78.69it/s, epoch=22/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 76.99it/s, epoch=23/30, avg_epoch_loss=4.39]
# 100%|██████████| 50/50 [00:00<00:00, 75.71it/s, epoch=24/30, avg_epoch_loss=4.31]
# 100%|██████████| 50/50 [00:00<00:00, 75.17it/s, epoch=25/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 75.74it/s, epoch=26/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 53.80it/s, epoch=27/30, avg_epoch_loss=5.28]
# 100%|██████████| 50/50 [00:00<00:00, 51.39it/s, epoch=28/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 53.84it/s, epoch=29/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 51.66it/s, epoch=30/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:01<00:00, 44.81it/s, epoch=1/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 70.98it/s, epoch=2/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 79.71it/s, epoch=3/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 76.54it/s, epoch=4/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:00<00:00, 71.59it/s, epoch=5/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 79.27it/s, epoch=6/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 74.58it/s, epoch=7/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:00<00:00, 75.16it/s, epoch=8/30, avg_epoch_loss=4.67]
# 100%|██████████| 50/50 [00:00<00:00, 77.24it/s, epoch=9/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 75.38it/s, epoch=10/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 75.77it/s, epoch=11/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 80.55it/s, epoch=12/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 77.21it/s, epoch=13/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 73.71it/s, epoch=14/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 77.50it/s, epoch=15/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 74.43it/s, epoch=16/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 55.67it/s, epoch=17/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 52.68it/s, epoch=18/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 53.55it/s, epoch=19/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 51.89it/s, epoch=20/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:01<00:00, 49.40it/s, epoch=21/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 59.05it/s, epoch=22/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 78.18it/s, epoch=23/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 77.17it/s, epoch=24/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 77.72it/s, epoch=25/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 77.61it/s, epoch=26/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 76.43it/s, epoch=27/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 76.10it/s, epoch=28/30, avg_epoch_loss=5.91]
# 100%|██████████| 50/50 [00:00<00:00, 78.62it/s, epoch=29/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:00<00:00, 77.31it/s, epoch=30/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 75.81it/s, epoch=1/30, avg_epoch_loss=4.49]
# 100%|██████████| 50/50 [00:00<00:00, 78.21it/s, epoch=2/30, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:00<00:00, 77.78it/s, epoch=3/30, avg_epoch_loss=5.55]
# 100%|██████████| 50/50 [00:00<00:00, 75.35it/s, epoch=4/30, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:00<00:00, 73.58it/s, epoch=5/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 73.86it/s, epoch=6/30, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:00<00:00, 64.92it/s, epoch=7/30, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:00<00:00, 52.07it/s, epoch=8/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 51.83it/s, epoch=9/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 51.19it/s, epoch=10/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:01<00:00, 48.18it/s, epoch=11/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 53.67it/s, epoch=12/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 80.45it/s, epoch=13/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 80.88it/s, epoch=14/30, avg_epoch_loss=3.46]
# 100%|██████████| 50/50 [00:00<00:00, 77.98it/s, epoch=15/30, avg_epoch_loss=4.43]
# 100%|██████████| 50/50 [00:00<00:00, 75.80it/s, epoch=16/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 76.89it/s, epoch=17/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 76.87it/s, epoch=18/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 79.19it/s, epoch=19/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:00<00:00, 76.52it/s, epoch=20/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 76.41it/s, epoch=21/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 78.24it/s, epoch=22/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 79.12it/s, epoch=23/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 78.21it/s, epoch=24/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 80.83it/s, epoch=25/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 75.41it/s, epoch=26/30, avg_epoch_loss=4.53]
# 100%|██████████| 50/50 [00:00<00:00, 76.22it/s, epoch=27/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 51.82it/s, epoch=28/30, avg_epoch_loss=3.49]
# 100%|██████████| 50/50 [00:00<00:00, 52.70it/s, epoch=29/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 52.07it/s, epoch=30/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 47.89it/s, epoch=1/30, avg_epoch_loss=3.5]
# 100%|██████████| 50/50 [00:01<00:00, 48.88it/s, epoch=2/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 70.94it/s, epoch=3/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 77.98it/s, epoch=4/30, avg_epoch_loss=4.75]
# 100%|██████████| 50/50 [00:00<00:00, 75.72it/s, epoch=5/30, avg_epoch_loss=3.46]
# 100%|██████████| 50/50 [00:00<00:00, 80.29it/s, epoch=6/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 79.29it/s, epoch=7/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 78.68it/s, epoch=8/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:00<00:00, 75.58it/s, epoch=9/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 78.81it/s, epoch=10/30, avg_epoch_loss=3.46]
# 100%|██████████| 50/50 [00:00<00:00, 81.01it/s, epoch=11/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 77.21it/s, epoch=12/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 79.31it/s, epoch=13/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 78.42it/s, epoch=14/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 77.82it/s, epoch=15/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 78.65it/s, epoch=16/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 81.63it/s, epoch=17/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 64.55it/s, epoch=18/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 54.84it/s, epoch=19/30, avg_epoch_loss=4.68]
# 100%|██████████| 50/50 [00:00<00:00, 52.76it/s, epoch=20/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 50.68it/s, epoch=21/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 49.33it/s, epoch=22/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 53.23it/s, epoch=23/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 77.20it/s, epoch=24/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 80.80it/s, epoch=25/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 75.31it/s, epoch=26/30, avg_epoch_loss=3.48]
# 100%|██████████| 50/50 [00:00<00:00, 76.25it/s, epoch=27/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 79.94it/s, epoch=28/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 79.42it/s, epoch=29/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 77.76it/s, epoch=30/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 73.62it/s, epoch=1/30, avg_epoch_loss=4.63]
# 100%|██████████| 50/50 [00:00<00:00, 80.57it/s, epoch=2/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 81.80it/s, epoch=3/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 76.39it/s, epoch=4/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 76.16it/s, epoch=5/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 80.34it/s, epoch=6/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 80.65it/s, epoch=7/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 75.34it/s, epoch=8/30, avg_epoch_loss=3.47]
# 100%|██████████| 50/50 [00:00<00:00, 55.04it/s, epoch=9/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 54.44it/s, epoch=10/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 55.55it/s, epoch=11/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 55.13it/s, epoch=12/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 52.02it/s, epoch=13/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 56.91it/s, epoch=14/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 80.87it/s, epoch=15/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 79.76it/s, epoch=16/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 81.68it/s, epoch=17/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 80.63it/s, epoch=18/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 79.64it/s, epoch=19/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 80.37it/s, epoch=20/30, avg_epoch_loss=3.51]
# 100%|██████████| 50/50 [00:00<00:00, 77.75it/s, epoch=21/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 77.39it/s, epoch=22/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 80.45it/s, epoch=23/30, avg_epoch_loss=4.59]
# 100%|██████████| 50/50 [00:00<00:00, 80.75it/s, epoch=24/30, avg_epoch_loss=3.45]
# 100%|██████████| 50/50 [00:00<00:00, 80.09it/s, epoch=25/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 80.86it/s, epoch=26/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 80.71it/s, epoch=27/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 81.86it/s, epoch=28/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 79.34it/s, epoch=29/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 62.81it/s, epoch=30/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 50.65it/s, epoch=1/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 57.11it/s, epoch=2/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 54.18it/s, epoch=3/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 52.85it/s, epoch=4/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:01<00:00, 48.13it/s, epoch=5/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 52.76it/s, epoch=6/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 53.69it/s, epoch=7/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 53.88it/s, epoch=8/30, avg_epoch_loss=4.5]
# 100%|██████████| 50/50 [00:00<00:00, 54.96it/s, epoch=9/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:00<00:00, 50.13it/s, epoch=10/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 65.11it/s, epoch=11/30, avg_epoch_loss=4.52]
# 100%|██████████| 50/50 [00:00<00:00, 79.98it/s, epoch=12/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 81.76it/s, epoch=13/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 79.73it/s, epoch=14/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 79.81it/s, epoch=15/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 79.03it/s, epoch=16/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 77.16it/s, epoch=17/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 77.31it/s, epoch=18/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 56.52it/s, epoch=19/30, avg_epoch_loss=3.47]
# 100%|██████████| 50/50 [00:00<00:00, 55.66it/s, epoch=20/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 55.17it/s, epoch=21/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 54.16it/s, epoch=22/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:01<00:00, 49.48it/s, epoch=23/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:00<00:00, 58.31it/s, epoch=24/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 79.68it/s, epoch=25/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 78.33it/s, epoch=26/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 80.16it/s, epoch=27/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 79.44it/s, epoch=28/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 78.93it/s, epoch=29/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 74.22it/s, epoch=30/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 73.30it/s, epoch=1/30, avg_epoch_loss=3.55]
# 100%|██████████| 50/50 [00:00<00:00, 78.87it/s, epoch=2/30, avg_epoch_loss=3.46]
# 100%|██████████| 50/50 [00:00<00:00, 79.90it/s, epoch=3/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 78.54it/s, epoch=4/30, avg_epoch_loss=3.44]
# 100%|██████████| 50/50 [00:00<00:00, 78.92it/s, epoch=5/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 79.73it/s, epoch=6/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 77.61it/s, epoch=7/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 80.65it/s, epoch=8/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:00<00:00, 75.73it/s, epoch=9/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 55.39it/s, epoch=10/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 54.93it/s, epoch=11/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 55.33it/s, epoch=12/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 55.23it/s, epoch=13/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 50.89it/s, epoch=14/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 58.04it/s, epoch=15/30, avg_epoch_loss=3.46]
# 100%|██████████| 50/50 [00:00<00:00, 77.69it/s, epoch=16/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 79.54it/s, epoch=17/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 80.19it/s, epoch=18/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 80.58it/s, epoch=19/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 78.05it/s, epoch=20/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 76.32it/s, epoch=21/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 74.59it/s, epoch=22/30, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:00<00:00, 77.53it/s, epoch=23/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 78.88it/s, epoch=24/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 79.96it/s, epoch=25/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 77.72it/s, epoch=26/30, avg_epoch_loss=3.43]
# 100%|██████████| 50/50 [00:00<00:00, 76.71it/s, epoch=27/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 78.78it/s, epoch=28/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 78.16it/s, epoch=29/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 75.78it/s, epoch=30/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 50.64it/s, epoch=1/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 54.69it/s, epoch=2/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 55.19it/s, epoch=3/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 54.58it/s, epoch=4/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 51.31it/s, epoch=5/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 63.89it/s, epoch=6/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 80.23it/s, epoch=7/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 76.06it/s, epoch=8/30, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:00<00:00, 80.90it/s, epoch=9/30, avg_epoch_loss=3.47]
# 100%|██████████| 50/50 [00:00<00:00, 79.25it/s, epoch=10/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 78.59it/s, epoch=11/30, avg_epoch_loss=4.5]
# 100%|██████████| 50/50 [00:00<00:00, 78.29it/s, epoch=12/30, avg_epoch_loss=4.45]
# 100%|██████████| 50/50 [00:00<00:00, 79.06it/s, epoch=13/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 76.47it/s, epoch=14/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 80.68it/s, epoch=15/30, avg_epoch_loss=4.51]
# 100%|██████████| 50/50 [00:00<00:00, 78.39it/s, epoch=16/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 78.40it/s, epoch=17/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 79.39it/s, epoch=18/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 79.60it/s, epoch=19/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 80.53it/s, epoch=20/30, avg_epoch_loss=3.42]
# 100%|██████████| 50/50 [00:00<00:00, 72.82it/s, epoch=21/30, avg_epoch_loss=3.41]
# 100%|██████████| 50/50 [00:00<00:00, 53.73it/s, epoch=22/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 52.63it/s, epoch=23/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 55.48it/s, epoch=24/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 54.01it/s, epoch=25/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:01<00:00, 48.51it/s, epoch=26/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 67.43it/s, epoch=27/30, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [00:00<00:00, 79.28it/s, epoch=28/30, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [00:00<00:00, 79.58it/s, epoch=29/30, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:00<00:00, 76.51it/s, epoch=30/30, avg_epoch_loss=3.36]
# NVO: 3.638091015290309
# 100%|██████████| 50/50 [00:00<00:00, 72.69it/s, epoch=1/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 77.01it/s, epoch=2/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 77.48it/s, epoch=3/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 77.68it/s, epoch=4/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 80.26it/s, epoch=5/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 81.38it/s, epoch=6/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:00<00:00, 75.40it/s, epoch=7/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 79.54it/s, epoch=8/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 74.20it/s, epoch=9/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 79.90it/s, epoch=10/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 81.42it/s, epoch=11/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 61.36it/s, epoch=12/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 57.45it/s, epoch=13/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 55.18it/s, epoch=14/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 55.28it/s, epoch=15/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 50.44it/s, epoch=16/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 50.01it/s, epoch=17/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 77.90it/s, epoch=18/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 75.10it/s, epoch=19/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 71.27it/s, epoch=20/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 79.80it/s, epoch=21/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 78.06it/s, epoch=22/30, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:00<00:00, 77.95it/s, epoch=23/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 78.98it/s, epoch=24/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.14it/s, epoch=25/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 75.83it/s, epoch=26/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 79.28it/s, epoch=27/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 76.73it/s, epoch=28/30, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:00<00:00, 80.70it/s, epoch=29/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 78.61it/s, epoch=30/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 72.49it/s, epoch=1/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 77.57it/s, epoch=2/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 55.33it/s, epoch=3/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 54.58it/s, epoch=4/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:00<00:00, 54.75it/s, epoch=5/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 53.48it/s, epoch=6/30, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:00<00:00, 50.97it/s, epoch=7/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:00<00:00, 59.59it/s, epoch=8/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 74.15it/s, epoch=9/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 74.44it/s, epoch=10/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 75.63it/s, epoch=11/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 79.69it/s, epoch=12/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 79.07it/s, epoch=13/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 81.56it/s, epoch=14/30, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:00<00:00, 77.44it/s, epoch=15/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 78.91it/s, epoch=16/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 74.43it/s, epoch=17/30, avg_epoch_loss=4.47]
# 100%|██████████| 50/50 [00:00<00:00, 78.99it/s, epoch=18/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 79.54it/s, epoch=19/30, avg_epoch_loss=4.5]
# 100%|██████████| 50/50 [00:00<00:00, 77.86it/s, epoch=20/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 79.54it/s, epoch=21/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 75.55it/s, epoch=22/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 71.72it/s, epoch=23/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 55.49it/s, epoch=24/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 53.39it/s, epoch=25/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 53.49it/s, epoch=26/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 54.35it/s, epoch=27/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:01<00:00, 49.43it/s, epoch=28/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 64.37it/s, epoch=29/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 79.40it/s, epoch=30/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 73.61it/s, epoch=1/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 78.76it/s, epoch=2/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 78.74it/s, epoch=3/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 72.68it/s, epoch=4/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 77.23it/s, epoch=5/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 80.20it/s, epoch=6/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 76.18it/s, epoch=7/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 77.34it/s, epoch=8/30, avg_epoch_loss=3.09]
# 100%|██████████| 50/50 [00:00<00:00, 81.92it/s, epoch=9/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 80.59it/s, epoch=10/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 78.70it/s, epoch=11/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 80.82it/s, epoch=12/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 78.65it/s, epoch=13/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 65.40it/s, epoch=14/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 55.07it/s, epoch=15/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 53.89it/s, epoch=16/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 55.57it/s, epoch=17/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 53.65it/s, epoch=18/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:01<00:00, 48.95it/s, epoch=19/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 74.55it/s, epoch=20/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 77.94it/s, epoch=21/30, avg_epoch_loss=3.11]
# 100%|██████████| 50/50 [00:00<00:00, 78.73it/s, epoch=22/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 76.55it/s, epoch=23/30, avg_epoch_loss=5.9]
# 100%|██████████| 50/50 [00:00<00:00, 75.28it/s, epoch=24/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:00<00:00, 76.86it/s, epoch=25/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 76.36it/s, epoch=26/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 78.45it/s, epoch=27/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 74.15it/s, epoch=28/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 71.07it/s, epoch=29/30, avg_epoch_loss=4.53]
# 100%|██████████| 50/50 [00:00<00:00, 76.57it/s, epoch=30/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 72.27it/s, epoch=1/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 78.01it/s, epoch=2/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 78.64it/s, epoch=3/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 73.48it/s, epoch=4/30, avg_epoch_loss=4.52]
# 100%|██████████| 50/50 [00:00<00:00, 50.63it/s, epoch=5/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 51.83it/s, epoch=6/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 54.78it/s, epoch=7/30, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:00<00:00, 51.30it/s, epoch=8/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 47.22it/s, epoch=9/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 70.09it/s, epoch=10/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 77.68it/s, epoch=11/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 76.86it/s, epoch=12/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 76.73it/s, epoch=13/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 75.32it/s, epoch=14/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 75.04it/s, epoch=15/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 73.56it/s, epoch=16/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 74.66it/s, epoch=17/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 75.67it/s, epoch=18/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 75.23it/s, epoch=19/30, avg_epoch_loss=4.44]
# 100%|██████████| 50/50 [00:00<00:00, 75.42it/s, epoch=20/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 76.25it/s, epoch=21/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 74.89it/s, epoch=22/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 72.86it/s, epoch=23/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 77.18it/s, epoch=24/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 55.28it/s, epoch=25/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 52.05it/s, epoch=26/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 53.50it/s, epoch=27/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 52.42it/s, epoch=28/30, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:01<00:00, 47.97it/s, epoch=29/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 61.32it/s, epoch=30/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 71.54it/s, epoch=1/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 76.32it/s, epoch=2/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 76.65it/s, epoch=3/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 72.68it/s, epoch=4/30, avg_epoch_loss=4.42]
# 100%|██████████| 50/50 [00:00<00:00, 75.50it/s, epoch=5/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.83it/s, epoch=6/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 75.05it/s, epoch=7/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 76.34it/s, epoch=8/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 75.93it/s, epoch=9/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.25it/s, epoch=10/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 76.33it/s, epoch=11/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 73.99it/s, epoch=12/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 73.83it/s, epoch=13/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 73.31it/s, epoch=14/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 53.33it/s, epoch=15/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 52.75it/s, epoch=16/30, avg_epoch_loss=4.49]
# 100%|██████████| 50/50 [00:00<00:00, 53.01it/s, epoch=17/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 53.47it/s, epoch=18/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:01<00:00, 49.58it/s, epoch=19/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 60.14it/s, epoch=20/30, avg_epoch_loss=4.45]
# 100%|██████████| 50/50 [00:00<00:00, 76.89it/s, epoch=21/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 77.64it/s, epoch=22/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 74.98it/s, epoch=23/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 76.16it/s, epoch=24/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.47it/s, epoch=25/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 76.75it/s, epoch=26/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 76.95it/s, epoch=27/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 77.03it/s, epoch=28/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 77.66it/s, epoch=29/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 74.61it/s, epoch=30/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 71.71it/s, epoch=1/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 77.54it/s, epoch=2/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 76.19it/s, epoch=3/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 76.85it/s, epoch=4/30, avg_epoch_loss=4.64]
# 100%|██████████| 50/50 [00:00<00:00, 56.97it/s, epoch=5/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 51.47it/s, epoch=6/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 52.64it/s, epoch=7/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 50.76it/s, epoch=8/30, avg_epoch_loss=4.62]
# 100%|██████████| 50/50 [00:01<00:00, 49.46it/s, epoch=9/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.61it/s, epoch=10/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 76.77it/s, epoch=11/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 71.37it/s, epoch=12/30, avg_epoch_loss=4.59]
# 100%|██████████| 50/50 [00:00<00:00, 78.28it/s, epoch=13/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 75.44it/s, epoch=14/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 75.05it/s, epoch=15/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 76.58it/s, epoch=16/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 78.23it/s, epoch=17/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 76.58it/s, epoch=18/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 73.29it/s, epoch=19/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 77.72it/s, epoch=20/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 74.82it/s, epoch=21/30, avg_epoch_loss=4.55]
# 100%|██████████| 50/50 [00:00<00:00, 76.23it/s, epoch=22/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 63.11it/s, epoch=23/30, avg_epoch_loss=4.63]
# 100%|██████████| 50/50 [00:00<00:00, 71.78it/s, epoch=24/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 54.41it/s, epoch=25/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 51.16it/s, epoch=26/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 51.59it/s, epoch=27/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 50.42it/s, epoch=28/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:01<00:00, 46.33it/s, epoch=29/30, avg_epoch_loss=4.72]
# 100%|██████████| 50/50 [00:00<00:00, 62.94it/s, epoch=30/30, avg_epoch_loss=5.91]
# 100%|██████████| 50/50 [00:00<00:00, 71.82it/s, epoch=1/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 74.88it/s, epoch=2/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 74.09it/s, epoch=3/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 76.43it/s, epoch=4/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:00<00:00, 74.14it/s, epoch=5/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 73.57it/s, epoch=6/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 77.11it/s, epoch=7/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 73.31it/s, epoch=8/30, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:00<00:00, 68.29it/s, epoch=9/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 51.11it/s, epoch=10/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 51.14it/s, epoch=11/30, avg_epoch_loss=4.59]
# 100%|██████████| 50/50 [00:00<00:00, 51.77it/s, epoch=12/30, avg_epoch_loss=4.43]
# 100%|██████████| 50/50 [00:01<00:00, 48.46it/s, epoch=13/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:01<00:00, 42.15it/s, epoch=14/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 44.49it/s, epoch=15/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 50.18it/s, epoch=16/30, avg_epoch_loss=4.52]
# 100%|██████████| 50/50 [00:00<00:00, 54.20it/s, epoch=17/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:01<00:00, 47.93it/s, epoch=18/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 53.70it/s, epoch=19/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 75.79it/s, epoch=20/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 75.04it/s, epoch=21/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 74.62it/s, epoch=22/30, avg_epoch_loss=4.4]
# 100%|██████████| 50/50 [00:00<00:00, 75.43it/s, epoch=23/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.85it/s, epoch=24/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 74.17it/s, epoch=25/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 76.37it/s, epoch=26/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 74.94it/s, epoch=27/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 74.24it/s, epoch=28/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 77.64it/s, epoch=29/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 74.97it/s, epoch=30/30, avg_epoch_loss=4.54]
# 100%|██████████| 50/50 [00:00<00:00, 70.05it/s, epoch=1/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 76.77it/s, epoch=2/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 75.58it/s, epoch=3/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 55.49it/s, epoch=4/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 53.09it/s, epoch=5/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 51.28it/s, epoch=6/30, avg_epoch_loss=3.16]
# 100%|██████████| 50/50 [00:00<00:00, 51.60it/s, epoch=7/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:01<00:00, 49.44it/s, epoch=8/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 56.24it/s, epoch=9/30, avg_epoch_loss=4.6]
# 100%|██████████| 50/50 [00:00<00:00, 76.44it/s, epoch=10/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 76.04it/s, epoch=11/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 75.00it/s, epoch=12/30, avg_epoch_loss=3.19]
# 100%|██████████| 50/50 [00:00<00:00, 76.54it/s, epoch=13/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 76.64it/s, epoch=14/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 75.40it/s, epoch=15/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 76.58it/s, epoch=16/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 74.58it/s, epoch=17/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 74.12it/s, epoch=18/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.62it/s, epoch=19/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 74.70it/s, epoch=20/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 76.82it/s, epoch=21/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 75.12it/s, epoch=22/30, avg_epoch_loss=3.15]
# 100%|██████████| 50/50 [00:00<00:00, 74.92it/s, epoch=23/30, avg_epoch_loss=4.51]
# 100%|██████████| 50/50 [00:00<00:00, 57.39it/s, epoch=24/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 51.33it/s, epoch=25/30, avg_epoch_loss=3.12]
# 100%|██████████| 50/50 [00:00<00:00, 53.30it/s, epoch=26/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 53.18it/s, epoch=27/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:01<00:00, 49.63it/s, epoch=28/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 53.56it/s, epoch=29/30, avg_epoch_loss=3.17]
# 100%|██████████| 50/50 [00:00<00:00, 73.76it/s, epoch=30/30, avg_epoch_loss=3.18]
# 100%|██████████| 50/50 [00:00<00:00, 71.55it/s, epoch=1/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 78.25it/s, epoch=2/30, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:00<00:00, 76.49it/s, epoch=3/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 74.65it/s, epoch=4/30, avg_epoch_loss=3.27]
# 100%|██████████| 50/50 [00:00<00:00, 78.54it/s, epoch=5/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 75.92it/s, epoch=6/30, avg_epoch_loss=3.34]
# 100%|██████████| 50/50 [00:00<00:00, 75.76it/s, epoch=7/30, avg_epoch_loss=3.33]
# 100%|██████████| 50/50 [00:00<00:00, 74.21it/s, epoch=8/30, avg_epoch_loss=3.38]
# 100%|██████████| 50/50 [00:00<00:00, 75.96it/s, epoch=9/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 78.24it/s, epoch=10/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 76.95it/s, epoch=11/30, avg_epoch_loss=4.76]
# 100%|██████████| 50/50 [00:00<00:00, 76.37it/s, epoch=12/30, avg_epoch_loss=3.3]
# 100%|██████████| 50/50 [00:00<00:00, 74.50it/s, epoch=13/30, avg_epoch_loss=3.26]
# 100%|██████████| 50/50 [00:00<00:00, 61.20it/s, epoch=14/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 52.91it/s, epoch=15/30, avg_epoch_loss=3.25]
# 100%|██████████| 50/50 [00:00<00:00, 51.46it/s, epoch=16/30, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:00<00:00, 53.17it/s, epoch=17/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 51.25it/s, epoch=18/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 52.04it/s, epoch=19/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 75.01it/s, epoch=20/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 76.88it/s, epoch=21/30, avg_epoch_loss=4.66]
# 100%|██████████| 50/50 [00:00<00:00, 78.66it/s, epoch=22/30, avg_epoch_loss=4.78]
# 100%|██████████| 50/50 [00:00<00:00, 78.52it/s, epoch=23/30, avg_epoch_loss=3.39]
# 100%|██████████| 50/50 [00:00<00:00, 77.33it/s, epoch=24/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 75.33it/s, epoch=25/30, avg_epoch_loss=3.29]
# 100%|██████████| 50/50 [00:00<00:00, 76.37it/s, epoch=26/30, avg_epoch_loss=3.32]
# 100%|██████████| 50/50 [00:00<00:00, 74.18it/s, epoch=27/30, avg_epoch_loss=3.28]
# 100%|██████████| 50/50 [00:00<00:00, 72.86it/s, epoch=28/30, avg_epoch_loss=3.37]
# 100%|██████████| 50/50 [00:00<00:00, 74.96it/s, epoch=29/30, avg_epoch_loss=4.72]
# 100%|██████████| 50/50 [00:00<00:00, 76.05it/s, epoch=30/30, avg_epoch_loss=4.69]
# 100%|██████████| 50/50 [00:00<00:00, 71.47it/s, epoch=1/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 76.37it/s, epoch=2/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 77.01it/s, epoch=3/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 58.94it/s, epoch=4/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 51.59it/s, epoch=5/30, avg_epoch_loss=3.31]
# 100%|██████████| 50/50 [00:00<00:00, 52.69it/s, epoch=6/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.62it/s, epoch=7/30, avg_epoch_loss=3.24]
# 100%|██████████| 50/50 [00:00<00:00, 50.71it/s, epoch=8/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 53.57it/s, epoch=9/30, avg_epoch_loss=3.22]
# 100%|██████████| 50/50 [00:00<00:00, 76.97it/s, epoch=10/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.24it/s, epoch=11/30, avg_epoch_loss=3.23]
# 100%|██████████| 50/50 [00:00<00:00, 76.83it/s, epoch=12/30, avg_epoch_loss=3.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.44it/s, epoch=13/30, avg_epoch_loss=3.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.65it/s, epoch=14/30, avg_epoch_loss=4.53]
# 100%|██████████| 50/50 [00:00<00:00, 73.23it/s, epoch=15/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 75.88it/s, epoch=16/30, avg_epoch_loss=5.83]
# 100%|██████████| 50/50 [00:00<00:00, 74.88it/s, epoch=17/30, avg_epoch_loss=4.57]
# 100%|██████████| 50/50 [00:00<00:00, 76.03it/s, epoch=18/30, avg_epoch_loss=3.23]
# ...
# 100%|██████████| 50/50 [00:00<00:00, 78.83it/s, epoch=16/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 81.05it/s, epoch=17/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 76.24it/s, epoch=18/30, avg_epoch_loss=3.96]
# 100%|██████████| 50/50 [00:00<00:00, 76.60it/s, epoch=19/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 78.15it/s, epoch=20/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 73.46it/s, epoch=21/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 74.90it/s, epoch=22/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 76.53it/s, epoch=23/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 78.48it/s, epoch=24/30, avg_epoch_loss=3.98]
# 100%|██████████| 50/50 [00:00<00:00, 62.67it/s, epoch=25/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 52.75it/s, epoch=26/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 51.94it/s, epoch=27/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:00<00:00, 52.04it/s, epoch=28/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:01<00:00, 48.56it/s, epoch=29/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 51.14it/s, epoch=30/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 68.75it/s, epoch=1/30, avg_epoch_loss=6.84]
# 100%|██████████| 50/50 [00:00<00:00, 75.97it/s, epoch=2/30, avg_epoch_loss=5.26]
# 100%|██████████| 50/50 [00:00<00:00, 71.49it/s, epoch=3/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 73.90it/s, epoch=4/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 75.76it/s, epoch=5/30, avg_epoch_loss=3.8]
# 100%|██████████| 50/50 [00:00<00:00, 78.46it/s, epoch=6/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 76.66it/s, epoch=7/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 76.55it/s, epoch=8/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:00<00:00, 77.22it/s, epoch=9/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 77.44it/s, epoch=10/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 75.88it/s, epoch=11/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 78.51it/s, epoch=12/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:00<00:00, 74.70it/s, epoch=13/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 74.48it/s, epoch=14/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 61.73it/s, epoch=15/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 52.47it/s, epoch=16/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 51.14it/s, epoch=17/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 51.00it/s, epoch=18/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:01<00:00, 49.40it/s, epoch=19/30, avg_epoch_loss=5.43]
# 100%|██████████| 50/50 [00:00<00:00, 54.67it/s, epoch=20/30, avg_epoch_loss=5.27]
# 100%|██████████| 50/50 [00:00<00:00, 75.34it/s, epoch=21/30, avg_epoch_loss=5.33]
# 100%|██████████| 50/50 [00:00<00:00, 73.69it/s, epoch=22/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 75.90it/s, epoch=23/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 73.76it/s, epoch=24/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 72.77it/s, epoch=25/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 75.62it/s, epoch=26/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 74.71it/s, epoch=27/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 75.02it/s, epoch=28/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 75.34it/s, epoch=29/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 73.73it/s, epoch=30/30, avg_epoch_loss=5.27]
# 100%|██████████| 50/50 [00:00<00:00, 69.44it/s, epoch=1/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 73.55it/s, epoch=2/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 74.90it/s, epoch=3/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 75.17it/s, epoch=4/30, avg_epoch_loss=5.2]
# 100%|██████████| 50/50 [00:00<00:00, 53.01it/s, epoch=5/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:01<00:00, 47.52it/s, epoch=6/30, avg_epoch_loss=5.25]
# 100%|██████████| 50/50 [00:01<00:00, 49.84it/s, epoch=7/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 50.27it/s, epoch=8/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:01<00:00, 48.82it/s, epoch=9/30, avg_epoch_loss=5.22]
# 100%|██████████| 50/50 [00:01<00:00, 47.21it/s, epoch=10/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:01<00:00, 43.86it/s, epoch=11/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:01<00:00, 44.70it/s, epoch=12/30, avg_epoch_loss=6.44]
# 100%|██████████| 50/50 [00:01<00:00, 43.83it/s, epoch=13/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 56.74it/s, epoch=14/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 77.79it/s, epoch=15/30, avg_epoch_loss=4]
# 100%|██████████| 50/50 [00:00<00:00, 73.09it/s, epoch=16/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:00<00:00, 72.53it/s, epoch=17/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 77.57it/s, epoch=18/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 74.98it/s, epoch=19/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 75.92it/s, epoch=20/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 75.64it/s, epoch=21/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 73.55it/s, epoch=22/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 78.26it/s, epoch=23/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 77.90it/s, epoch=24/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 77.78it/s, epoch=25/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 76.27it/s, epoch=26/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 63.27it/s, epoch=27/30, avg_epoch_loss=5.23]
# 100%|██████████| 50/50 [00:00<00:00, 51.52it/s, epoch=28/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 52.04it/s, epoch=29/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 52.40it/s, epoch=30/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:01<00:00, 45.21it/s, epoch=1/30, avg_epoch_loss=3.96]
# 100%|██████████| 50/50 [00:00<00:00, 58.14it/s, epoch=2/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 76.63it/s, epoch=3/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 72.69it/s, epoch=4/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 74.83it/s, epoch=5/30, avg_epoch_loss=4]
# 100%|██████████| 50/50 [00:00<00:00, 71.28it/s, epoch=6/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:00<00:00, 77.08it/s, epoch=7/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 75.20it/s, epoch=8/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 77.95it/s, epoch=9/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 77.42it/s, epoch=10/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 75.03it/s, epoch=11/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 77.63it/s, epoch=12/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 76.88it/s, epoch=13/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 75.01it/s, epoch=14/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 75.21it/s, epoch=15/30, avg_epoch_loss=5.22]
# 100%|██████████| 50/50 [00:00<00:00, 76.67it/s, epoch=16/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 59.81it/s, epoch=17/30, avg_epoch_loss=3.98]
# 100%|██████████| 50/50 [00:00<00:00, 53.36it/s, epoch=18/30, avg_epoch_loss=3.98]
# 100%|██████████| 50/50 [00:00<00:00, 54.15it/s, epoch=19/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 52.59it/s, epoch=20/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:01<00:00, 49.33it/s, epoch=21/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 51.22it/s, epoch=22/30, avg_epoch_loss=3.97]
# 100%|██████████| 50/50 [00:00<00:00, 77.38it/s, epoch=23/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 75.00it/s, epoch=24/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 75.31it/s, epoch=25/30, avg_epoch_loss=5.08]
# 100%|██████████| 50/50 [00:00<00:00, 78.32it/s, epoch=26/30, avg_epoch_loss=5.2]
# 100%|██████████| 50/50 [00:00<00:00, 75.50it/s, epoch=27/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 76.82it/s, epoch=28/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 78.26it/s, epoch=29/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 76.24it/s, epoch=30/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 71.08it/s, epoch=1/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 76.71it/s, epoch=2/30, avg_epoch_loss=3.78]
# 100%|██████████| 50/50 [00:00<00:00, 73.31it/s, epoch=3/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 71.84it/s, epoch=4/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 71.83it/s, epoch=5/30, avg_epoch_loss=5.32]
# 100%|██████████| 50/50 [00:00<00:00, 73.70it/s, epoch=6/30, avg_epoch_loss=5.25]
# 100%|██████████| 50/50 [00:00<00:00, 60.12it/s, epoch=7/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 53.48it/s, epoch=8/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 52.42it/s, epoch=9/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 54.47it/s, epoch=10/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 51.36it/s, epoch=11/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:00<00:00, 50.53it/s, epoch=12/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 74.40it/s, epoch=13/30, avg_epoch_loss=5.29]
# 100%|██████████| 50/50 [00:00<00:00, 78.50it/s, epoch=14/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 75.68it/s, epoch=15/30, avg_epoch_loss=3.78]
# 100%|██████████| 50/50 [00:00<00:00, 75.53it/s, epoch=16/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:00<00:00, 74.29it/s, epoch=17/30, avg_epoch_loss=3.79]
# 100%|██████████| 50/50 [00:00<00:00, 74.69it/s, epoch=18/30, avg_epoch_loss=5.21]
# 100%|██████████| 50/50 [00:00<00:00, 75.86it/s, epoch=19/30, avg_epoch_loss=4]
# 100%|██████████| 50/50 [00:00<00:00, 76.83it/s, epoch=20/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 77.75it/s, epoch=21/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 78.61it/s, epoch=22/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 78.20it/s, epoch=23/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 77.10it/s, epoch=24/30, avg_epoch_loss=5.31]
# 100%|██████████| 50/50 [00:00<00:00, 77.52it/s, epoch=25/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 73.81it/s, epoch=26/30, avg_epoch_loss=6.68]
# 100%|██████████| 50/50 [00:00<00:00, 71.08it/s, epoch=27/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 53.43it/s, epoch=28/30, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:00<00:00, 52.61it/s, epoch=29/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 53.57it/s, epoch=30/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:01<00:00, 48.43it/s, epoch=1/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:01<00:00, 48.85it/s, epoch=2/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 76.74it/s, epoch=3/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 74.60it/s, epoch=4/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 75.98it/s, epoch=5/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 74.12it/s, epoch=6/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 74.70it/s, epoch=7/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 74.96it/s, epoch=8/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 69.15it/s, epoch=9/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 73.70it/s, epoch=10/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 76.88it/s, epoch=11/30, avg_epoch_loss=3.8]
# 100%|██████████| 50/50 [00:00<00:00, 73.19it/s, epoch=12/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 76.55it/s, epoch=13/30, avg_epoch_loss=5.08]
# 100%|██████████| 50/50 [00:00<00:00, 77.09it/s, epoch=14/30, avg_epoch_loss=3.78]
# 100%|██████████| 50/50 [00:00<00:00, 74.79it/s, epoch=15/30, avg_epoch_loss=3.83]
# 100%|██████████| 50/50 [00:00<00:00, 75.85it/s, epoch=16/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 67.04it/s, epoch=17/30, avg_epoch_loss=5.24]
# 100%|██████████| 50/50 [00:00<00:00, 52.80it/s, epoch=18/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 52.71it/s, epoch=19/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 53.60it/s, epoch=20/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 52.23it/s, epoch=21/30, avg_epoch_loss=6.44]
# 100%|██████████| 50/50 [00:01<00:00, 47.06it/s, epoch=22/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 67.43it/s, epoch=23/30, avg_epoch_loss=5.17]
# 100%|██████████| 50/50 [00:00<00:00, 73.19it/s, epoch=24/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 75.77it/s, epoch=25/30, avg_epoch_loss=3.9]
# 100%|██████████| 50/50 [00:00<00:00, 76.92it/s, epoch=26/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 74.11it/s, epoch=27/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 74.91it/s, epoch=28/30, avg_epoch_loss=3.95]
# 100%|██████████| 50/50 [00:00<00:00, 74.81it/s, epoch=29/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 76.83it/s, epoch=30/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 69.57it/s, epoch=1/30, avg_epoch_loss=5.16]
# 100%|██████████| 50/50 [00:00<00:00, 77.11it/s, epoch=2/30, avg_epoch_loss=3.81]
# 100%|██████████| 50/50 [00:00<00:00, 75.82it/s, epoch=3/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 77.70it/s, epoch=4/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 78.01it/s, epoch=5/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 75.83it/s, epoch=6/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 72.71it/s, epoch=7/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 54.42it/s, epoch=8/30, avg_epoch_loss=3.8]
# 100%|██████████| 50/50 [00:00<00:00, 52.20it/s, epoch=9/30, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:00<00:00, 51.17it/s, epoch=10/30, avg_epoch_loss=3.84]
# 100%|██████████| 50/50 [00:00<00:00, 53.93it/s, epoch=11/30, avg_epoch_loss=5.03]
# 100%|██████████| 50/50 [00:01<00:00, 47.09it/s, epoch=12/30, avg_epoch_loss=3.82]
# 100%|██████████| 50/50 [00:00<00:00, 63.08it/s, epoch=13/30, avg_epoch_loss=5.09]
# 100%|██████████| 50/50 [00:00<00:00, 76.36it/s, epoch=14/30, avg_epoch_loss=3.85]
# 100%|██████████| 50/50 [00:00<00:00, 75.76it/s, epoch=15/30, avg_epoch_loss=3.92]
# 100%|██████████| 50/50 [00:00<00:00, 72.11it/s, epoch=16/30, avg_epoch_loss=5.08]
# 100%|██████████| 50/50 [00:00<00:00, 75.01it/s, epoch=17/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 75.61it/s, epoch=18/30, avg_epoch_loss=3.94]
# 100%|██████████| 50/50 [00:00<00:00, 69.98it/s, epoch=19/30, avg_epoch_loss=6.34]
# 100%|██████████| 50/50 [00:00<00:00, 74.93it/s, epoch=20/30, avg_epoch_loss=5.06]
# 100%|██████████| 50/50 [00:00<00:00, 77.93it/s, epoch=21/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 78.40it/s, epoch=22/30, avg_epoch_loss=3.98]
# 100%|██████████| 50/50 [00:00<00:00, 76.32it/s, epoch=23/30, avg_epoch_loss=3.76]
# 100%|██████████| 50/50 [00:00<00:00, 75.12it/s, epoch=24/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 74.61it/s, epoch=25/30, avg_epoch_loss=3.89]
# 100%|██████████| 50/50 [00:00<00:00, 75.98it/s, epoch=26/30, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:00<00:00, 77.57it/s, epoch=27/30, avg_epoch_loss=5.12]
# 100%|██████████| 50/50 [00:00<00:00, 56.39it/s, epoch=28/30, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:00<00:00, 53.81it/s, epoch=29/30, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:00<00:00, 53.21it/s, epoch=30/30, avg_epoch_loss=5.13]
# ROG: 17.537771112701243
